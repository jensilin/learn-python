# %%
#Integers

#integers = whole numbers

print(123)
# Out:
# 123

# %%
#Float = floating point numbers
print(3141.48)
# Out:
# 3141.48

# %%
#Boolean
print(True)

print(False)
# Out:
# True
# False

# %%
#Type function

#If we want to check the data type of any function
print(type(123))
# Out:
# <class 'int'>

# %%
print(type(123.34))
# Out:
# <class 'float'>

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
print(type("Jensilin"))
# Out:
# <class 'str'>

# %%
#Type casting
#If we want change the data type from one to another
#Exam from string to Integer

print(type("123"))
a="123"
#int(a)         is converting to integer
print(type(int(a)))
# Out:
# <class 'str'>
# <class 'int'>
