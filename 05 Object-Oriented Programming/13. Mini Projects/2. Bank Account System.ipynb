# %% [markdown]
# # 🏦 Mini Project: Bank Account System in Python
#
# A **Bank Account System** is a simple application that manages customer bank accounts and allows users to perform basic banking operations.
#
# This project demonstrates how **Object-Oriented Programming (OOP)** concepts work together to build a real-world application.
#
# Throughout this project, you will apply concepts such as:
#
# - Classes
# - Objects
# - Constructors
# - Instance Variables
# - Methods
# - Encapsulation
# - Exception Handling
# - Lists
# - Conditional Statements
#
# This project is an excellent way to practice Python OOP while understanding how banking systems manage accounts.
#
# ---
#
# # 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - How to create a Bank Account class.
# - How to manage multiple bank accounts.
# - How to deposit money.
# - How to withdraw money.
# - How to check account balances.
# - How to search for accounts.
# - How to delete accounts.
# - How OOP concepts are used in banking applications.
# - Best coding practices.
#
# ---
#
# # 💻 Project Overview
#
# Our Bank Account System will support the following operations:
#
# - ➕ Create Account
# - 💰 Deposit Money
# - 💸 Withdraw Money
# - 💵 Check Balance
# - 🔍 Search Account
# - 📋 View All Accounts
# - ❌ Delete Account
# - 🚪 Exit Program
#
# ---
#
# # 📖 Topics Covered
#
# ## 1. Designing the BankAccount Class
#
# The `BankAccount` class stores information about each customer.
#
# ```python
# class BankAccount:
#
#     def __init__(self, account_number, account_holder, balance=0):
#
#         self.account_number = account_number
#         self.account_holder = account_holder
#         self.balance = balance
#
#     def display(self):
#
#         print(f"Account Number : {self.account_number}")
#         print(f"Account Holder : {self.account_holder}")
#         print(f"Balance        : ₹{self.balance}")
# ```
#
# ---
#
# ## 2. Creating the Bank Management Class
#
# This class manages all bank accounts.
#
# ```python
# class BankManagementSystem:
#
#     def __init__(self):
#
#         self.accounts = []
# ```
#
# The `accounts` list stores all bank account objects.
#
# ---
#
# ## 3. Creating a New Account
#
# ```python
# def create_account(self, account):
#
#     self.accounts.append(account)
#
#     print("Account created successfully.")
# ```
#
# ---
#
# ## 4. Searching for an Account
#
# ```python
# def search_account(self, account_number):
#
#     for account in self.accounts:
#
#         if account.account_number == account_number:
#             return account
#
#     return None
# ```
#
# ---
#
# ## 5. Depositing Money
#
# ```python
# def deposit(self, account_number, amount):
#
#     account = self.search_account(account_number)
#
#     if account:
#
#         account.balance += amount
#
#         print("Amount deposited successfully.")
#
#     else:
#
#         print("Account not found.")
# ```
#
# ---
#
# ## 6. Withdrawing Money
#
# ```python
# def withdraw(self, account_number, amount):
#
#     account = self.search_account(account_number)
#
#     if account:
#
#         if amount > account.balance:
#             print("Insufficient balance.")
#         else:
#             account.balance -= amount
#             print("Withdrawal successful.")
#
#     else:
#
#         print("Account not found.")
# ```
#
# ---
#
# ## 7. Viewing All Accounts
#
# ```python
# def view_accounts(self):
#
#     if not self.accounts:
#
#         print("No accounts available.")
#         return
#
#     for account in self.accounts:
#
#         account.display()
#
#         print("-" * 35)
# ```
#
# ---
#
# ## 8. Deleting an Account
#
# ```python
# def delete_account(self, account_number):
#
#     account = self.search_account(account_number)
#
#     if account:
#
#         self.accounts.remove(account)
#
#         print("Account deleted successfully.")
#
#     else:
#
#         print("Account not found.")
# ```
#
# ---
#
# ## 9. Complete Project
#
# ```python
# class BankAccount:
#
#     def __init__(self, account_number, account_holder, balance=0):
#
#         self.account_number = account_number
#         self.account_holder = account_holder
#         self.balance = balance
#
#     def display(self):
#
#         print(f"Account Number : {self.account_number}")
#         print(f"Account Holder : {self.account_holder}")
#         print(f"Balance        : ₹{self.balance}")
#
#
# class BankManagementSystem:
#
#     def __init__(self):
#
#         self.accounts = []
#
#     def create_account(self, account):
#
#         self.accounts.append(account)
#
#         print("Account created successfully.")
#
#     def search_account(self, account_number):
#
#         for account in self.accounts:
#
#             if account.account_number == account_number:
#                 return account
#
#         return None
#
#     def deposit(self, account_number, amount):
#
#         account = self.search_account(account_number)
#
#         if account:
#
#             account.balance += amount
#
#             print("Amount deposited successfully.")
#
#         else:
#
#             print("Account not found.")
#
#     def withdraw(self, account_number, amount):
#
#         account = self.search_account(account_number)
#
#         if account:
#
#             if amount > account.balance:
#
#                 print("Insufficient balance.")
#
#             else:
#
#                 account.balance -= amount
#
#                 print("Withdrawal successful.")
#
#         else:
#
#             print("Account not found.")
#
#     def view_accounts(self):
#
#         if not self.accounts:
#
#             print("No accounts available.")
#             return
#
#         for account in self.accounts:
#
#             account.display()
#
#             print("-" * 35)
#
#     def delete_account(self, account_number):
#
#         account = self.search_account(account_number)
#
#         if account:
#
#             self.accounts.remove(account)
#
#             print("Account deleted successfully.")
#
#         else:
#
#             print("Account not found.")
#
#
# system = BankManagementSystem()
#
# account1 = BankAccount(1001, "Alice", 5000)
# account2 = BankAccount(1002, "Bob", 3000)
#
# system.create_account(account1)
# system.create_account(account2)
#
# print("\nAll Accounts")
#
# system.view_accounts()
#
# print("\nDepositing Money")
#
# system.deposit(1001, 2000)
#
# print("\nWithdrawing Money")
#
# system.withdraw(1002, 1000)
#
# print("\nChecking Updated Accounts")
#
# system.view_accounts()
#
# print("\nDeleting Account")
#
# system.delete_account(1002)
#
# print("\nRemaining Accounts")
#
# system.view_accounts()
# ```
#
# ### Output
#
# ```text
# Account created successfully.
# Account created successfully.
#
# All Accounts
#
# Account Number : 1001
# Account Holder : Alice
# Balance        : ₹5000
# -----------------------------------
#
# Account Number : 1002
# Account Holder : Bob
# Balance        : ₹3000
# -----------------------------------
#
# Depositing Money
#
# Amount deposited successfully.
#
# Withdrawing Money
#
# Withdrawal successful.
#
# Checking Updated Accounts
#
# Account Number : 1001
# Account Holder : Alice
# Balance        : ₹7000
# -----------------------------------
#
# Account Number : 1002
# Account Holder : Bob
# Balance        : ₹2000
# -----------------------------------
#
# Deleting Account
#
# Account deleted successfully.
#
# Remaining Accounts
#
# Account Number : 1001
# Account Holder : Alice
# Balance        : ₹7000
# -----------------------------------
# ```
#
# ---
#
# ## 10. OOP Concepts Used
#
# | OOP Concept | Usage in Project |
# |-------------|------------------|
# | Class | `BankAccount`, `BankManagementSystem` |
# | Object | Customer bank accounts |
# | Constructor | Initialize account details |
# | Instance Variables | Account number, holder name, balance |
# | Methods | Deposit, withdraw, search, delete |
# | Encapsulation | Account data stored inside objects |
# | Composition | Bank management system contains bank account objects |
# | Exception Handling | Balance validation and account lookup |
#
# ---
#
# ## 11. Possible Enhancements
#
# This project can be extended with additional features such as:
#
# - PIN-based authentication
# - Money transfer between accounts
# - Transaction history
# - Interest calculation
# - Fixed deposit accounts
# - Savings and current account types
# - Loan management
# - Monthly statements
# - File handling (save/load accounts)
# - Database integration (SQLite/MySQL)
# - Graphical User Interface (Tkinter/PyQt)
# - Web application using Flask or Django
#
# ---
#
# ## 12. Real-World Applications
#
# Bank account management systems are used in:
#
# - Commercial banks
# - Online banking applications
# - Mobile banking apps
# - ATM software
# - Digital wallet platforms
# - Cooperative banks
# - Financial institutions
# - FinTech applications
#
# ---
#
# ## 13. Common Mistakes
#
# Avoid these common mistakes while building a bank account system.
#
# ### Allowing Duplicate Account Numbers
#
# Always ensure that each account number is unique before creating a new account.
#
# ---
#
# ### Allowing Negative Deposits
#
# Validate deposit amounts before updating the balance.
#
# Example:
#
# ```python
# if amount <= 0:
#     raise ValueError("Deposit amount must be greater than zero.")
# ```
#
# ---
#
# ### Allowing Negative Balances
#
# Prevent withdrawals that exceed the available balance.
#
# Example:
#
# ```python
# if amount > account.balance:
#     raise ValueError("Insufficient balance.")
# ```
#
# ---
#
# ### Mixing User Interface with Business Logic
#
# Keep menu-driven input/output separate from the classes that manage bank accounts.
#
# ---
#
# ## 14. Best Practices
#
# Follow these recommended practices while building the project.
#
# - Create separate classes for accounts and account management.
# - Validate all user inputs.
# - Prevent duplicate account numbers.
# - Handle exceptions gracefully.
# - Use meaningful method names.
# - Keep methods short and focused.
# - Protect sensitive account data using encapsulation.
# - Avoid duplicate code.
# - Follow the SOLID principles where appropriate.
# - Write clean and maintainable code.
#
# ---
#
# # 📊 Summary
#
# | Feature | Description |
# |---------|-------------|
# | Project | Bank Account System |
# | Difficulty | Beginner |
# | Concepts Used | Classes, Objects, Methods, Constructors, Encapsulation, Exception Handling |
# | Operations | Create, Deposit, Withdraw, Search, View, Delete |
# | Storage | Python List |
# | Extension Ideas | Database, GUI, Web Application, Transaction History |
#
# ---
#
# > **Note:** The **Bank Account System** is a practical beginner-level OOP project that demonstrates how classes and objects can model real-world banking operations. By separating account data from account management logic, the project follows good object-oriented design practices and provides a strong foundation for building more advanced banking applications with features such as authentication, transaction history, databases, and graphical or web-based interfaces.
