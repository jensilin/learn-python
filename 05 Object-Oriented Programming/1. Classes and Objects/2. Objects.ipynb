# %% [markdown]
# #### 🎯 Objects in Python
#
# An **object** is an **instance of a class**. When a class is created, it serves as a blueprint. An object is the actual entity created from that blueprint.
#
# Objects contain their own **attributes (data)** and can perform **methods (functions)** defined inside their class.
#
# In Object-Oriented Programming (OOP), objects represent real-world entities such as students, cars, employees, bank accounts, and many more.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What an object is.
# - Why objects are used.
# - How to create objects.
# - Accessing object attributes and methods.
# - Multiple objects from the same class.
# - Practical examples.
# - Common use cases.
# - Common mistakes.
# - Best practices.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# class Student:
#     pass
#
# student1 = Student()
#
# print(student1)
# ```
#
# ##### Sample Output
#
# ```text
# <__main__.Student object at 0x7f8c5d9b8fd0>
# ```
#
# > **Note:** The memory address will vary each time you run the program.
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. What is an Object?
#
# An **object** is an instance of a class.
#
# A class defines the structure, while objects are the actual entities created from that structure.
#
# Example:
#
# ```python
# class Car:
#     pass
#
# car1 = Car()
# ```
#
# Here:
#
# - `Car` is a class.
# - `car1` is an object of the `Car` class.
#
# ---
#
# ##### 2. Why Use Objects?
#
# Objects help us:
#
# - Represent real-world entities.
# - Store individual data.
# - Call methods defined in a class.
# - Create multiple independent instances.
# - Organize programs efficiently.
#
# ---
#
# ##### 3. Syntax for Creating an Object
#
# ##### Syntax
#
# ```python
# object_name = ClassName()
# ```
#
# Example:
#
# ```python
# class Student:
#     pass
#
# student = Student()
# ```
#
# ##### Explanation
#
# - `Student` → Class
# - `Student()` → Constructor call that creates an object
# - `student` → Object reference
#
# ---
#
# ##### 4. Creating Multiple Objects
#
# A single class can create many objects.
#
# ```python
# class Student:
#     pass
#
# student1 = Student()
# student2 = Student()
# student3 = Student()
# ```
#
# Each object is independent.
#
# ---
#
# ##### 5. Checking the Type of an Object
#
# Use the `type()` function to determine the class of an object.
#
# ```python
# class Employee:
#     pass
#
# emp = Employee()
#
# print(type(emp))
# ```
#
# ##### Output
#
# ```text
# <class '__main__.Employee'>
# ```
#
# ---
#
# ##### 6. Checking Object Identity
#
# Every object has its own identity.
#
# ```python
# class Laptop:
#     pass
#
# laptop1 = Laptop()
# laptop2 = Laptop()
#
# print(id(laptop1))
# print(id(laptop2))
# ```
#
# ##### Sample Output
#
# ```text
# 140543260798112
# 140543260798304
# ```
#
# Each object has a unique identity.
#
# ---
#
# ##### 7. Multiple Objects of the Same Class
#
# ```python
# class Animal:
#     pass
#
# dog = Animal()
# cat = Animal()
#
# print(type(dog))
# print(type(cat))
# ```
#
# ##### Output
#
# ```text
# <class '__main__.Animal'>
# <class '__main__.Animal'>
# ```
#
# Although both belong to the same class, they are different objects.
#
# ---
#
# ##### 8. Objects Can Access Methods
#
# Objects use the dot (`.`) operator to call methods.
#
# ```python
# class Student:
#
#     def greet(self):
#         print("Welcome!")
#
# student = Student()
#
# student.greet()
# ```
#
# ##### Output
#
# ```text
# Welcome!
# ```
#
# ---
#
# ##### 9. Objects Can Access Attributes
#
# ```python
# class Car:
#
#     brand = "Toyota"
#
# car = Car()
#
# print(car.brand)
# ```
#
# ##### Output
#
# ```text
# Toyota
# ```
#
# ---
#
# ##### 10. Practical Examples
#
# ##### Example 1: Student Object
#
# ```python
# class Student:
#
#     college = "ABC College"
#
# student = Student()
#
# print(student.college)
# ```
#
# ##### Output
#
# ```text
# ABC College
# ```
#
# ---
#
# ##### Example 2: Bank Account
#
# ```python
# class BankAccount:
#
#     bank_name = "XYZ Bank"
#
# account = BankAccount()
#
# print(account.bank_name)
# ```
#
# ##### Output
#
# ```text
# XYZ Bank
# ```
#
# ---
#
# ##### Example 3: Calculator
#
# ```python
# class Calculator:
#
#     def add(self):
#         print(50 + 20)
#
# calc = Calculator()
#
# calc.add()
# ```
#
# ##### Output
#
# ```text
# 70
# ```
#
# ---
#
# ##### Example 4: Vehicle
#
# ```python
# class Vehicle:
#
#     wheels = 4
#
# car = Vehicle()
#
# print(car.wheels)
# ```
#
# ##### Output
#
# ```text
# 4
# ```
#
# ---
#
# ##### 11. Common Use Cases
#
# Objects are commonly used in:
#
# - Student Management Systems
# - Banking Applications
# - Hospital Management Systems
# - Inventory Systems
# - Library Management Systems
# - E-commerce Applications
# - Game Development
# - GUI Applications
# - Web Applications
# - Machine Learning Models
#
# ---
#
# ##### 12. Common Mistakes
#
# Avoid these common mistakes while creating and using objects.
#
# ##### Forgetting Parentheses
#
# Incorrect
#
# ```python
# class Student:
#     pass
#
# student = Student
# ```
#
# Correct
#
# ```python
# student = Student()
# ```
#
# ---
#
# ##### Calling an Instance Method Without an Object
#
# Incorrect
#
# ```python
# class Dog:
#
#     def bark(self):
#         print("Woof!")
#
# Dog.bark()
# ```
#
# Correct
#
# ```python
# dog = Dog()
#
# dog.bark()
# ```
#
# ---
#
# ##### Assuming All Objects Are the Same
#
# ```python
# class Book:
#     pass
#
# book1 = Book()
# book2 = Book()
#
# print(book1 == book2)
# ```
#
# ##### Output
#
# ```text
# False
# ```
#
# Different objects are not equal unless explicitly defined.
#
# ---
#
# ##### Forgetting That Each Object Has Its Own Identity
#
# ```python
# class Test:
#     pass
#
# a = Test()
# b = Test()
#
# print(id(a))
# print(id(b))
# ```
#
# The identities are different because they are different objects.
#
# ---
#
# ##### 13. Best Practices
#
# Follow these recommended practices when working with objects.
#
# - Use meaningful object names.
# - Create separate objects for separate entities.
# - Access attributes and methods using the dot (`.`) operator.
# - Avoid creating unnecessary objects.
# - Keep object names descriptive and readable.
# - Use objects to represent real-world entities.
#
# ---
#
# #### 📊 Summary
#
# | Feature | Description |
# |---------|-------------|
# | Object | Instance of a class |
# | Created Using | `ClassName()` |
# | Purpose | Represents a real-world entity |
# | Access Members | Dot (`.`) operator |
# | Identity | Each object has a unique identity |
# | Common Uses | Creating instances, storing data, calling methods |
#
# ---
#
# > **Note:** An object is a concrete instance of a class that brings the class blueprint to life. Multiple objects can be created from the same class, with each object having its own identity while sharing the structure and behavior defined by the class. Understanding objects is essential before learning constructors, instance variables, and other advanced Object-Oriented Programming concepts.

# %%
# Creating an object from a class

class Student:
    pass

student1 = Student()

print(student1)
# Out:
# <__main__.Student object at 0x000001AA8B590D70>

# %%
# Checking the type of an object

class Student:
    pass

student1 = Student()

print(type(student1))
# Out:
# <class '__main__.Student'>

# %%
# Creating multiple objects from the same class

class Student:
    pass

student1 = Student()
student2 = Student()
student3 = Student()

print(student1)
print(student2)
print(student3)
# Out:
# <__main__.Student object at 0x000001AA8B590D70>
# <__main__.Student object at 0x000001AA8B38B9D0>
# <__main__.Student object at 0x000001AA8B38B750>

# %%
# Accessing a class attribute through an object

class Student:
    school = "ABC School"
    course = "Python"

student1 = Student()

print(student1.school)
print(student1.course)
# Out:
# ABC School
# Python

# %%
# Calling a class method through an object

class Student:
    def study(self):
        print("Student is studying")

student1 = Student()

student1.study()
# Out:
# Student is studying

# %%
# Creating two objects from the same class

class Car:
    wheels = 4

car1 = Car()
car2 = Car()

print(car1.wheels)
print(car2.wheels)
# Out:
# 4
# 4

# %%
# Checking whether two variables refer to the same object

class Student:
    pass

student1 = Student()
student2 = Student()

print(student1 is student2)
# Out:
# False

# %%
# Assigning the same object to another variable

class Student:
    pass

student1 = Student()
student2 = student1

print(student1 is student2)
# Out:
# True

# %%
# Creating object-specific attributes

class Student:
    pass

student1 = Student()
student2 = Student()

student1.name = "John"
student2.name = "Alice"

print(student1.name)
print(student2.name)
# Out:
# John
# Alice

# %%
# Storing different data in different objects

class Student:
    pass

student1 = Student()
student2 = Student()

student1.name = "John"
student1.age = 20

student2.name = "Alice"
student2.age = 22

print(student1.name, student1.age)
print(student2.name, student2.age)
# Out:
# John 20
# Alice 22

# %%
# Calling multiple methods using an object

class Car:

    def start(self):
        print("Car started")

    def stop(self):
        print("Car stopped")

car1 = Car()

car1.start()
car1.stop()
# Out:
# Car started
# Car stopped

# %%
# Understanding self with an object

class Student:

    def study(self):
        print("Student is studying")

student1 = Student()

student1.study()
# Out:
# Student is studying

# %%
# Checking the identity of an object

class Student:
    pass

student1 = Student()

print(id(student1))
# Out:
# 1831993936592

# %%
# Comparing the identities of two objects

class Student:
    pass

student1 = Student()
student2 = Student()

print(id(student1))
print(id(student2))
print(student1 is student2)
# Out:
# 1831993937600
# 1831991818704
# False

# %%
# Accessing a class attribute through an object

class Student:
    school = "ABC School"

student1 = Student()

print(student1.school)
# Out:
# ABC School

# %%
# Overriding a class attribute for one object

class Student:
    school = "ABC School"

student1 = Student()
student2 = Student()

student1.school = "XYZ School"

print(student1.school)
print(student2.school)
print(Student.school)
# Out:
# XYZ School
# ABC School
# ABC School

# %%
# Passing an object to a function

class Student:
    name = "John"

def display_student(student):
    print(student.name)

student1 = Student()

display_student(student1)
# Out:
# John

# %%
# Storing objects inside a list

class Student:
    pass

student1 = Student()
student2 = Student()
student3 = Student()

students = [student1, student2, student3]

print(students)
# Out:
# [<__main__.Student object at 0x000001AA8B590EC0>, <__main__.Student object at 0x000001AA8B38B9D0>, <__main__.Student object at 0x000001AA8B38BED0>]

# %%
# Creating multiple student objects

class Student:
    school = "ABC School"

student1 = Student()
student2 = Student()
student3 = Student()

student1.name = "John"
student2.name = "Alice"
student3.name = "David"

print(student1.name)
print(student2.name)
print(student3.name)
# Out:
# John
# Alice
# David

# %%
# Creating multiple car objects

class Car:
    wheels = 4

car1 = Car()
car2 = Car()
car3 = Car()

car1.brand = "Toyota"
car2.brand = "Honda"
car3.brand = "BMW"

print(car1.brand)
print(car2.brand)
print(car3.brand)
# Out:
# Toyota
# Honda
# BMW

# %%
# Creating employee objects with different information

class Employee:
    company = "ABC Technologies"

employee1 = Employee()
employee2 = Employee()

employee1.name = "John"
employee1.department = "IT"

employee2.name = "Alice"
employee2.department = "HR"

print(employee1.name, employee1.department)
print(employee2.name, employee2.department)
# Out:
# John IT
# Alice HR

# %%
# Creating an object with attributes and methods

class Student:
    school = "ABC School"

    def study(self):
        print("Student is studying")

student1 = Student()

student1.name = "John"

print(student1.name)
print(student1.school)

student1.study()
# Out:
# John
# ABC School
# Student is studying

# %%
# Understanding the state of an object

class Student:
    pass

student1 = Student()

student1.name = "John"
student1.age = 20
student1.course = "Python"

print(student1.name)
print(student1.age)
print(student1.course)
# Out:
# John
# 20
# Python

# %%
# Changing the state of an object

class Student:
    pass

student1 = Student()

student1.name = "John"
student1.age = 20

print(student1.name)
print(student1.age)

student1.age = 21

print(student1.age)
# Out:
# John
# 20
# 21

# %%
# Deleting an attribute from an object

class Student:
    pass

student1 = Student()

student1.name = "John"
student1.age = 20

del student1.age

print(student1.name)
# Out:
# John

# %%
# Deleting an object reference

class Student:
    pass

student1 = Student()

print(student1)

del student1
# Out:
# <__main__.Student object at 0x000001AA8B590AD0>

# %%
# Demonstrating object references

class Student:
    pass

student1 = Student()
student2 = student1

del student1

print(student2)
# Out:
# <__main__.Student object at 0x000001AA8B590AD0>

# %%
# Distinguishing a class from an object

class Student:
    pass

student1 = Student()

print(type(Student))
print(type(student1))
# Out:
# <class 'type'>
# <class '__main__.Student'>

# %%
# Demonstrating that separate object creations create separate objects

class Student:
    pass

student1 = Student()
student2 = Student()

print(student1 is student2)
# Out:
# False

# %%
# Demonstrating object references during assignment

class Student:
    pass

student1 = Student()
student2 = student1

print(student1 is student2)
# Out:
# True

# %%
# Basic relationship between a class and an object

class Student:
    school = "ABC School"

student1 = Student()

print(
'''
Student"
   ↓
Class / Blueprint

student1
   ↓
Object / Instance
'''
)
# Out:
# Student"
#    ↓
# Class / Blueprint
#
# student1
#    ↓
# Object / Instance

# %%
# Creating multiple objects from one class

class Student:
    school = "ABC School"

student1 = Student()
student2 = Student()
student3 = Student()

print('''
              Student Class
                   │
        ┌──────────┼──────────┐
        ↓          ↓          ↓
    student1    student2    student3
     Object      Object      Object
''')
# Out:
#               Student Class
#                    │
#         ┌──────────┼──────────┐
#         ↓          ↓          ↓
#     student1    student2    student3
#      Object      Object      Object

# %%
# Two variables referring to the same object

student1 = Student()
student2 = student1

print(student1 is student2)

print(student1)
print(student2)
# Out:
# True
# <__main__.Student object at 0x000001AA8B3E27B0>
# <__main__.Student object at 0x000001AA8B3E27B0>
