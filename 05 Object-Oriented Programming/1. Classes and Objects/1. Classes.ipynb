# %% [markdown]
# #### 🏛️ Classes in Python
#
# A **class** is a **blueprint or template** for creating objects in Python. It defines the **attributes (data)** and **methods (functions)** that the objects created from the class will have.
#
# Think of a class as a **design or blueprint**, while an object is the **actual item created from that design**.
#
# Classes are the foundation of **Object-Oriented Programming (OOP)** and help organize code into reusable and maintainable components.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What a class is.
# - Why classes are used.
# - How to create a class.
# - Class syntax.
# - Class attributes and methods.
# - Naming conventions.
# - Practical examples.
# - Common use cases.
# - Common mistakes.
# - Best practices.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# class Student:
#     pass
#
# student1 = Student()
#
# print(type(student1))
# ```
#
# ##### Output
#
# ```text
# <class '__main__.Student'>
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. What is a Class?
#
# A **class** is a user-defined data type that acts as a blueprint for creating objects.
#
# A class defines:
#
# - Attributes (variables)
# - Methods (functions)
# - Behavior of objects
#
# Once a class is created, multiple objects can be created from it.
#
# Example:
#
# ```python
# class Car:
#     pass
# ```
#
# The class `Car` is only a blueprint. No actual car object exists until one is created.
#
# ---
#
# ##### 2. Why Use Classes?
#
# Classes help us:
#
# - Organize code.
# - Reuse code.
# - Model real-world entities.
# - Improve readability.
# - Reduce code duplication.
# - Build scalable applications.
#
# Without classes, managing large applications becomes difficult.
#
# ---
#
# ##### 3. Syntax of a Class
#
# ##### Syntax
#
# ```python
# class ClassName:
#     # Class body
# ```
#
# Example:
#
# ```python
# class Student:
#     pass
# ```
#
# ##### Explanation
#
# - `class` → Keyword used to define a class.
# - `Student` → Class name.
# - `:` → Begins the class body.
# - `pass` → Placeholder indicating an empty class.
#
# ---
#
# ##### 4. Creating a Simple Class
#
# ```python
# class Person:
#     pass
# ```
#
# The class is created successfully, but it currently contains no attributes or methods.
#
# ---
#
# ##### 5. Creating a Class with Attributes
#
# Class attributes are variables defined inside a class.
#
# ```python
# class Car:
#     brand = "Toyota"
#     wheels = 4
# ```
#
# Accessing class attributes:
#
# ```python
# print(Car.brand)
# print(Car.wheels)
# ```
#
# ##### Output
#
# ```text
# Toyota
# 4
# ```
#
# ---
#
# ##### 6. Creating a Class with Methods
#
# Methods define the behavior of a class.
#
# ```python
# class Dog:
#
#     def bark(self):
#         print("Woof!")
# ```
#
# Creating an object:
#
# ```python
# dog = Dog()
#
# dog.bark()
# ```
#
# ##### Output
#
# ```text
# Woof!
# ```
#
# ---
#
# ##### 7. The `self` Parameter
#
# The first parameter of an instance method is usually named `self`.
#
# It refers to the **current object** that calls the method.
#
# Example:
#
# ```python
# class Student:
#
#     def show(self):
#         print("Welcome to Python")
# ```
#
# Creating an object:
#
# ```python
# student = Student()
#
# student.show()
# ```
#
# ##### Output
#
# ```text
# Welcome to Python
# ```
#
# ---
#
# ##### 8. Class Naming Conventions
#
# According to **PEP 8**, class names should use **PascalCase** (also called CapWords).
#
# Good examples:
#
# ```python
# class Student:
#     pass
#
# class BankAccount:
#     pass
#
# class EmployeeDetails:
#     pass
# ```
#
# Avoid:
#
# ```python
# class student:
#     pass
#
# class bank_account:
#     pass
# ```
#
# ---
#
# ##### 9. Empty Classes
#
# Sometimes classes are created before their implementation.
#
# Example:
#
# ```python
# class Library:
#     pass
# ```
#
# This is valid Python syntax.
#
# ---
#
# ##### 10. Practical Examples
#
# ##### Example 1: Student Class
#
# ```python
# class Student:
#
#     college = "ABC College"
#
# print(Student.college)
# ```
#
# ##### Output
#
# ```text
# ABC College
# ```
#
# ---
#
# ##### Example 2: Vehicle Class
#
# ```python
# class Vehicle:
#
#     wheels = 4
#
# print(Vehicle.wheels)
# ```
#
# ##### Output
#
# ```text
# 4
# ```
#
# ---
#
# ##### Example 3: Calculator Class
#
# ```python
# class Calculator:
#
#     def add(self):
#         print(10 + 20)
#
# calc = Calculator()
#
# calc.add()
# ```
#
# ##### Output
#
# ```text
# 30
# ```
#
# ---
#
# ##### Example 4: Greeting Class
#
# ```python
# class Greeting:
#
#     def welcome(self):
#         print("Welcome to Python!")
#
# g = Greeting()
#
# g.welcome()
# ```
#
# ##### Output
#
# ```text
# Welcome to Python!
# ```
#
# ---
#
# ##### 11. Common Use Cases
#
# Classes are commonly used in:
#
# - Student Management Systems
# - Banking Applications
# - Hospital Management Systems
# - E-commerce Applications
# - Inventory Management
# - Library Systems
# - Game Development
# - GUI Applications
# - Web Frameworks
# - Machine Learning Models
#
# ---
#
# ##### 12. Common Mistakes
#
# Avoid these common mistakes while creating classes.
#
# ##### Forgetting Parentheses When Creating an Object
#
# Incorrect
#
# ```python
# class Student:
#     pass
#
# student = Student
# ```
#
# Correct
#
# ```python
# student = Student()
# ```
#
# ---
#
# ##### Forgetting `self` in Methods
#
# Incorrect
#
# ```python
# class Test:
#
#     def display():
#         print("Hello")
# ```
#
# Correct
#
# ```python
# class Test:
#
#     def display(self):
#         print("Hello")
# ```
#
# ---
#
# ##### Incorrect Class Naming
#
# Incorrect
#
# ```python
# class student:
#     pass
# ```
#
# Preferred
#
# ```python
# class Student:
#     pass
# ```
#
# ---
#
# ##### Using a Class Without Creating an Object
#
# Incorrect
#
# ```python
# class Dog:
#
#     def bark(self):
#         print("Woof!")
#
# Dog.bark()
# ```
#
# This raises an error because `bark()` is an instance method.
#
# Correct
#
# ```python
# dog = Dog()
#
# dog.bark()
# ```
#
# ---
#
# ##### 13. Best Practices
#
# Follow these recommended practices when creating classes.
#
# - Use meaningful class names.
# - Follow PascalCase naming conventions.
# - Keep each class focused on a single responsibility.
# - Define methods that represent the behavior of objects.
# - Use `self` correctly in instance methods.
# - Write reusable and modular classes.
# - Add documentation for larger classes.
#
# ---
#
# #### 📊 Summary
#
# | Feature | Description |
# |---------|-------------|
# | Keyword | `class` |
# | Purpose | Defines a blueprint for creating objects |
# | Contains | Attributes and Methods |
# | Naming Style | PascalCase |
# | Object Creation | `object = ClassName()` |
# | Common Uses | Real-world modeling, reusable code, OOP |
#
# ---
#
# > **Note:** A class is the foundation of Object-Oriented Programming in Python. It acts as a blueprint for creating objects, allowing you to organize related data and behavior into reusable, maintainable, and scalable components. Mastering classes is the first step toward understanding advanced OOP concepts such as objects, inheritance, polymorphism, encapsulation, and abstraction.

# %%
# Creating a simple class

class Student:
    pass

# %%
# Creating a class with attributes

class Student:
    name = "John"
    age = 20
    course = "Python"

# %%
# Accessing class attributes

class Student:
    name = "John"
    age = 20
    course = "Python"

print(Student.name)
print(Student.age)
print(Student.course)
# Out:
# John
# 20
# Python

# %%
# Changing a class attribute

class Student:
    course = "Python"

print(Student.course)
Student.course = "Java"

print(Student.course)
# Out:
# Python
# Java

# %%
# Adding a new class attribute

class Student:
    name = "John"

Student.age = 20

print(Student.name)
print(Student.age)
# Out:
# John
# 20

# %%
# Creating a class with a method

class Student:
    school = "ABC School"
    course = "Python"

    def study(self):
        print("Student is studying")

# %%
# Using self to access a class attribute

class Student:
    name = "John"

    def display_name(self):
        print(self.name)

# %%
# Creating a class with multiple attributes and methods

class Car:
    brand = "Toyota"
    wheels = 4
    fuel_type = "Petrol"

    def start(self):
        print("Car started")

    def stop(self):
        print("Car stopped")

# %%
# Creating a class with different types of attributes

class Product:
    name = "Laptop"
    price = 75000
    available = True
    categories = ["Electronics", "Computer"]

# %%
# Creating a practical Student class

class Student:
    name = "John"
    age = 20
    course = "Python"

    def study(self):
        print(self.name, "is studying", self.course)

    def display_details(self):
        print("Name:", self.name)
        print("Age:", self.age)
        print("Course:", self.course)
