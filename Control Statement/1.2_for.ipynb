# %%
#Input : onetwothree
#Output : 1 2 3

a = "onetwothreesixtennine"
num = {'one':1,'two':2,'three':3,'four':4,'five':5,'six':6,'seven':7,'eight':8,'nine':9,'ten':10}
ext = []
for i in num:
    if i in a:
        print(i)
        ext+=[i]
        print(num[i],end=" ")
# Out:
# one
# 1 two
# 2 three
# 3 six
# 6 nine
# 9 ten
# 10

# %%
'nine' in "onetwothreesixtennine"
# Out:
# True

# %%
#Consider Username and password of a user.
#make the user  login only if he/she enters valid username valid username and password
#NOTE: User should enter the password only if the username is correct

# DB={"jen":"7995","ben":"78965","bon":"8974"}

db = {"jen":7995,"ben":78965,"bon":8974}
username = 'oon'
password = 8974

for i in db:
    if i == username and db[i]==password:
        print("Successful login")
        break
else:
    print("Invalid username/passowrd")
# Out:
# Invalid username/passowrd

# %%
#WAP to check whether the entered number is prime number or not

num = 1
for i in range(2,num):
    if i%num==0 or num==1:
        print(f'{num} is not a prime number.')
        break
else:
    print(f'{num} is a prime number.')
# Out:
# 1 is a prime number.

# %%
#a=["jensilin","Aditya","Shakthi"]
#{'jensilin': 3, 'Aditya': 3, 'Shakthi': 2}
#Extract vowels

# %%
#st='Abc8#*$zbE'
#B,c,no,sp=0,0,0,0
#upr,lwr,num,spc='','','',''

#{'AE': 2, 'bczb': 4, '8': 1, '#*$': 3}

# %%
#a="kannadave sathya kanndavuu nithya"
#{'kannadave': 4, 'sathya': 2, 'kanndavuu': 4, 'nithya': 2}
#vowels
