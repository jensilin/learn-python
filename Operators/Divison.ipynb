# %% [markdown]
# <h4>Division Operators</h4>
#
# <p>
# Division operators are used to perform <b>division</b> between numeric operands. Python provides three types of division operators:
# </p>
#
# <ol>
#     <li><b>True Division</b> (<code>/</code>)</li>
#     <li><b>Floor Division</b> (<code>//</code>)</li>
#     <li><b>Modulus</b> (<code>%</code>)</li>
# </ol>

# %% [markdown]
# <h4>a) True Division (<code>/</code>)</h4>
#
# <p>
# The <code>/</code> operator performs <b>true division</b> and returns the <b>exact quotient</b> of the division. The result is always of type <code>float</code>, even if the operands are integers.
# </p>
#
# <h5>Syntax</h5>
#
# ```python
# operand1 / operand2
# ```
#
# <h5>Example</h5>
#
# ```python
# print(10 / 2)
# print(7 / 2)
# print(5 / 2)
# ```
#
# <h5>Output</h5>
#
# ```text
# 5.0
# 3.5
# 2.5
# ```
#
# <h5>Note</h5>
#
# <ul>
#     <li>The result of true division is always a <code>float</code>.</li>
#     <li>Division by <code>0</code> raises a <code>ZeroDivisionError</code>.</li>
# </ul>

# %%
#In Jupyter noter or .ipynb file, without print statement also will work

740/2
# Out:
# 370.0

# %% [markdown]
# <h4>b) Floor Division (<code>//</code>)</h4>
#
# <p>
# The <code>//</code> operator performs <b>floor division</b>. It returns the quotient after <b>discarding the fractional (decimal) part</b> of the result.
# </p>
#
# <h5>Syntax</h5>
#
# ```python
# operand1 // operand2
# ```
#
# <h5>Example</h5>
#
# ```python
# print(10 // 2)
# print(7 // 2)
# print(5 // 2)
# print(-7 // 2)
# ```
#
# <h5>Output</h5>
#
# ```text
# 5
# 3
# 2
# -4
# ```
#
# <h5>Note</h5>
#
# <ul>
#     <li>The <code>//</code> operator returns the <b>floor value</b> (the greatest integer less than or equal to the actual quotient).</li>
#     <li>If either operand is a <code>float</code>, the result is also returned as a <code>float</code>.</li>
#     <li>Division by <code>0</code> raises a <code>ZeroDivisionError</code>.</li>
# </ul>

# %%
750//3
# Out:
# 250

# %% [markdown]
# <h4>c) Modulus (<code>%</code>) Operator</h4>
#
# <p>
# The <code>%</code> operator performs the <b>modulus</b> operation. It returns the <b>remainder</b> after dividing one operand by another.
# </p>
#
# <h5>Syntax</h5>
#
# ```python
# operand1 % operand2
# ```
#
# <h5>Example</h5>
#
# ```python
# print(10 % 3)
# print(20 % 6)
# print(15 % 5)
# ```
#
# <h5>Output</h5>
#
# ```text
# 1
# 2
# 0
# ```
#
# <h5>Note</h5>
#
# <ul>
#     <li>The <code>%</code> operator returns the <b>remainder</b> of the division.</li>
#     <li>If the dividend is exactly divisible by the divisor, the result is <code>0</code>.</li>
#     <li>Division by <code>0</code> raises a <code>ZeroDivisionError</code>.</li>
# </ul>

# %%
37 % 4
# Out:
# 1

# %% [markdown]
# <h5>Note</h5>
#
# <ul>
#     <li>None of the division operators (<code>/</code>, <code>//</code>, and <code>%</code>) support <b>collection data types</b> such as strings, lists, tuples, sets, or dictionaries.</li>
#     <li>The <code>//</code> (floor division) and <code>%</code> (modulus) operators do <b>not</b> support <code>complex</code> numbers.</li>
#     <li>The <code>/</code> (true division) operator supports <code>complex</code> numbers.</li>
# </ul>

# %%
#Not supported for strings

'Jensilin' / 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 #Not supported for strings
#       2
# ----> 3 'Jensilin' / 2
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
3+4j / 4+4j
# Out:
# (3+5j)

# %%
True / True
# Out:
# 1.0
