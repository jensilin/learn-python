# %% [markdown]
# #### 🔢 Integer (`int`) Data Type
#
# The **Integer (`int`)** data type is one of Python's fundamental numeric data types. It is used to represent **whole numbers** without any decimal or fractional part. Integer values can be **positive**, **negative**, or **zero**, making them suitable for a wide variety of mathematical and logical operations.
#
# Python integers are **immutable**, meaning their value cannot be modified after creation. Unlike many programming languages, Python supports integers of **unlimited precision**, allowing you to work with very large numbers without worrying about overflow (limited only by the available system memory).
#
# Integers are commonly used in counting, indexing, mathematical computations, loop control, and many real-world applications where decimal values are not required.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Integer (`int`) data type is.
# - The characteristics and features of integers.
# - Different ways to create integer objects.
# - Positive, negative, and zero values.
# - Arithmetic and mathematical operations supported by integers.
# - Type conversion using the `int()` function.
# - Useful built-in functions related to integers.
# - Practical programming examples.
# - Common real-world applications of integers.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# age = 22
# temperature = -10
# count = 100
# marks = 0
#
# print(age)
# print(temperature)
# print(count)
# print(type(age))
# ```
#
# ##### Output
#
# ```text
# 22
# -10
# 100
# <class 'int'>
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Integer (`int`) Data Type
#
# Learn what an integer is, why it is one of Python's built-in numeric data types, and how it is used to represent whole numbers without any decimal or fractional part.
#
# **Example**
#
# ```python
# age = 21
# marks = 95
#
# print(age)
# print(marks)
# ```
#
# **Output**
#
# ```text
# 21
# 95
# ```
#
# ---
#
# ##### 2. Characteristics of Integers
#
# Explore the important characteristics of the `int` data type.
#
# ##### Characteristics
#
# - Stores whole numbers only.
# - Supports positive, negative, and zero values.
# - Immutable data type.
# - Unlimited precision (limited only by available memory).
# - Supports arithmetic, relational, logical, and bitwise operations.
#
# **Example**
#
# ```python
# num = 100
#
# print(type(num))
# ```
#
# **Output**
#
# ```text
# <class 'int'>
# ```
#
# ---
#
# ##### 3. Creating Integer Objects
#
# Learn different ways to create integer objects in Python.
#
# ##### Topics Covered
#
# - Direct assignment
# - Using the `int()` constructor
# - Type conversion from other data types
# - Creating integers from different number systems
#
# **Example**
#
# ```python
# a = 100
# b = int(25.8)
# c = int(True)
#
# print(a)
# print(b)
# print(c)
# ```
#
# **Output**
#
# ```text
# 100
# 25
# 1
# ```
#
# ---
#
# ##### 4. Positive, Negative, and Zero Values
#
# Understand how integers can represent positive, negative, and zero values.
#
# **Example**
#
# ```python
# positive = 50
# negative = -20
# zero = 0
#
# print(positive)
# print(negative)
# print(zero)
# ```
#
# **Output**
#
# ```text
# 50
# -20
# 0
# ```
#
# ---
#
# ##### 5. Integer Operations
#
# Learn the arithmetic operations supported by integers.
#
# ##### Operations Covered
#
# - Addition
# - Subtraction
# - Multiplication
# - Division
# - Floor Division
# - Modulus
# - Exponentiation
#
# **Example**
#
# ```python
# a = 12
# b = 5
#
# print(a + b)
# print(a - b)
# print(a * b)
# print(a // b)
# print(a % b)
# print(a ** 2)
# ```
#
# **Output**
#
# ```text
# 17
# 7
# 60
# 2
# 2
# 144
# ```
#
# ---
#
# ##### 6. Arithmetic with Integers
#
# Understand how Python evaluates arithmetic expressions involving integers.
#
# ##### Topics Covered
#
# - Expression evaluation
# - Operator precedence
# - Mixed arithmetic operations
#
# **Example**
#
# ```python
# result = 10 + 5 * 2
#
# print(result)
# ```
#
# **Output**
#
# ```text
# 20
# ```
#
# ---
#
# ##### 7. Type Conversion
#
# Learn how to convert other data types into integers.
#
# ##### Topics Covered
#
# - `int()`
# - Float to Integer
# - Boolean to Integer
# - String to Integer
# - Invalid conversions
#
# **Example**
#
# ```python
# print(int(10.9))
# print(int("25"))
# print(int(False))
# ```
#
# **Output**
#
# ```text
# 10
# 25
# 0
# ```
#
# ---
#
# ##### 8. Built-in Functions
#
# Explore useful built-in functions that work with integers.
#
# ##### Functions Covered
#
# - `int()`
# - `abs()`
# - `pow()`
# - `bin()`
# - `oct()`
# - `hex()`
# - `divmod()`
#
# **Example**
#
# ```python
# print(abs(-15))
# print(pow(2, 5))
# print(bin(10))
# ```
#
# **Output**
#
# ```text
# 15
# 32
# 0b1010
# ```
#
# ---
#
# ##### 9. Practical Examples
#
# Apply integer concepts through real-world programming examples.
#
# Examples include:
#
# - Mathematical calculations
# - Counting values
# - User input
# - Billing systems
# - Inventory calculations
#
# ---
#
# ##### 10. Common Use Cases
#
# Understand where integers are commonly used in software development.
#
# Examples include:
#
# - Counting objects
# - Loop counters
# - Array and list indexing
# - Age calculation
# - Product quantities
# - Marks and scores
# - IDs
# - Menu selections
#
# **Example**
#
# ```python
# students = 45
# product_id = 1001
# score = 98
#
# print(students)
# print(product_id)
# print(score)
# ```
#
# **Output**
#
# ```text
# 45
# 1001
# 98
# ```
#
# ---
#
# > **Note:** This notebook focuses exclusively on the **Integer (`int`)** data type. By the end of this notebook, you will have a solid understanding of how integers are created, manipulated, and used in real-world Python applications.

# %%
#Creating Integer Variables
age = 23
experience = 2

print(age)
print(experience)
# Out:
# 23
# 2

# %%
#Checking the Data Type

b = 20
print(type(b))
# Out:
# <class 'int'>

# %%
#Positive, Negative, and Zero

positive = 25
negative = -10
zero = 0

print(positive)
print(negative)
print(zero)
# Out:
# 25
# -10
# 0

# %%
#Converting Float to Integer

n1 = 20.654
res = int(n1)

print(n1 , type(n1))
print(res , type(res))
# Out:
# 20.654 <class 'float'>
# 20 <class 'int'>

# %%
#Addition
a = 10
b = 20

print(a + b)
# Out:
# 30

# %%
#Subtraction
a = 785
b = 69

print(a - b)
# Out:
# 716

# %%
#Multiplication
a = 10
b = 208

print(a * b)
# Out:
# 2080

# %%
#Division
a = 100
b = 20

print(a / b)
# Out:
# 5.0

# %%
#Floor Division
a = 1087
b = 20

print(a // b)
# Out:
# 54

# %%
#Modulus
a = 1045
b = 20565

print(a % b)
# Out:
# 1045

# %%
#Exponentiation
a = 619

print(a ** 2)
print(a ** 3)
# Out:
# 383161
# 237176659

# %%
#Absolute Value
n = -100

print(abs(n))
# Out:
# 100

# %%
#Comparison Operators
a = 15
b = 20

print(a > b)
print(a < b)
print(a == b)
print(a != b)
# Out:
# False
# True
# False
# True

# %%
#Large Integers

population = 9876543546565756

print(population)
# Out:
# 9876543546565756

# %%
#Using Underscores for Readability
distance = 384_487
salary = 10_50_000

print(distance)
print(salary)
# Out:
# 384487
# 1050000

# %%
#Integer with User Input
age = int(input("Enter your age: "))

print(age)
# Out:
# 23

# %%
#Integer Arithmetic
a = 25
b = 10

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)
print("Modulus:", a % b)
print("Power:", a ** b)
# Out:
# Addition: 35
# Subtraction: 15
# Multiplication: 250
# Division: 2.5
# Floor Division: 2
# Modulus: 5
# Power: 95367431640625

# %%
#Finding Even or Odd
number = 18

print(number % 2 == 0)
# Out:
# True

# %%
#Swapping Two Numbers
a = 10
b = 20

a, b = b, a

print(a)
print(b)
# Out:
# 20
# 10

# %%
#Finding Maximum

a = 15
b = 25

print(max(a, b))
# Out:
# 25

# %%
#Finding Minimum
a = 15
b = 25

print(min(a, b))
# Out:
# 15

# %%
#Integer in Different Number Systems
decimal = 10
binary = 0b1010
octal = 0o12
hexadecimal = 0xA

print(decimal)
print(binary)
print(octal)
print(hexadecimal)
# Out:
# 10
# 10
# 10
# 10

# %%
#Integer Base Conversion
number = 25

print(bin(number))
print(oct(number))
print(hex(number))
# Out:
# 0b11001
# 0o31
# 0x19

# %%
#Real-world Example
price = 250
quantity = 4

total = price * quantity

print(total)
# Out:
# 1000
