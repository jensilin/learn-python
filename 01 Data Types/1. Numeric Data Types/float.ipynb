# %% [markdown]
# #### 🌊 Floating Point (`float`) Data Type
#
# The **Floating Point (`float`)** data type is one of Python's built-in numeric data types. It is used to represent **decimal (fractional) numbers**. A float can store both positive and negative decimal values, making it suitable for mathematical calculations that require precision.
#
# Python stores floating-point numbers using the **IEEE 754 double-precision format**, which provides approximately **15 to 17 significant decimal digits** of precision. Float values are immutable, meaning their value cannot be modified after creation.
#
# Floating-point numbers are commonly used in scientific calculations, measurements, financial applications, statistical analysis, and any scenario where decimal values are required.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Floating Point (`float`) data type is.
# - The characteristics and features of float values.
# - Different ways to create float objects.
# - Positive, negative, and zero decimal values.
# - Arithmetic operations supported by floats.
# - Type conversion using the `float()` function.
# - Useful built-in functions related to floats.
# - Practical programming examples.
# - Common real-world applications of floating-point numbers.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# price = 499.99
# temperature = -12.5
# pi = 3.14159
# discount = 0.0
#
# print(price)
# print(temperature)
# print(pi)
# print(type(price))
# ```
#
# ##### Output
#
# ```text
# 499.99
# -12.5
# 3.14159
# <class 'float'>
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Floating Point (`float`) Data Type
#
# Learn what a floating-point number is, why Python provides the `float` data type, and how it is used to represent decimal numbers.
#
# **Example**
#
# ```python
# height = 172.5
# weight = 65.8
#
# print(height)
# print(weight)
# ```
#
# **Output**
#
# ```text
# 172.5
# 65.8
# ```
#
# ---
#
# ##### 2. Characteristics of Floating Point Numbers
#
# Explore the important characteristics of the `float` data type.
#
# ##### Characteristics
#
# - Stores decimal (fractional) numbers.
# - Supports positive, negative, and zero values.
# - Immutable data type.
# - Uses IEEE 754 double-precision representation.
# - Supports arithmetic, relational, and logical operations.
#
# **Example**
#
# ```python
# num = 25.75
#
# print(type(num))
# ```
#
# **Output**
#
# ```text
# <class 'float'>
# ```
#
# ---
#
# ##### 3. Creating Float Objects
#
# Learn different ways to create floating-point objects in Python.
#
# ##### Topics Covered
#
# - Direct assignment
# - Using the `float()` constructor
# - Type conversion from integers
# - Creating float values from numeric strings
#
# **Example**
#
# ```python
# a = 25.5
# b = float(100)
# c = float("45.75")
#
# print(a)
# print(b)
# print(c)
# ```
#
# **Output**
#
# ```text
# 25.5
# 100.0
# 45.75
# ```
#
# ---
#
# ##### 4. Positive, Negative, and Zero Decimal Values
#
# Understand how Python represents decimal values.
#
# **Example**
#
# ```python
# positive = 15.75
# negative = -8.5
# zero = 0.0
#
# print(positive)
# print(negative)
# print(zero)
# ```
#
# **Output**
#
# ```text
# 15.75
# -8.5
# 0.0
# ```
#
# ---
#
# ##### 5. Floating Point Operations
#
# Learn the arithmetic operations supported by floating-point numbers.
#
# ##### Operations Covered
#
# - Addition
# - Subtraction
# - Multiplication
# - Division
# - Floor Division
# - Modulus
# - Exponentiation
#
# **Example**
#
# ```python
# a = 12.5
# b = 2.5
#
# print(a + b)
# print(a - b)
# print(a * b)
# print(a / b)
# print(a // b)
# print(a % b)
# print(a ** 2)
# ```
#
# **Output**
#
# ```text
# 15.0
# 10.0
# 31.25
# 5.0
# 5.0
# 0.0
# 156.25
# ```
#
# ---
#
# ##### 6. Arithmetic with Floating Point Numbers
#
# Understand how Python evaluates arithmetic expressions involving decimal values.
#
# ##### Topics Covered
#
# - Expression evaluation
# - Operator precedence
# - Mixed arithmetic operations
#
# **Example**
#
# ```python
# result = 10.5 + 5 * 2
#
# print(result)
# ```
#
# **Output**
#
# ```text
# 20.5
# ```
#
# ---
#
# ##### 7. Type Conversion
#
# Learn how to convert different data types into floating-point numbers.
#
# ##### Topics Covered
#
# - Using `float()`
# - Integer to Float
# - Boolean to Float
# - Numeric String to Float
# - Invalid conversions
#
# **Example**
#
# ```python
# print(float(25))
# print(float(True))
# print(float("12.75"))
# ```
#
# **Output**
#
# ```text
# 25.0
# 1.0
# 12.75
# ```
#
# ---
#
# ##### 8. Built-in Functions
#
# Explore useful built-in functions that work with floating-point values.
#
# ##### Functions Covered
#
# - `float()`
# - `abs()`
# - `round()`
# - `pow()`
# - `min()`
# - `max()`
#
# **Example**
#
# ```python
# print(round(15.6789, 2))
# print(abs(-12.75))
# print(pow(2.5, 2))
# ```
#
# **Output**
#
# ```text
# 15.68
# 12.75
# 6.25
# ```
#
# ---
#
# ##### 9. Practical Examples
#
# Apply floating-point concepts through practical programming examples.
#
# Examples include:
#
# - Price calculations
# - Percentage calculations
# - Temperature conversion
# - Scientific computations
# - Average calculations
#
# ---
#
# ##### 10. Common Use Cases
#
# Understand where floating-point numbers are commonly used in software development.
#
# Examples include:
#
# - Product prices
# - Height and weight
# - Temperature values
# - Distance measurements
# - Scientific calculations
# - Percentage calculations
# - Financial applications
# - Statistical analysis
#
# **Example**
#
# ```python
# price = 2499.99
# gst = 18.5
# height = 175.8
#
# print(price)
# print(gst)
# print(height)
# ```
#
# **Output**
#
# ```text
# 2499.99
# 18.5
# 175.8
# ```
#
# ---
#
# > **Note:** This notebook focuses exclusively on the **Floating Point (`float`)** data type. By the end of this notebook, you will have a solid understanding of how floating-point numbers are created, manipulated, and used in real-world Python applications.

# %%
#Creating Float Variables
price = 99.50
temperature = 36.5

print(price)
print(temperature)
# Out:
# 99.5
# 36.5

# %%
#Checking the Data Type
value = 68.5

print(type(value))
# Out:
# <class 'float'>

# %%
#Converting Integer to Float

num = 18

res = float(num)
print(res)
# Out:
# 18.0

# %%
#Converting String to Float

n = "25.9"
r = float(n)

print(r)
print(type(r))
# Out:
# 25.9
# <class 'float'>

# %%
#Addition
n1 = 45
n2 = 89

print(n1 + n2)
# Out:
# 134

# %%
#Subtraction
n1 = 45
n2 = 89

print(n1 - n2)
# Out:
# -44

# %%
#Multiplication
n1 = 45
n2 = 89

print(n1 * n2)
# Out:
# 4005

# %%
#Division
n1 = 45
n2 = 89

print(n1 / n2)
# Out:
# 0.5056179775280899

# %%
#Floor Division
n1 = 450
n2 = 4

print(n1 // n2)
# Out:
# 112

# %%
#Modulus
n1 = 450
n2 = 4

print(n1 % n2)
# Out:
# 2

# %%
#Power
a = 5

print(a**2)
# Out:
# 25

# %%
#Rounding a Float

n = 4.239498

print(round(n))
print(round(n,1))
print(round(n,3))
# Out:
# 4
# 4.2
# 4.239

# %%
#Absolute Value

n = 4.239498

print(abs(n))
# Out:
# 4.239498

# %%
#Float Comparison
a = 10.5
b = 20.5

print(a < b)
print(a > b)
print(a == b)
# Out:
# True
# False
# False

# %%
#Scientific Notation
num1 = 1.5e3
num2 = 2.5e-2

print(num1)
print(num2)
# Out:
# 1500.0
# 0.025

# %%
#Float with User Input
fl = float(input("Enter the float number : "))

print(fl)
# Out:
# 45.576

# %%
#Average of Three Numbers

a = 10.554
b = 780.5
c = 30.864

average = (a + b + c) / 3

print(average)
# Out:
# 273.97266666666667

# %%
#Simple Interest Calculation
principal = 1000.0
rate = 5.5
time = 2

simple_interest = (principal * rate * time) / 100

print(simple_interest)
# Out:
# 110.0

# %%
#Area of a Circle
radius = 7.5

area = 3.14159 * radius ** 2

print(area)
# Out:
# 176.7144375

# %%
#Float Precision

print(0.1 + 0.2)
print(0.3)
# Out:
# 0.30000000000000004
# 0.3

# %%
#Formatting Float Values

pi = 3.1415926535

print(f"{pi:.2f}")
print(f"{pi:.4f}")
print(f"{pi:.6f}")
# Out:
# 3.14
# 3.1416
# 3.141593
