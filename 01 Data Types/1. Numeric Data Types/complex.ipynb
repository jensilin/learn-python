# %% [markdown]
# #### 🧮 Complex (`complex`) Data Type
#
# The **Complex (`complex`)** data type is one of Python's built-in numeric data types. It is used to represent **complex numbers**, which consist of a **real part** and an **imaginary part**. In Python, the imaginary part is represented using the suffix **`j`**.
#
# Complex numbers are immutable and support various arithmetic operations such as addition, subtraction, multiplication, and division. They are commonly used in scientific computing, electrical engineering, signal processing, and mathematical modeling.
#
# Unlike `int` and `float`, complex numbers cannot be compared using relational operators such as `<`, `>`, `<=`, and `>=`.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Complex (`complex`) data type is.
# - The characteristics and features of complex numbers.
# - Different ways to create complex objects.
# - Real and imaginary parts.
# - Arithmetic operations supported by complex numbers.
# - Type conversion using the `complex()` function.
# - Useful built-in attributes and functions.
# - Practical programming examples.
# - Common real-world applications of complex numbers.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# z1 = 4 + 3j
# z2 = complex(2, 5)
#
# print(z1)
# print(z2)
# print(type(z1))
# ```
#
# ##### Output
#
# ```text
# (4+3j)
# (2+5j)
# <class 'complex'>
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Complex (`complex`) Data Type
#
# Learn what a complex number is, why Python provides the `complex` data type, and how it is used to represent numbers containing both real and imaginary parts.
#
# **Example**
#
# ```python
# z = 5 + 2j
#
# print(z)
# ```
#
# **Output**
#
# ```text
# (5+2j)
# ```
#
# ---
#
# ##### 2. Characteristics of Complex Numbers
#
# Explore the important characteristics of the `complex` data type.
#
# ##### Characteristics
#
# - Stores real and imaginary values.
# - Imaginary part is represented using `j`.
# - Immutable data type.
# - Supports arithmetic operations.
# - Does not support relational comparisons (`<`, `>`, `<=`, `>=`).
#
# **Example**
#
# ```python
# num = 10 + 4j
#
# print(type(num))
# ```
#
# **Output**
#
# ```text
# <class 'complex'>
# ```
#
# ---
#
# ##### 3. Creating Complex Objects
#
# Learn different ways to create complex objects in Python.
#
# ##### Topics Covered
#
# - Direct assignment
# - Using the `complex()` constructor
# - Creating complex numbers from integers
# - Creating complex numbers from floats
#
# **Example**
#
# ```python
# a = 4 + 8j
# b = complex(2, 6)
# c = complex(3.5, 4.2)
#
# print(a)
# print(b)
# print(c)
# ```
#
# **Output**
#
# ```text
# (4+8j)
# (2+6j)
# (3.5+4.2j)
# ```
#
# ---
#
# ##### 4. Real and Imaginary Parts
#
# Understand the components of a complex number.
#
# ##### Topics Covered
#
# - Real part
# - Imaginary part
# - Accessing `.real`
# - Accessing `.imag`
#
# **Example**
#
# ```python
# z = 8 + 5j
#
# print(z.real)
# print(z.imag)
# ```
#
# **Output**
#
# ```text
# 8.0
# 5.0
# ```
#
# ---
#
# ##### 5. Complex Number Operations
#
# Learn the arithmetic operations supported by complex numbers.
#
# ##### Operations Covered
#
# - Addition
# - Subtraction
# - Multiplication
# - Division
# - Exponentiation
#
# **Example**
#
# ```python
# a = 2 + 3j
# b = 1 + 2j
#
# print(a + b)
# print(a - b)
# print(a * b)
# print(a / b)
# print(a ** 2)
# ```
#
# **Output**
#
# ```text
# (3+5j)
# (1+1j)
# (-4+7j)
# (1.6-0.2j)
# (-5+12j)
# ```
#
# ---
#
# ##### 6. Arithmetic with Complex Numbers
#
# Understand how Python performs arithmetic calculations using complex numbers.
#
# ##### Topics Covered
#
# - Expression evaluation
# - Mixed arithmetic operations
# - Complex arithmetic examples
#
# **Example**
#
# ```python
# result = (2 + 3j) * 4
#
# print(result)
# ```
#
# **Output**
#
# ```text
# (8+12j)
# ```
#
# ---
#
# ##### 7. Type Conversion
#
# Learn how to create complex numbers using the `complex()` function.
#
# ##### Topics Covered
#
# - Integer to Complex
# - Float to Complex
# - Using `complex(real, imag)`
#
# **Example**
#
# ```python
# print(complex(10))
# print(complex(5.5))
# print(complex(3, 7))
# ```
#
# **Output**
#
# ```text
# (10+0j)
# (5.5+0j)
# (3+7j)
# ```
#
# ---
#
# ##### 8. Built-in Attributes and Functions
#
# Explore useful attributes and functions available for complex numbers.
#
# ##### Functions and Attributes Covered
#
# - `complex()`
# - `.real`
# - `.imag`
# - `abs()`
#
# **Example**
#
# ```python
# z = 3 + 4j
#
# print(z.real)
# print(z.imag)
# print(abs(z))
# ```
#
# **Output**
#
# ```text
# 3.0
# 4.0
# 5.0
# ```
#
# ---
#
# ##### 9. Practical Examples
#
# Apply complex number concepts through practical programming examples.
#
# Examples include:
#
# - Electrical circuit calculations
# - Signal processing
# - Mathematical computations
# - Engineering calculations
#
# ---
#
# ##### 10. Common Use Cases
#
# Understand where complex numbers are commonly used.
#
# Examples include:
#
# - Electrical Engineering
# - Signal Processing
# - Control Systems
# - Scientific Computing
# - Mathematical Modeling
# - Physics Simulations
#
# **Example**
#
# ```python
# voltage = 230 + 15j
#
# print(voltage)
# print(type(voltage))
# ```
#
# **Output**
#
# ```text
# (230+15j)
# <class 'complex'>
# ```
#
# ---
#
# > **Note:** This notebook focuses exclusively on the **Complex (`complex`)** data type. By the end of this notebook, you will have a solid understanding of how complex numbers are created, manipulated, and applied in scientific and engineering applications.

# %%
#Creating Complex Numbers
num1 = 2+3j
num2 = 3+5j

print(num1+num2)
# Out:
# (5+8j)

# %%
#Checking the Data Type
num = 5+2j
print(type(num))
# Out:
# <class 'complex'>

# %%
#Using complex()

n=complex(7,9)
print(n)
# Out:
# (7+9j)

# %%
#Real Part
a = 3+44j
print(a.real)
# Out:
# 3.0

# %%
#Imaginary Part
b = 9+69j
print(b.imag)
# Out:
# 69.0

# %%
#Addition

print((3+2j) + (6+50j))
# Out:
# (9+52j)

# %%
#Subtraction

print((3+268j) - (6+50j))
# Out:
# (-3+218j)

# %%
#Multiplication

print((3+200j) * (6+50j))
# Out:
# (-9982+1350j)

# %%
#Division

print((3+2j) / (6+50j))
# Out:
# (0.04652996845425867-0.054416403785488954j)

# %%
#Absolute Value (Magnitude)
v = 2+3j
print(abs(v))
# Out:
# 3.605551275463989

# %%
#Complex Conjugate
num = 87+6j
print(num.conjugate())
# Out:
# (87-6j)

# %%
#Equality Comparison
a = 3 + 4j
b = 3 + 4j

print(a == b)
# Out:
# True

# %%
#Accessing Real and Imaginary Parts

np = 2+9j

print(f'Real: {np.real}')
print(f'Imaginary: {np.imag}')
# Out:
# Real: 2.0
# Imaginary: 9.0

# %%
#Arithmetic Operations Together

a = 2 + 3j
b = 4 + 1j

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
# Out:
# Addition: (6+4j)
# Subtraction: (-2+2j)
# Multiplication: (5+14j)
# Division: (0.6470588235294118+0.5882352941176471j)

# %%
#Using Variables

real = 7
imaginary = 9

num = complex(real, imaginary)

print(num)
# Out:
# (7+9j)

# %%
#Type Conversion

q = complex(99)
print(q)
# Out:
# (99+0j)

# %%
#Complex Number in Expressions

x = 1 + 2j

result = x * 2
print(result)
# Out:
# (2+4j)

# %%
#Simple Example

voltage = 230 + 15j

print(voltage)
print(voltage.real)
print(voltage.imag)
# Out:
# (230+15j)
# 230.0
# 15.0
