# %% [markdown]
# #### 💾 Bytearray (`bytearray`) Data Type
#
# The **`bytearray`** data type is one of Python's built-in **binary data types** used to store a sequence of **bytes** (integers ranging from **0 to 255**).
#
# Unlike the `bytes` data type, a `bytearray` is **mutable**, meaning its contents can be modified after creation. This makes it suitable for applications where binary data needs to be updated efficiently, such as file manipulation, network communication, image processing, and data buffering.
#
# The `bytearray` data type combines the efficiency of binary data storage with the flexibility of mutable objects.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the `bytearray` data type is.
# - Characteristics of `bytearray`.
# - Different ways to create bytearray objects.
# - Accessing bytearray elements.
# - Bytearray operations.
# - Built-in bytearray methods.
# - Type conversion using `bytearray()`.
# - Practical programming examples.
# - Common real-world applications.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# data = bytearray(b"Python")
#
# print(data)
# print(type(data))
# ```
#
# ##### Output
#
# ```text
# bytearray(b'Python')
# <class 'bytearray'>
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the `bytearray` Data Type
#
# Learn what the `bytearray` data type is and why it is used when binary data needs to be modified.
#
# **Example**
#
# ```python
# data = bytearray(b"Hello")
#
# print(data)
# ```
#
# ##### Output
#
# ```text
# bytearray(b'Hello')
# ```
#
# ---
#
# ##### 2. Characteristics of `bytearray`
#
# Explore the important characteristics of the `bytearray` data type.
#
# ##### Characteristics
#
# - Stores binary data.
# - Mutable.
# - Ordered collection.
# - Supports indexing and slicing.
# - Stores integer values from **0 to 255**.
# - Efficient for modifying binary data.
# - Supports most bytes methods.
#
# **Example**
#
# ```python
# data = bytearray(b"ABC")
#
# print(type(data))
# ```
#
# ##### Output
#
# ```text
# <class 'bytearray'>
# ```
#
# ---
#
# ##### 3. Creating Bytearray Objects
#
# Learn different ways to create `bytearray` objects.
#
# ##### Topics Covered
#
# - From bytes
# - Using the `bytearray()` constructor
# - From a list of integers
# - From a string using encoding
#
# **Example**
#
# ```python
# a = bytearray(b"Python")
#
# b = bytearray([80, 121, 116, 104, 111, 110])
#
# c = bytearray("Hello", "utf-8")
#
# print(a)
# print(b)
# print(c)
# ```
#
# ##### Output
#
# ```text
# bytearray(b'Python')
# bytearray(b'Python')
# bytearray(b'Hello')
# ```
#
# ---
#
# ##### 4. Accessing Bytearray Elements
#
# Learn how to access individual bytes.
#
# ##### Topics Covered
#
# - Indexing
# - Negative indexing
# - Slicing
#
# **Example**
#
# ```python
# data = bytearray(b"Python")
#
# print(data[0])
# print(data[-1])
# print(data[1:4])
# ```
#
# ##### Output
#
# ```text
# 80
# 110
# bytearray(b'yth')
# ```
#
# ---
#
# ##### 5. Bytearray Operations
#
# Learn the common operations supported by `bytearray`.
#
# ##### Operations Covered
#
# - Indexing
# - Slicing
# - Concatenation
# - Repetition
# - Membership (`in`, `not in`)
# - Length (`len()`)
# - Updating elements
#
# **Example**
#
# ```python
# data = bytearray(b"Python")
#
# data[0] = ord("J")
#
# print(data)
# ```
#
# ##### Output
#
# ```text
# bytearray(b'Jython')
# ```
#
# ---
#
# ##### 6. Built-in Bytearray Methods
#
# Learn the commonly used methods available for bytearray objects.
#
# ##### Methods Covered
#
# - `append()`
# - `extend()`
# - `insert()`
# - `remove()`
# - `pop()`
# - `clear()`
# - `copy()`
# - `count()`
# - `find()`
# - `index()`
# - `replace()`
# - `split()`
# - `join()`
# - `reverse()`
# - `decode()`
# - `strip()`
#
# **Example**
#
# ```python
# data = bytearray(b"python")
#
# data.append(33)
#
# print(data)
# ```
#
# ##### Output
#
# ```text
# bytearray(b'python!')
# ```
#
# ---
#
# ##### 7. Type Conversion
#
# Learn how to create bytearray objects using the `bytearray()` constructor.
#
# ##### Topics Covered
#
# - Bytes to bytearray
# - List to bytearray
# - String to bytearray
#
# **Example**
#
# ```python
# numbers = [65, 66, 67]
#
# print(bytearray(numbers))
# ```
#
# ##### Output
#
# ```text
# bytearray(b'ABC')
# ```
#
# ---
#
# ##### 8. Practical Examples
#
# Apply bytearray concepts through practical programming examples.
#
# Examples include:
#
# - Binary file editing
# - Data buffering
# - Network packet modification
# - Image processing
# - Binary protocol implementation
#
# ---
#
# ##### 9. Common Use Cases
#
# Understand where the `bytearray` data type is commonly used.
#
# Examples include:
#
# - Binary file modification
# - Network programming
# - Streaming data
# - Cryptography
# - Image and multimedia processing
# - Embedded systems
#
# **Example**
#
# ```python
# packet = bytearray(b"DATA")
#
# packet[0] = ord("M")
#
# print(packet)
# ```
#
# ##### Output
#
# ```text
# bytearray(b'MATA')
# ```
#
# ---
#
# ##### 10. Limitations of `bytearray`
#
# Understand the limitations of the `bytearray` data type.
#
# ##### Limitations
#
# - Stores only values from **0 to 255**.
# - Uses more memory than immutable `bytes` objects.
# - Requires encoding and decoding when working with text.
# - Not suitable when immutable binary data is required.
#
# ---
#
# ##### 11. Bytearray Methods (Detailed Study)
#
# This section provides a detailed explanation of Python's built-in bytearray methods with syntax, examples, outputs, and real-world use cases.
#
# Methods include:
#
# - `append()`
# - `extend()`
# - `insert()`
# - `remove()`
# - `pop()`
# - `clear()`
# - `copy()`
# - `count()`
# - `find()`
# - `index()`
# - `replace()`
# - `split()`
# - `join()`
# - `reverse()`
# - `decode()`
# - `strip()`
#
# ---
#
# > **Note:** This notebook focuses on the **`bytearray`** data type. By the end of this notebook, you will understand how to create, modify, and manipulate mutable binary data efficiently, making it useful for applications involving binary file editing, networking, and low-level data processing.

# %%
# Creating a Bytearray

data = bytearray([65, 66, 67])
print(data)
# Out:
# bytearray(b'ABC')

# %%
# String to Bytearray

text = "Python"

data = bytearray(text, "utf-8")
print(data)
# Out:
# bytearray(b'Python')

# %%
# Bytes to Bytearray

data = bytes([65, 66, 67])
result = bytearray(data)
print(result)
# Out:
# bytearray(b'ABC')

# %%
# Empty Bytearray

data = bytearray()
print(data)
print(type(data))
# Out:
# bytearray(b'')
# <class 'bytearray'>

# %%
# Bytearray with Numbers

data = bytearray([10, 20, 30, 40, 50])
print(data)
# Out:
# bytearray(b'\n\x14\x1e(2')

# %%
# Accessing Elements

data = bytearray([65, 66, 67])
print(data[0])
print(data[1])
print(data[2])
# Out:
# 65
# 66
# 67

# %%
# Bytearray Indexing

data = bytearray([10, 20, 30, 40])
print(data[0])
print(data[-1])
# Out:
# 10
# 40

# %%
# Bytearray Slicing

data = bytearray([10, 20, 30, 40, 50])
print(data[1:4])
# Out:
# bytearray(b'\x14\x1e(')

# %%
# Modifying Bytearray

data = bytearray([65, 66, 67])
data[0] = 90
print(data)
# Out:
# bytearray(b'ZBC')

# %%
# Adding an Element

data = bytearray([65, 66, 67])
data.append(68)
print(data)
# Out:
# bytearray(b'ABCD')

# %%
# Removing an Element

data = bytearray([65, 66, 67, 68])
data.remove(67)
print(data)
# Out:
# bytearray(b'ABD')

# %%
# Length

data = bytearray([65, 66, 67, 68])
print(len(data))
# Out:
# 4

# %%
# Checking Membership

data = bytearray([65, 66, 67])
print(65 in data)
print(90 in data)
# Out:
# True
# False

# %%
# Bytearray with for loop

data = bytearray([65, 66, 67])
for value in data:
    print(value)
# Out:
# 65
# 66
# 67

# %%
# Bytearray to String

data = bytearray(b"Python")
text = data.decode("utf-8")
print(text)
# Out:
# Python

# %%
# Bytearray to Bytes

data = bytearray([65, 66, 67])
result = bytes(data)
print(result)
# Out:
# b'ABC'

# %%
# Bytearray vs Bytes

data1 = bytes([65, 66, 67])
data2 = bytearray([65, 66, 67])
print(data1)
print(data2)
# Out:
# b'ABC'
# bytearray(b'ABC')

# %%
# Bytes cannot be modified

data = bytes([65, 66, 67])
# data[0] = 90

# %%
# Bytearray can be modified

data = bytearray([65, 66, 67])
data[0] = 90
print(data)
# Out:
# bytearray(b'ZBC')
