# %% [markdown]
# #### 🚫 NoneType (`NoneType`) Data Type
#
# The **`NoneType`** is Python's built-in **special data type** that represents the **absence of a value**. It has only one possible value: **`None`**.
#
# The `None` value is commonly used to indicate that a variable has no value assigned, a function does not return a result, or an object is intentionally empty. Unlike `0`, `False`, or an empty string (`""`), `None` specifically means **"no value"** or **"nothing"**.
#
# Python uses `None` extensively in function returns, optional parameters, object initialization, and missing data representation.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the `NoneType` data type is.
# - Characteristics of `NoneType`.
# - How to assign and use `None`.
# - Common operations involving `None`.
# - Comparisons using `None`.
# - Practical programming examples.
# - Common real-world applications.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# value = None
#
# print(value)
# print(type(value))
# ```
#
# ##### Output
#
# ```text
# None
# <class 'NoneType'>
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the `NoneType` Data Type
#
# Learn what the `NoneType` data type is and why Python uses the `None` value.
#
# **Example**
#
# ```python
# result = None
#
# print(result)
# ```
#
# ##### Output
#
# ```text
# None
# ```
#
# ---
#
# ##### 2. Characteristics of `NoneType`
#
# Explore the important characteristics of the `NoneType` data type.
#
# ##### Characteristics
#
# - Has only one value: `None`.
# - Represents the absence of a value.
# - Immutable.
# - Singleton object (only one instance exists).
# - Frequently used as a default value.
# - Returned by functions without an explicit `return` statement.
# - Different from `0`, `False`, or an empty string.
#
# **Example**
#
# ```python
# value = None
#
# print(type(value))
# ```
#
# ##### Output
#
# ```text
# <class 'NoneType'>
# ```
#
# ---
#
# ##### 3. Assigning `None`
#
# Learn how to assign the `None` value to variables.
#
# **Example**
#
# ```python
# name = None
# age = None
#
# print(name)
# print(age)
# ```
#
# ##### Output
#
# ```text
# None
# None
# ```
#
# ---
#
# ##### 4. Checking for `None`
#
# The recommended way to check whether a variable is `None` is by using the **`is`** operator.
#
# ##### Topics Covered
#
# - `is`
# - `is not`
#
# **Example**
#
# ```python
# value = None
#
# print(value is None)
# print(value is not None)
# ```
#
# ##### Output
#
# ```text
# True
# False
# ```
#
# ---
#
# ##### 5. Common Operations
#
# Learn the common operations involving `None`.
#
# ##### Operations Covered
#
# - Assignment
# - Comparison
# - Function return values
# - Conditional checking
#
# **Example**
#
# ```python
# value = None
#
# if value is None:
#     print("No value available")
# ```
#
# ##### Output
#
# ```text
# No value available
# ```
#
# ---
#
# ##### 6. Functions Returning `None`
#
# When a function does not explicitly return a value, Python automatically returns `None`.
#
# **Example**
#
# ```python
# def greet():
#     print("Hello")
#
# result = greet()
#
# print(result)
# ```
#
# ##### Output
#
# ```text
# Hello
# None
# ```
#
# ---
#
# ##### 7. Practical Examples
#
# Apply `NoneType` concepts through practical programming examples.
#
# Examples include:
#
# - Placeholder variables
# - Function return values
# - Object initialization
# - Missing data handling
# - Optional parameters
#
# ---
#
# ##### 8. Common Use Cases
#
# Understand where the `NoneType` data type is commonly used.
#
# Examples include:
#
# - Database queries
# - API responses
# - Configuration settings
# - Default function arguments
# - Searching operations
# - Object attributes
# - Error handling
#
# **Example**
#
# ```python
# employee = {
#     "id": 101,
#     "manager": None
# }
#
# print(employee)
# ```
#
# ##### Output
#
# ```text
# {'id': 101, 'manager': None}
# ```
#
# ---
#
# ##### 9. Comparison with Other Values
#
# Understand how `None` differs from other commonly used values.
#
# | Value | Meaning |
# |--------|---------|
# | `None` | No value |
# | `0` | Numeric zero |
# | `False` | Boolean false |
# | `""` | Empty string |
# | `[]` | Empty list |
# | `{}` | Empty dictionary |
#
# **Example**
#
# ```python
# print(None == 0)
# print(None == False)
# print(None == "")
# ```
#
# ##### Output
#
# ```text
# False
# False
# False
# ```
#
# ---
#
# ##### 10. Limitations of `NoneType`
#
# Understand the limitations of the `NoneType` data type.
#
# ##### Limitations
#
# - Has only one possible value (`None`).
# - Does not support arithmetic operations.
# - Does not support indexing or slicing.
# - Cannot be iterated over.
# - Accessing attributes or methods on `None` raises an exception.
#
# **Example**
#
# ```python
# value = None
#
# #### print(value + 10)
# ```
#
# ##### Output
#
# ```text
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'
# ```
#
# ---
#
# ##### 11. Best Practices
#
# Follow these recommended practices when working with `None`.
#
# - Use `is None` instead of `== None`.
# - Use `is not None` instead of `!= None`.
# - Initialize variables with `None` when the value is not yet known.
# - Use `None` to represent missing or optional values.
# - Avoid performing operations on `None` without checking it first.
#
# ---
#
# > **Note:** This notebook focuses on the **`NoneType`** data type. By the end of this notebook, you will understand how to use `None` effectively to represent missing values, write safer conditional logic, and build more reliable Python programs.

# %%
# Creating a None value

value = None
print(value)
# Out:
# None

# %%
# Checking the type

value = None
print(type(value))
# Out:
# <class 'NoneType'>

# %%
# None represents no value

result = None
print(result)
# Out:
# None

# %%
# Checking for None

value = None
print(value is None)
# Out:
# True

# %%
# Checking if value is not None

value = 100
print(value is not None)
# Out:
# True

# %%
# None vs 0

value1 = None
value2 = 0
print(value1)
print(value2)
print(value1 == value2)
# Out:
# None
# 0
# False

# %%
# None vs empty string

value1 = None
value2 = ""
print(value1 == value2)
# Out:
# False

# %%
# None vs False

value1 = None
value2 = False
print(value1 == value2)
# Out:
# False

# %%
# None in if statement

value = None
if value is None:
    print("No value")
# Out:
# No value

# %%
# None with if-else

value = None
if value is None:
    print("Value is not available")
else:
    print("Value is available")
# Out:
# Value is not available

# %%
# Function returning None

def display():
    print("Hello")
result = display()
print(result)
# Out:
# Hello
# None

# %%
# Explicitly returning None

def get_value():
    return None
result = get_value()
print(result)
# Out:
# None

# %%
# None as a default value

name = None
print(name)
name = "Jensilin"
print(name)
# Out:
# None
# Jensilin

# %%
# Multiple None values

name = None
age = None
course = None
print(name)
print(age)
print(course)
# Out:
# None
# None
# None

# %%
# Checking multiple values

name = "Jensilin"
age = None

if name is not None:
    print("Name is available")
    
if age is None:
    print("Age is not available")
# Out:
# Name is available
# Age is not available

# %%
# None in a list

data = [10, 20, None, 40]
print(data)
# Out:
# [10, 20, None, 40]

# %%
# Checking None in a list

data = [10, 20, None, 40]

for value in data:
    if value is None:
        print("None value found")
# Out:
# None value found

# %%
# None is a singleton

value1 = None
value2 = None
print(value1 is value2)
# Out:
# True

# %%
if value is None:
    print("No value")
