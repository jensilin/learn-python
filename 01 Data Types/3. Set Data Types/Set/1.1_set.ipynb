# %% [markdown]
# #### 🎯 Set (`set`) Data Type
#
# The **Set (`set`)** is one of Python's built-in **collection data types** used to store an **unordered collection of unique elements**. Unlike lists and tuples, sets automatically remove duplicate values and do not support indexing or slicing.
#
# Sets are **mutable**, meaning elements can be added or removed after creation. They are widely used for eliminating duplicate values, performing mathematical set operations, and checking membership efficiently.
#
# Python provides several built-in methods to manipulate sets, making them useful for data analysis, searching, filtering, and various real-world applications.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Set (`set`) data type is.
# - The characteristics and features of sets.
# - Different ways to create set objects.
# - Common set operations.
# - Built-in set methods.
# - Type conversion using the `set()` function.
# - Practical programming examples.
# - Common real-world applications of sets.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# numbers = {10, 20, 30, 40}
#
# print(numbers)
# print(type(numbers))
# ```
#
# ##### Output
#
# ```text
# {10, 20, 30, 40}
# <class 'set'>
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Set (`set`) Data Type
#
# Learn what a set is, why Python provides the `set` data type, and how it stores unique values.
#
# **Example**
#
# ```python
# numbers = {10, 20, 20, 30}
#
# print(numbers)
# ```
#
# ##### Output
#
# ```text
# {10, 20, 30}
# ```
#
# ---
#
# ##### 2. Characteristics of Sets
#
# Explore the important characteristics of the `set` data type.
#
# ##### Characteristics
#
# - Unordered collection.
# - Mutable data type.
# - Stores unique elements only.
# - Does not allow duplicate values.
# - Does not support indexing or slicing.
# - Supports mathematical set operations.
# - Supports membership operators (`in`, `not in`).
#
# **Example**
#
# ```python
# data = {10, "Python", 3.14, True}
#
# print(data)
# ```
#
# ##### Output
#
# ```text
# {10, 'Python', 3.14, True}
# ```
#
# ---
#
# ##### 3. Creating Set Objects
#
# Learn different ways to create set objects in Python.
#
# ##### Topics Covered
#
# - Empty set
# - Direct assignment
# - Using the `set()` constructor
# - Creating a set from other collections
#
# **Example**
#
# ```python
# a = set()
# b = {10, 20, 30}
# c = set([1, 2, 3])
# d = set("Python")
#
# print(a)
# print(b)
# print(c)
# print(d)
# ```
#
# ##### Output
#
# ```text
# set()
# {10, 20, 30}
# {1, 2, 3}
# {'P', 'y', 't', 'h', 'o', 'n'}
# ```
#
# ---
#
# ##### 4. Set Operations
#
# Learn the common operations that can be performed on sets.
#
# ##### Operations Covered
#
# - Union (`|`)
# - Intersection (`&`)
# - Difference (`-`)
# - Symmetric Difference (`^`)
# - Membership (`in`, `not in`)
# - Length (`len()`)
#
# **Example**
#
# ```python
# a = {1, 2, 3}
# b = {3, 4, 5}
#
# print(a | b)
# print(a & b)
# print(a - b)
# print(a ^ b)
# ```
#
# ##### Output
#
# ```text
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}
# {1, 2, 4, 5}
# ```
#
# ---
#
# ##### 5. Built-in Set Methods
#
# Learn the commonly used methods available for sets.
#
# ##### Methods Covered
#
# - `add()`
# - `update()`
# - `remove()`
# - `discard()`
# - `pop()`
# - `clear()`
# - `copy()`
# - `union()`
# - `intersection()`
# - `difference()`
# - `symmetric_difference()`
# - `issubset()`
# - `issuperset()`
# - `isdisjoint()`
#
# **Example**
#
# ```python
# numbers = {10, 20}
#
# numbers.add(30)
#
# print(numbers)
# ```
#
# ##### Output
#
# ```text
# {10, 20, 30}
# ```
#
# ---
#
# ##### 6. Type Conversion
#
# Learn how to convert other iterable objects into sets.
#
# ##### Topics Covered
#
# - Using `set()`
# - List to Set
# - Tuple to Set
# - String to Set
# - Range to Set
#
# **Example**
#
# ```python
# print(set([1, 2, 3]))
# print(set("Python"))
# ```
#
# ##### Output
#
# ```text
# {1, 2, 3}
# {'P', 'y', 't', 'h', 'o', 'n'}
# ```
#
# ---
#
# ##### 7. Practical Examples
#
# Apply set concepts through practical programming examples.
#
# Examples include:
#
# - Removing duplicate values
# - Finding common elements
# - Comparing two collections
# - Data filtering
# - Membership testing
#
# ---
#
# ##### 8. Common Use Cases
#
# Understand where sets are commonly used in software development.
#
# Examples include:
#
# - Removing duplicates
# - Data analysis
# - Searching and filtering
# - Database operations
# - Permission management
# - Tag management
# - Mathematical set operations
#
# **Example**
#
# ```python
# names = ["Alice", "Bob", "Alice", "John"]
#
# unique_names = set(names)
#
# print(unique_names)
# ```
#
# ##### Output
#
# ```text
# {'Alice', 'Bob', 'John'}
# ```
#
# ---
#
# ##### 9. Limitations of Sets
#
# Understand the limitations of the `set` data type.
#
# ##### Limitations
#
# - Does not preserve element order.
# - Does not support indexing.
# - Does not support slicing.
# - Stores only hashable (immutable) elements.
# - Duplicate values are automatically removed.
#
# **Example**
#
# ```python
# numbers = {10, 20, 30}
#
# print(numbers)
# ```
#
# ##### Output
#
# ```text
# {10, 20, 30}
# ```
#
# ---
#
# ##### 10. Set Methods (Detailed Study)
#
# This section provides a detailed explanation of Python's built-in set methods with syntax, examples, outputs, and real-world use cases.
#
# Methods include:
#
# - `add()`
# - `update()`
# - `remove()`
# - `discard()`
# - `pop()`
# - `clear()`
# - `copy()`
# - `union()`
# - `intersection()`
# - `difference()`
# - `symmetric_difference()`
# - `issubset()`
# - `issuperset()`
# - `isdisjoint()`
#
# ---
#
# > **Note:** This notebook focuses exclusively on the **Set (`set`)** data type. By the end of this notebook, you will have a solid understanding of set creation, operations, methods, type conversion, and real-world applications, enabling you to work efficiently with unique collections of data in Python.

# %%
#Creating a Set

fruits = {"Apple", "Banana", "Mango"}
print(fruits)
# Out:
# {'Banana', 'Mango', 'Apple'}

# %%
#Set with Numbers

numbers = {10, 20, 30, 40, 50}
print(numbers)
# Out:
# {50, 20, 40, 10, 30}

# %%
#Different Data Types

data = {"Jensilin", 21, 50.5, True}
print(data)
# Out:
# {True, 50.5, 21, 'Jensilin'}

# %%
#Empty Set

items = set()
print(items)
print(type(items))
# Out:
# set()
# <class 'set'>

# %%
#Duplicate Values

numbers = {10, 20, 10, 30, 20, 40}
print(numbers)
# Out:
# {40, 10, 20, 30}

# %%
#Set Length

fruits = {"Apple", "Banana", "Mango", "Orange"}
print(len(fruits))
# Out:
# 4

# %%
#Set does not support indexing

fruits = {"Apple", "Banana", "Mango"}
# print(fruits[0])

# %%
#Set with a String

letters = {"A", "B", "C", "D"}
print(letters)
# Out:
# {'A', 'D', 'B', 'C'}

# %%
#List to Set

numbers = [10, 20, 30, 20, 10]
numbers_set = set(numbers)
print(numbers_set)
# Out:
# {10, 20, 30}

# %%
#Tuple to Set

numbers = (10, 20, 30, 20, 10)
numbers_set = set(numbers)
print(numbers_set)
# Out:
# {10, 20, 30}

# %%
#Checking Membership

fruits = {"Apple", "Banana", "Mango"}
print("Apple" in fruits)
print("Orange" in fruits)
# Out:
# True
# False

# %%
#Checking if an Element is Not Present

fruits = {"Apple", "Banana", "Mango"}
print("Orange" not in fruits)
print("Apple" not in fruits)
# Out:
# True
# False

# %%
#Set with for loop

fruits = {"Apple", "Banana", "Mango"}
for fruit in fruits:
    print(fruit)
# Out:
# Banana
# Mango
# Apple

# %%
#Comparing Sets

set1 = {1, 2, 3}
set2 = {1, 2, 3}
print(set1 == set2)
# Out:
# True

# %%
#Set with Boolean Values

values = {True, False}
print(values)
# Out:
# {False, True}

# %%
#Set is Mutable

fruits = {"Apple", "Banana", "Mango"}
print(fruits)
fruits.add("Orange")
print(fruits)
# Out:
# {'Banana', 'Mango', 'Apple'}
# {'Banana', 'Mango', 'Orange', 'Apple'}

# %%
#Set is Mutable

fruits = {"Apple", "Banana", "Mango"}
print(fruits)
# Out:
# {'Banana', 'Mango', 'Apple'}
