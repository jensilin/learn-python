# %% [markdown]
# #### ❄️ Frozen Set Methods
#
# Python provides only **non-modifying methods** for the `frozenset` data type because a `frozenset` is **immutable**. Unlike a normal `set`, you cannot add, remove, or update elements after creating a `frozenset`.
#
# This notebook covers the **commonly used `frozenset` methods** with their syntax, examples, and outputs.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What `frozenset` methods are.
# - Why only non-modifying methods are available.
# - Syntax of each method.
# - Practical examples.
# - Common use cases.
#
# ---
#
# ##### 1. `copy()`
#
# Returns a shallow copy of the `frozenset`.
#
# ##### Syntax
#
# ```python
# frozenset_name.copy()
# ```
#
# ##### Example
#
# ```python
# numbers = frozenset({10, 20, 30})
#
# new_numbers = numbers.copy()
#
# print(new_numbers)
# ```
#
# ##### Output
#
# ```text
# frozenset({10, 20, 30})
# ```
#
# > **Note:** Since `frozenset` is immutable, `copy()` returns the same immutable object.
#
# ---
#
# ##### 2. `union()`
#
# Returns a new `frozenset` containing all unique elements from both collections.
#
# ##### Syntax
#
# ```python
# frozenset1.union(frozenset2)
# ```
#
# ##### Example
#
# ```python
# a = frozenset({1, 2, 3})
# b = frozenset({3, 4, 5})
#
# print(a.union(b))
# ```
#
# ##### Output
#
# ```text
# frozenset({1, 2, 3, 4, 5})
# ```
#
# ---
#
# ##### 3. `intersection()`
#
# Returns the common elements present in both `frozenset` objects.
#
# ##### Syntax
#
# ```python
# frozenset1.intersection(frozenset2)
# ```
#
# ##### Example
#
# ```python
# a = frozenset({1, 2, 3})
# b = frozenset({2, 3, 4})
#
# print(a.intersection(b))
# ```
#
# ##### Output
#
# ```text
# frozenset({2, 3})
# ```
#
# ---
#
# ##### 4. `difference()`
#
# Returns the elements that are present only in the first `frozenset`.
#
# ##### Syntax
#
# ```python
# frozenset1.difference(frozenset2)
# ```
#
# ##### Example
#
# ```python
# a = frozenset({1, 2, 3})
# b = frozenset({2, 3, 4})
#
# print(a.difference(b))
# ```
#
# ##### Output
#
# ```text
# frozenset({1})
# ```
#
# ---
#
# ##### 5. `symmetric_difference()`
#
# Returns the elements that are present in either `frozenset`, but not in both.
#
# ##### Syntax
#
# ```python
# frozenset1.symmetric_difference(frozenset2)
# ```
#
# ##### Example
#
# ```python
# a = frozenset({1, 2, 3})
# b = frozenset({2, 3, 4})
#
# print(a.symmetric_difference(b))
# ```
#
# ##### Output
#
# ```text
# frozenset({1, 4})
# ```
#
# ---
#
# ##### 6. `issubset()`
#
# Checks whether one `frozenset` is a subset of another.
#
# ##### Syntax
#
# ```python
# frozenset1.issubset(frozenset2)
# ```
#
# ##### Example
#
# ```python
# a = frozenset({1, 2})
# b = frozenset({1, 2, 3})
#
# print(a.issubset(b))
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ##### 7. `issuperset()`
#
# Checks whether one `frozenset` is a superset of another.
#
# ##### Syntax
#
# ```python
# frozenset1.issuperset(frozenset2)
# ```
#
# ##### Example
#
# ```python
# a = frozenset({1, 2, 3})
# b = frozenset({1, 2})
#
# print(a.issuperset(b))
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ##### 8. `isdisjoint()`
#
# Checks whether two `frozenset` objects have no common elements.
#
# ##### Syntax
#
# ```python
# frozenset1.isdisjoint(frozenset2)
# ```
#
# ##### Example
#
# ```python
# a = frozenset({1, 2})
# b = frozenset({3, 4})
#
# print(a.isdisjoint(b))
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# #### 📊 Summary
#
# | Method | Purpose |
# |---------|---------|
# | `copy()` | Returns a shallow copy |
# | `union()` | Combines two `frozenset` objects |
# | `intersection()` | Returns common elements |
# | `difference()` | Returns elements present only in the first `frozenset` |
# | `symmetric_difference()` | Returns non-common elements |
# | `issubset()` | Checks subset relationship |
# | `issuperset()` | Checks superset relationship |
# | `isdisjoint()` | Checks whether two `frozenset` objects have no common elements |
#
# ---
#
# #### 📖 Further Reference
#
# Python provides additional information about the `frozenset` data type and its supported operations. You can learn more from the official W3Schools documentation.
#
# **W3Schools – Python Frozen Set Methods**
#
# https://www.w3schools.com/python/ref_func_frozenset.asp
#
# **W3Schools – Python Sets**
#
# https://www.w3schools.com/python/python_sets.asp
#
# ---
#
# > **Note:** Since `frozenset` objects are immutable, they support only methods that do not modify their contents. Methods such as `add()`, `update()`, `remove()`, `discard()`, `pop()`, and `clear()` are available only for the mutable `set` data type.

# %%
#union()

set1 = frozenset({1, 2, 3})
set2 = frozenset({3, 4, 5})
result = set1.union(set2)
print(result)
# Out:
# frozenset({1, 2, 3, 4, 5})

# %%
#intersection()

set1 = frozenset({1, 2, 3, 4})
set2 = frozenset({3, 4, 5, 6})
result = set1.intersection(set2)
print(result)
# Out:
# frozenset({3, 4})

# %%
#difference()

set1 = frozenset({1, 2, 3, 4})
set2 = frozenset({3, 4, 5, 6})
result = set1.difference(set2)
print(result)
# Out:
# frozenset({1, 2})

# %%
#symmetric_difference()

set1 = frozenset({1, 2, 3, 4})
set2 = frozenset({3, 4, 5, 6})
result = set1.symmetric_difference(set2)
print(result)
# Out:
# frozenset({1, 2, 5, 6})

# %%
#issubset()

set1 = frozenset({1, 2})
set2 = frozenset({1, 2, 3, 4})
print(set1.issubset(set2))
# Out:
# True

# %%
#issuperset()

set1 = frozenset({1, 2, 3, 4})
set2 = frozenset({1, 2})
print(set1.issuperset(set2))
# Out:
# True

# %%
#isdisjoint()

set1 = frozenset({1, 2, 3})
set2 = frozenset({4, 5, 6})
print(set1.isdisjoint(set2))
# Out:
# True

# %%
#copy()

fruits = frozenset({"Apple", "Banana", "Mango"})
new_fruits = fruits.copy()
print(fruits)
print(new_fruits)
# Out:
# frozenset({'Apple', 'Banana', 'Mango'})
# frozenset({'Apple', 'Banana', 'Mango'})
