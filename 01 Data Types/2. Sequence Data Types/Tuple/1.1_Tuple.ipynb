# %% [markdown]
# #### 📦 Tuple (`tuple`) Data Type
#
# The **Tuple (`tuple`)** is one of Python's built-in **sequence data types**. It is used to store an **ordered collection of multiple values** in a single variable. A tuple can contain elements of the **same or different data types**, making it useful for storing related data.
#
# Unlike lists, tuples are **immutable**, which means their elements **cannot be modified, added, or removed** after creation. Because of their immutability, tuples are faster than lists and are commonly used for storing fixed data.
#
# Tuples support indexing, slicing, iteration, and many common sequence operations. They are widely used for returning multiple values from functions, storing records, and protecting data from accidental modification.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Tuple (`tuple`) data type is.
# - The characteristics and features of tuples.
# - Different ways to create tuple objects.
# - Indexing and slicing.
# - Tuple operations.
# - Built-in tuple methods.
# - Type conversion using the `tuple()` function.
# - Practical programming examples.
# - Common real-world applications of tuples.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# student = ("John", 21, "Python")
#
# print(student)
# print(type(student))
# ```
#
# ##### Output
#
# ```text
# ('John', 21, 'Python')
# <class 'tuple'>
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Tuple (`tuple`) Data Type
#
# Learn what a tuple is, why Python provides the `tuple` data type, and how it is used to store multiple values in an ordered collection.
#
# **Example**
#
# ```python
# numbers = (10, 20, 30)
#
# print(numbers)
# ```
#
# ##### Output
#
# ```text
# (10, 20, 30)
# ```
#
# ---
#
# ##### 2. Characteristics of Tuples
#
# Explore the important characteristics of the `tuple` data type.
#
# ##### Characteristics
#
# - Ordered collection.
# - Immutable data type.
# - Allows duplicate values.
# - Supports heterogeneous data.
# - Supports indexing and slicing.
# - Faster than lists.
# - Allows nested tuples.
#
# **Example**
#
# ```python
# data = (10, "Python", 3.14, True)
#
# print(data)
# ```
#
# ##### Output
#
# ```text
# (10, 'Python', 3.14, True)
# ```
#
# ---
#
# ##### 3. Creating Tuple Objects
#
# Learn different ways to create tuple objects in Python.
#
# ##### Topics Covered
#
# - Empty tuple
# - Single-element tuple
# - Multiple-element tuple
# - Using the `tuple()` constructor
# - Nested tuples
#
# **Example**
#
# ```python
# a = ()
# b = (100,)
# c = (10, 20, 30)
# d = tuple("Python")
#
# print(a)
# print(b)
# print(c)
# print(d)
# ```
#
# ##### Output
#
# ```text
# ()
# (100,)
# (10, 20, 30)
# ('P', 'y', 't', 'h', 'o', 'n')
# ```
#
# ---
#
# ##### 4. Indexing and Slicing
#
# Learn how to access individual elements and sub-tuples using indexes and slices.
#
# **Example**
#
# ```python
# numbers = (10, 20, 30, 40, 50)
#
# print(numbers[0])
# print(numbers[-1])
# print(numbers[1:4])
# ```
#
# ##### Output
#
# ```text
# 10
# 50
# (20, 30, 40)
# ```
#
# ---
#
# ##### 5. Tuple Operations
#
# Learn the common operations that can be performed on tuples.
#
# ##### Operations Covered
#
# - Concatenation (`+`)
# - Repetition (`*`)
# - Membership (`in`, `not in`)
# - Length (`len()`)
# - Iteration
# - Comparison
#
# **Example**
#
# ```python
# a = (1, 2)
# b = (3, 4)
#
# print(a + b)
# print(a * 2)
# print(2 in a)
# ```
#
# ##### Output
#
# ```text
# (1, 2, 3, 4)
# (1, 2, 1, 2)
# True
# ```
#
# ---
#
# ##### 6. Built-in Tuple Methods
#
# Unlike lists, tuples provide only two built-in methods.
#
# ##### Methods Covered
#
# - `count()`
# - `index()`
#
# **Example**
#
# ```python
# numbers = (10, 20, 10, 30)
#
# print(numbers.count(10))
# print(numbers.index(20))
# ```
#
# ##### Output
#
# ```text
# 2
# 1
# ```
#
# ---
#
# ##### 7. Type Conversion
#
# Learn how to convert other iterable objects into tuples.
#
# ##### Topics Covered
#
# - Using `tuple()`
# - String to Tuple
# - List to Tuple
# - Range to Tuple
# - Set to Tuple
#
# **Example**
#
# ```python
# print(tuple("Python"))
# print(tuple([1, 2, 3]))
# ```
#
# ##### Output
#
# ```text
# ('P', 'y', 't', 'h', 'o', 'n')
# (1, 2, 3)
# ```
#
# ---
#
# ##### 8. Practical Examples
#
# Apply tuple concepts through practical programming examples.
#
# Examples include:
#
# - Student records
# - Employee details
# - Coordinate points
# - RGB color values
# - Returning multiple values from functions
#
# ---
#
# ##### 9. Common Use Cases
#
# Understand where tuples are commonly used in software development.
#
# Examples include:
#
# - Returning multiple values from functions
# - Database records
# - Coordinates (`x`, `y`)
# - Configuration settings
# - Fixed collections of data
# - Dictionary keys
# - Data exchange
#
# **Example**
#
# ```python
# point = (10, 25)
#
# print(point)
# ```
#
# ##### Output
#
# ```text
# (10, 25)
# ```
#
# ---
#
# ##### 10. Tuple Methods (Detailed Study)
#
# This section provides a detailed explanation of the tuple methods with syntax, examples, outputs, and real-world use cases.
#
# Methods include:
#
# - `count()`
# - `index()`
#
# ---
#
# > **Note:** This notebook focuses exclusively on the **Tuple (`tuple`)** data type. By the end of this notebook, you will have a solid understanding of tuple creation, indexing, slicing, operations, built-in methods, and real-world applications, enabling you to work efficiently with immutable collections in Python.

# %%
#Creating a Tuple

fruits = ("Apple", "Banana", "Mango")
print(fruits)
# Out:
# ('Apple', 'Banana', 'Mango')

# %%
#Different Data Types

data = ("Jensilin", 21, 50.5, True)
print(data)
# Out:
# ('Jensilin', 21, 50.5, True)

# %%
#Single Element Tuple
number = (10,)

print(number)
print(type(number))
# Out:
# (10,)
# <class 'tuple'>

# %%
#Empty Tuple
items = ()

print(items)
print(type(items))
# Out:
# ()
# <class 'tuple'>

# %%
#Tuple Length

fruits = ("Apple", "Banana", "Mango", "Orange")
print(len(fruits))
# Out:
# 4

# %%
#Tuple Indexing

fruits = ("Apple", "Banana", "Mango", "Orange")
print(fruits[0])
print(fruits[1])
print(fruits[2])
print(fruits[3])
# Out:
# Apple
# Banana
# Mango
# Orange

# %%
#Negative Indexing

fruits = ("Apple", "Banana", "Mango", "Orange")
print(fruits[-1])
print(fruits[-2])
# Out:
# Orange
# Mango

# %%
#Tuple Slicing

numbers = (10, 20, 30, 40, 50)
print(numbers[1:4])
print(numbers[:3])
print(numbers[2:])
# Out:
# (20, 30, 40)
# (10, 20, 30)
# (30, 40, 50)

# %%
#Tuple Concatenation
tuple1 = (1, 2, 3)
tuple2 = (4, 5, 6)

result = tuple1 + tuple2
print(result)
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
#Tuple Repetition
numbers = (1, 2, 3)
result = numbers * 2

print(result)
# Out:
# (1, 2, 3, 1, 2, 3)

# %%
#Checking an Element
fruits = ("Apple", "Banana", "Mango")

print("Apple" in fruits)
print("Orange" in fruits)
# Out:
# True
# False

# %%
#Tuple Unpacking
person = ("Jensilin", 21, "Python")
name, age, language = person

print(name)
print(age)
print(language)
# Out:
# Jensilin
# 21
# Python

# %%
#Nested Tuple
students = (
    ("Jensilin", 21),
    ("Rahul", 22),
    ("Priya", 20)
)

print(students)
print(students[0])
print(students[0][0])
# Out:
# (('Jensilin', 21), ('Rahul', 22), ('Priya', 20))
# ('Jensilin', 21)
# Jensilin

# %%
#Tuple with Numbers
numbers = (10, 20, 30, 40, 50)

print(numbers)
print(numbers[0])
print(numbers[-1])
# Out:
# (10, 20, 30, 40, 50)
# 10
# 50

# %%
#Tuple is Immutable

fruits = ("Apple", "Banana", "Mango")
# fruits[0] = "Orange"
print(fruits)
# Out:
# ('Apple', 'Banana', 'Mango')
