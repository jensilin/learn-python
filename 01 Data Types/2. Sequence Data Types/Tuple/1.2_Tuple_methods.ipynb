# %% [markdown]
# #### 📦 Tuple Methods
#
# Python provides only **two built-in methods** for tuples because tuples are **immutable**. Unlike lists, tuples cannot be modified after they are created, so methods such as `append()`, `remove()`, `insert()`, and `sort()` are not available.
#
# This notebook explains the **two built-in tuple methods** with their syntax, examples, and outputs.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What tuple methods are.
# - Why tuples have only two built-in methods.
# - Syntax of each method.
# - Practical examples.
# - Return values.
# - Common use cases.
#
# ---
#
# ##### 1. `count()`
#
# The `count()` method returns the **number of times** a specified element appears in the tuple.
#
# ##### Syntax
#
# ```python
# tuple_name.count(value)
# ```
#
# ##### Example
#
# ```python
# numbers = (10, 20, 10, 30, 10)
#
# print(numbers.count(10))
# ```
#
# ##### Output
#
# ```text
# 3
# ```
#
# ##### Note
#
# - Returns an integer.
# - Returns `0` if the element is not found.
#
# ---
#
# ##### 2. `index()`
#
# The `index()` method returns the **index position of the first occurrence** of the specified element.
#
# ##### Syntax
#
# ```python
# tuple_name.index(value)
# ```
#
# ##### Example
#
# ```python
# numbers = (10, 20, 30, 20)
#
# print(numbers.index(20))
# ```
#
# ##### Output
#
# ```text
# 1
# ```
#
# ##### Note
#
# - Returns the index of the first matching element.
# - Raises a `ValueError` if the element is not present in the tuple.
#
# ---
#
# #### 📊 Summary
#
# | Method | Purpose |
# |---------|---------|
# | `count()` | Returns the number of occurrences of an element. |
# | `index()` | Returns the index of the first occurrence of an element. |
#
# ---
#
# #### 📖 Further Reference
#
# Tuples support only two built-in methods because they are immutable. To learn more about tuples and their methods, refer to the official W3Schools documentation.
#
# **W3Schools – Python Tuple Methods**
#
# https://www.w3schools.com/python/python_tuples_methods.asp
#
# ---
#
# > **Note:** Since tuples are immutable, they do not support methods that modify their contents. The available methods are primarily used for searching and counting elements within a tuple.

# %%
#count()

numbers = (10, 20, 10, 30, 10, 40)
print(numbers.count(10))
# Out:
# 3

# %%
#count()

fruits = ("Apple", "Banana", "Apple", "Mango")
print(fruits.count("Orange"))
# Out:
# 0

# %%
#index()

fruits = ("Apple", "Banana", "Mango", "Orange")
print(fruits.index("Mango"))
# Out:
# 2

# %%
#index()

numbers = (10, 20, 30, 20, 40)
print(numbers.index(20))
# Out:
# 1

# %%
#count() and index()
numbers = (10, 20, 10, 30, 10, 40)

print(numbers.count(10))
print(numbers.index(10))
# Out:
# 3
# 0

# %%
#Tuple Methods with Strings

languages = ("Python", "Java", "Python", "C++")
print(languages.count("Python"))
print(languages.index("Python"))
# Out:
# 2
# 0

# %%
#index() with start position

numbers = (10, 20, 30, 20, 40)
print(numbers.index(20, 2))
# Out:
# 3

# %%
#count() with different values

numbers = (10, 20, 10, 30, 20, 10)
print(numbers.count(10))
print(numbers.count(20))
print(numbers.count(30))
# Out:
# 3
# 2
# 1
