# %% [markdown]
# #### ⚖️ Less Than or Equal To Operator (`<=`)
#
# The **Less Than or Equal To (`<=`) operator** is a comparison operator in Python used to **check whether the value on the left is less than or equal to the value on the right**.
#
# If the left operand is either **less than** or **equal to** the right operand, the operator returns **`True`**. Otherwise, it returns **`False`**.
#
# The Less Than or Equal To operator is commonly used in conditional statements, loops, validation, eligibility checks, grading systems, and decision-making.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Less Than or Equal To operator is.
# - Syntax of the Less Than or Equal To operator.
# - How it works.
# - Comparing different data types.
# - Practical programming examples.
# - Common real-world applications.
# - Common mistakes.
# - Best practices.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# a = 15
# b = 20
#
# print(a <= b)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Less Than or Equal To Operator
#
# The Less Than or Equal To operator (`<=`) compares two values and checks whether the **left operand is less than or equal to the right operand**.
#
# If the condition is true, Python returns `True`; otherwise, it returns `False`.
#
# **Example**
#
# ```python
# print(15 <= 20)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ##### 2. Syntax
#
# ##### Syntax
#
# ```python
# operand1 <= operand2
# ```
#
# ##### Explanation
#
# - `operand1` → Left value
# - `<=` → Less Than or Equal To operator
# - `operand2` → Right value
#
# The result is always either `True` or `False`.
#
# ---
#
# ##### 3. Comparing Integers
#
# The operator works with integer values.
#
# **Example**
#
# ```python
# x = 20
# y = 25
#
# print(x <= y)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ```python
# print(30 <= 30)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ```python
# print(40 <= 25)
# ```
#
# ##### Output
#
# ```text
# False
# ```
#
# ---
#
# ##### 4. Comparing Floating-Point Numbers
#
# The operator also works with floating-point numbers.
#
# **Example**
#
# ```python
# print(7.5 <= 9.2)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ```python
# print(10.8 <= 10.8)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ##### 5. Comparing Strings
#
# Strings are compared lexicographically (dictionary order).
#
# **Example**
#
# ```python
# print("Apple" <= "Banana")
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ```python
# print("Python" <= "Programming")
# ```
#
# ##### Output
#
# ```text
# False
# ```
#
# > **Note:** String comparison is **case-sensitive**.
#
# ---
#
# ##### 6. Comparing Boolean Values
#
# Boolean values can also be compared.
#
# **Example**
#
# ```python
# print(False <= True)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ```python
# print(True <= False)
# ```
#
# ##### Output
#
# ```text
# False
# ```
#
# > **Explanation:** `False` is treated as `0` and `True` as `1` during numeric comparison.
#
# ---
#
# ##### 7. Comparing Different Data Types
#
# Compatible numeric data types can be compared.
#
# **Example**
#
# ```python
# print(8 <= 8.0)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# Comparing incompatible data types raises an error.
#
# ```python
# print(10 <= "20")
# ```
#
# ##### Output
#
# ```text
# TypeError
# ```
#
# ---
#
# ##### 8. Practical Examples
#
# Apply the Less Than or Equal To operator through practical programming examples.
#
# ##### Example 1: Maximum Age Check
#
# ```python
# age = 60
#
# if age <= 60:
#     print("Eligible")
# ```
#
# ##### Output
#
# ```text
# Eligible
# ```
#
# ---
#
# ##### Example 2: Passing Score Limit
#
# ```python
# marks = 35
#
# if marks <= 35:
#     print("Needs Improvement")
# ```
#
# ##### Output
#
# ```text
# Needs Improvement
# ```
#
# ---
#
# ##### Example 3: Speed Limit Check
#
# ```python
# speed = 60
#
# if speed <= 60:
#     print("Within Speed Limit")
# ```
#
# ##### Output
#
# ```text
# Within Speed Limit
# ```
#
# ---
#
# ##### 9. Common Use Cases
#
# The Less Than or Equal To operator is commonly used in:
#
# - Age restrictions
# - Banking applications
# - Inventory management
# - Temperature monitoring
# - Academic grading
# - Data filtering
# - Validation rules
# - Conditional statements
#
# ---
#
# ##### 10. Common Mistakes
#
# Avoid these common mistakes while using the Less Than or Equal To operator.
#
# ##### Confusing `<` with `<=`
#
# ```python
# age = 18
#
# print(age < 18)
# ```
#
# ##### Output
#
# ```text
# False
# ```
#
# Correct:
#
# ```python
# print(age <= 18)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ##### Comparing Strings Numerically
#
# ```python
# print("100" <= "20")
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# > **Why?** Strings are compared alphabetically (lexicographically), not based on their numeric values.
#
# ---
#
# ##### Comparing Incompatible Data Types
#
# ```python
# print(25 <= "30")
# ```
#
# ##### Output
#
# ```text
# TypeError
# ```
#
# ---
#
# ##### 11. Best Practices
#
# Follow these recommended practices when using the Less Than or Equal To operator.
#
# - Use `<=` when equality should also satisfy the condition.
# - Compare compatible data types whenever possible.
# - Convert user input to the appropriate data type before comparison.
# - Use meaningful variable names.
# - Keep comparison expressions simple and readable.
#
# ---
#
# #### 📊 Summary
#
# | Feature | Description |
# |---------|-------------|
# | Operator | `<=` |
# | Category | Comparison Operator |
# | Purpose | Checks whether the left value is less than or equal to the right value |
# | Returns | `True` or `False` |
# | Works With | `int`, `float`, `str`, `bool`, and other comparable data types |
# | Case Sensitive | Yes (for strings) |
#
# ---
#
# > **Note:** The Less Than or Equal To (`<=`) operator is an essential comparison operator used to evaluate maximum limits and threshold conditions. It is widely used in validation, eligibility checks, filtering, grading systems, and many real-world programming scenarios where a value must not exceed a specified limit.

# %%
# Less Than or Equal To
a = 10
b = 20

result = a <= b
print(result)
# Out:
# True

# %%
# Equal Values
a = 10
b = 10

print(a <= b)
# Out:
# True

# %%
# Smaller Value
print(10 <= 20)
# Out:
# True

# %%
# Greater Value
print(20 <= 10)
# Out:
# False

# %%
# Integer Comparison

print(10 <= 20)
print(20 <= 10)
print(20 <= 20)
# Out:
# True
# False
# True

# %%
# Float Comparison

print(5.5 <= 10.5)
print(10.5 <= 5.5)
print(10.5 <= 10.5)
# Out:
# True
# False
# True

# %%
# Integer and Float

print(10 <= 10.0)
print(5 <= 10.5)
print(10 <= 5.5)
# Out:
# True
# True
# False

# %%
# Negative Numbers

print(-10 <= -5)
print(-5 <= -10)
print(-5 <= -5)
# Out:
# True
# False
# True

# %%
# Positive and Negative

print(-5 <= 10)
print(10 <= -5)
# Out:
# True
# False

# %%
# String Comparison

print("Apple" <= "Banana")
print("Banana" <= "Apple")
# Out:
# True
# False

# %%
# Equal Strings
print("Python" <= "Python")
# Out:
# True

# %%
# Case-Sensitive Comparison

print("Apple" <= "apple")
print("apple" <= "Apple")
# Out:
# True
# False

# %%
# Boolean Comparison

print(False <= True)
print(True <= False)
print(True <= True)
# Out:
# True
# False
# True

# %%
# Boolean and Integer

print(False <= 0)
print(True <= 1)
print(True <= 0)
# Out:
# True
# True
# False

# %%
# Variables
age = 18
limit = 18

print(age <= limit)
# Out:
# True

# %%
# if Statement
age = 17

if age <= 18:
    print("Age is 18 or below")
# Out:
# Age is 18 or below

# %%
# if-else
number = 50

if number <= 100:
    print("Number is 100 or below")
else:
    print("Number is greater than 100")
# Out:
# Number is 100 or below

# %%
# Maximum Value
speed = 80
speed_limit = 80

if speed <= speed_limit:
    print("Speed is within the limit")
# Out:
# Speed is within the limit

# %%
# User Input
number = int(input("Enter a number: "))

if number <= 100:
    print("Number is 100 or below")
else:
    print("Number is greater than 100")
# Out:
# Number is 100 or below

# %%
# Marks
marks = 40

if marks <= 40:
    print("Marks are 40 or below")
# Out:
# Marks are 40 or below

# %%
# Comparing Expressions
a = 10
b = 5

print(a + b <= 15)
print(a * b <= 50)
print(a - b <= 5)
# Out:
# True
# True
# True

# %%
# Arithmetic and Comparison
result = 10 + 5 <= 15

print(result)
# Out:
# True

# %%
# Parentheses
result = (10 + 5) <= 15

print(result)
# Out:
# True

# %%
# Chained Comparison
age = 25

print(18 <= age <= 60)
# Out:
# True

# %%
# Chained Comparison
age = 65

print(18 <= age <= 60)
# Out:
# False

# %%
# Less Than or Equal To in a Loop

for number in range(1, 6):
    if number <= 3:
        print(number)
# Out:
# 1
# 2
# 3

# %%
# Finding Values
numbers = [10, 20, 30, 40, 50]

for number in numbers:
    if number <= 30:
        print(number)
# Out:
# 10
# 20
# 30

# %%
# Finding Smaller Value
a = 25
b = 50

if a <= b:
    print(a)
else:
    print(b)
# Out:
# 25

# %%
# Age Comparison
age = 18

if age <= 18:
    print("Age is 18 or below")
else:
    print("Age is above 18")
# Out:
# Age is 18 or below

# %%
# Boolean Result
result = 10 <= 20

print(result)
print(type(result))
# Out:
# True
# <class 'bool'>

# %% [markdown]
# | Expression            | Result  |
# | --------------------- | ------- |
# | `10 <= 20`            | `True`  |
# | `20 <= 10`            | `False` |
# | `10 <= 10`            | `True`  |
# | `5.5 <= 10.5`         | `True`  |
# | `-10 <= -5`           | `True`  |
# | `False <= True`       | `True`  |
# | `"Apple" <= "Banana"` | `True`  |
