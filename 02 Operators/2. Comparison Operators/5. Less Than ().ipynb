# %% [markdown]
# #### ⚖️ Less Than Operator (`<`)
#
# The **Less Than (`<`) operator** is a comparison operator in Python used to **check whether the value on the left is less than the value on the right**.
#
# If the left operand is less than the right operand, the operator returns **`True`**. Otherwise, it returns **`False`**.
#
# The Less Than operator is commonly used in conditional statements, loops, sorting, filtering, validation, and decision-making.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Less Than operator is.
# - Syntax of the Less Than operator.
# - How it works.
# - Comparing different data types.
# - Practical programming examples.
# - Common real-world applications.
# - Common mistakes.
# - Best practices.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# a = 10
# b = 20
#
# print(a < b)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Less Than Operator
#
# The Less Than operator (`<`) compares two values and checks whether the **left operand is less than the right operand**.
#
# If the condition is true, Python returns `True`; otherwise, it returns `False`.
#
# **Example**
#
# ```python
# print(8 < 15)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ##### 2. Syntax
#
# ##### Syntax
#
# ```python
# operand1 < operand2
# ```
#
# ##### Explanation
#
# - `operand1` → Left value
# - `<` → Less Than operator
# - `operand2` → Right value
#
# The result is always either `True` or `False`.
#
# ---
#
# ##### 3. Comparing Integers
#
# The Less Than operator works with integer values.
#
# **Example**
#
# ```python
# x = 15
# y = 25
#
# print(x < y)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ```python
# print(30 < 10)
# ```
#
# ##### Output
#
# ```text
# False
# ```
#
# ---
#
# ##### 4. Comparing Floating-Point Numbers
#
# The operator also works with floating-point numbers.
#
# **Example**
#
# ```python
# print(3.14 < 6.28)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ##### 5. Comparing Strings
#
# Strings are compared lexicographically (dictionary order).
#
# **Example**
#
# ```python
# print("Apple" < "Banana")
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ```python
# print("python" < "Python")
# ```
#
# ##### Output
#
# ```text
# False
# ```
#
# > **Note:** String comparison is **case-sensitive**. Uppercase and lowercase letters have different Unicode values.
#
# ---
#
# ##### 6. Comparing Boolean Values
#
# Boolean values can also be compared.
#
# **Example**
#
# ```python
# print(False < True)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# > **Explanation:** `False` is treated as `0` and `True` as `1` during numeric comparison.
#
# ---
#
# ##### 7. Comparing Different Data Types
#
# Compatible numeric data types can be compared.
#
# **Example**
#
# ```python
# print(5 < 7.5)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# Comparing incompatible data types raises an error.
#
# ```python
# print(5 < "7")
# ```
#
# ##### Output
#
# ```text
# TypeError
# ```
#
# ---
#
# ##### 8. Practical Examples
#
# Apply the Less Than operator through practical programming examples.
#
# ##### Example 1: Speed Check
#
# ```python
# speed = 45
#
# if speed < 60:
#     print("Within Speed Limit")
# ```
#
# ##### Output
#
# ```text
# Within Speed Limit
# ```
#
# ---
#
# ##### Example 2: Temperature Check
#
# ```python
# temperature = 18
#
# if temperature < 20:
#     print("Cold Weather")
# ```
#
# ##### Output
#
# ```text
# Cold Weather
# ```
#
# ---
#
# ##### Example 3: Minimum Balance Alert
#
# ```python
# balance = 450
#
# if balance < 500:
#     print("Low Balance")
# ```
#
# ##### Output
#
# ```text
# Low Balance
# ```
#
# ---
#
# ##### 9. Common Use Cases
#
# The Less Than operator is commonly used in:
#
# - Age verification
# - Banking applications
# - Inventory monitoring
# - Data filtering
# - Loop conditions
# - Weather applications
# - Academic grading
# - Automation scripts
#
# ---
#
# ##### 10. Common Mistakes
#
# Avoid these common mistakes while using the Less Than operator.
#
# ##### Reversing the Operands
#
# **Incorrect Logic**
#
# ```python
# marks = 35
#
# print(40 < marks)
# ```
#
# ##### Output
#
# ```text
# False
# ```
#
# > **Why?** Ensure the values are compared in the correct order based on your intended logic.
#
# ---
#
# ##### Comparing Strings Numerically
#
# ```python
# print("100" < "20")
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# > **Why?** Strings are compared alphabetically (lexicographically), not based on their numeric values.
#
# ---
#
# ##### Comparing Incompatible Data Types
#
# ```python
# print(25 < "30")
# ```
#
# ##### Output
#
# ```text
# TypeError
# ```
#
# ---
#
# ##### 11. Best Practices
#
# Follow these recommended practices when using the Less Than operator.
#
# - Use `<` only when checking whether one value is less than another.
# - Compare compatible data types whenever possible.
# - Convert user input to the appropriate data type before comparison.
# - Use meaningful variable names.
# - Keep comparison expressions simple and readable.
#
# ---
#
# #### 📊 Summary
#
# | Feature | Description |
# |---------|-------------|
# | Operator | `<` |
# | Category | Comparison Operator |
# | Purpose | Checks whether the left value is less than the right value |
# | Returns | `True` or `False` |
# | Works With | `int`, `float`, `str`, `bool`, and other comparable data types |
# | Case Sensitive | Yes (for strings) |
#
# ---
#
# > **Note:** The Less Than (`<`) operator is a fundamental comparison operator used to compare values and make decisions in Python programs. It is widely used in conditions, loops, filtering, validation, and many real-world applications where checking smaller values is required.

# %%
# Less Than
a = 10
b = 20

result = a < b
print(result)
# Out:
# True

# %%
# Equal Values
a = 10
b = 10

print(a < b)
# Out:
# False

# %%
# Integer Comparison

print(10 < 20)
print(20 < 10)
# Out:
# True
# False

# %%
# Float Comparison

print(5.5 < 10.5)
print(10.5 < 5.5)
# Out:
# True
# False

# %%
# Integer and Float

print(5 < 10.0)
print(10 < 5.5)
# Out:
# True
# False

# %%
# Negative Numbers

print(-10 < -5)
print(-5 < -10)
# Out:
# True
# False

# %%
# Positive and Negative

print(-5 < 10)
print(10 < -5)
# Out:
# True
# False

# %%
# String Comparison

print("Apple" < "Banana")
print("Banana" < "Apple")
# Out:
# True
# False

# %%
# Case-Sensitive Comparison

print("apple" < "banana")
print("Apple" < "apple")
# Out:
# True
# True

# %%
# Boolean Comparison

print(False < True)
print(True < False)
# Out:
# True
# False

# %%
# Boolean and Integer

print(False < 1)
print(True < 2)
print(True < 1)
# Out:
# True
# True
# False

# %%
# Variables
age1 = 18
age2 = 21

print(age1 < age2)
# Out:
# True

# %%
# if Statement
age = 16

if age < 18:
    print("Under 18")
# Out:
# Under 18

# %%
# if-else
number = 25

if number < 50:
    print("Number is less than 50")
else:
    print("Number is not less than 50")
# Out:
# Number is less than 50

# %%
# Comparing Marks
marks = 40

if marks < 50:
    print("Below passing marks")
# Out:
# Below passing marks

# %%
# Finding Smaller Number
a = 20
b = 30

if a < b:
    print("a is smaller")
else:
    print("b is smaller")
# Out:
# a is smaller

# %%
# User Input
number = int(input("Enter a number: "))

if number < 100:
    print("Number is less than 100")
else:
    print("Number is not less than 100")
# Out:
# Number is less than 100

# %%
# Comparing Expressions
a = 10
b = 5

print(a + b < 20)
print(a * b < 60)
print(a - b < 10)
# Out:
# True
# True
# True

# %%
# Arithmetic and Comparison
result = 10 + 5 < 20

print(result)
# Out:
# True

# %%
# Parentheses
result = (10 + 5) < 20

print(result)
# Out:
# True

# %%
# Chained Comparison
a = 10
b = 20
c = 30

print(a < b < c)
# Out:
# True

# %%
# Chained Comparison
a = 10
b = 20
c = 15

print(a < b < c)
# Out:
# False

# %%
# Less Than in a Loop

for number in range(1, 6):
    if number < 4:
        print(number)
# Out:
# 1
# 2
# 3

# %%
# Finding Smaller Values
numbers = [10, 25, 40, 15, 50]

for number in numbers:
    if number < 30:
        print(number)
# Out:
# 10
# 25
# 15

# %%
# Finding Smaller Value
a = 25
b = 50

if a < b:
    print(a)
else:
    print(b)
# Out:
# 25

# %%
# Less Than vs Equal

print(10 < 10)
print(10 == 10)
# Out:
# False
# True

# %%
# Less Than or Equal To

print(10 <= 10)
# Out:
# True

# %%
# Age Comparison
age = 17

if age < 18:
    print("Minor")
else:
    print("Adult")
# Out:
# Minor

# %%
# Temperature Comparison
temperature = 15

if temperature < 20:
    print("Temperature is low")
else:
    print("Temperature is normal")
# Out:
# Temperature is low

# %%
# Stock Comparison
stock = 5

if stock < 10:
    print("Low stock")
else:
    print("Stock is sufficient")
# Out:
# Low stock

# %%
# Boolean Result
result = 10 < 20

print(result)
print(type(result))
# Out:
# True
# <class 'bool'>

# %% [markdown]
# | Expression           | Result  |
# | -------------------- | ------- |
# | `10 < 20`            | `True`  |
# | `20 < 10`            | `False` |
# | `10 < 10`            | `False` |
# | `5.5 < 10.5`         | `True`  |
# | `-10 < -5`           | `True`  |
# | `False < True`       | `True`  |
# | `"Apple" < "Banana"` | `True`  |
