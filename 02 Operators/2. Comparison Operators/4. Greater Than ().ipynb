# %% [markdown]
# #### ⚖️ Greater Than Operator (`>`)
#
# The **Greater Than (`>`) operator** is a comparison operator in Python used to **check whether the value on the left is greater than the value on the right**.
#
# If the left operand is greater than the right operand, the operator returns **`True`**. Otherwise, it returns **`False`**.
#
# The Greater Than operator is commonly used in conditional statements, loops, sorting, filtering, data validation, and decision-making.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Greater Than operator is.
# - Syntax of the Greater Than operator.
# - How it works.
# - Comparing different data types.
# - Practical programming examples.
# - Common real-world applications.
# - Common mistakes.
# - Best practices.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# a = 20
# b = 15
#
# print(a > b)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Greater Than Operator
#
# The Greater Than operator (`>`) compares two values and checks whether the **left operand is greater than the right operand**.
#
# If the condition is true, Python returns `True`; otherwise, it returns `False`.
#
# **Example**
#
# ```python
# print(15 > 10)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ##### 2. Syntax
#
# ##### Syntax
#
# ```python
# operand1 > operand2
# ```
#
# ##### Explanation
#
# - `operand1` → Left value
# - `>` → Greater Than operator
# - `operand2` → Right value
#
# The result is always either `True` or `False`.
#
# ---
#
# ##### 3. Comparing Integers
#
# The Greater Than operator works with integer values.
#
# **Example**
#
# ```python
# x = 30
# y = 20
#
# print(x > y)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ```python
# print(15 > 25)
# ```
#
# ##### Output
#
# ```text
# False
# ```
#
# ---
#
# ##### 4. Comparing Floating-Point Numbers
#
# The operator also works with floating-point numbers.
#
# **Example**
#
# ```python
# print(9.5 > 7.2)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ##### 5. Comparing Strings
#
# Strings are compared lexicographically (dictionary order).
#
# **Example**
#
# ```python
# print("Cat" > "Apple")
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ```python
# print("Python" > "python")
# ```
#
# ##### Output
#
# ```text
# False
# ```
#
# > **Note:** String comparison is **case-sensitive**. Uppercase letters are compared differently from lowercase letters.
#
# ---
#
# ##### 6. Comparing Boolean Values
#
# Boolean values can also be compared.
#
# **Example**
#
# ```python
# print(True > False)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# > **Explanation:** `True` is treated as `1` and `False` as `0` during numeric comparison.
#
# ---
#
# ##### 7. Comparing Different Data Types
#
# Some different numeric data types can be compared.
#
# **Example**
#
# ```python
# print(10 > 5.5)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# However, comparing incompatible data types raises an error.
#
# ```python
# print(10 > "5")
# ```
#
# ##### Output
#
# ```text
# TypeError
# ```
#
# ---
#
# ##### 8. Practical Examples
#
# Apply the Greater Than operator through practical programming examples.
#
# ##### Example 1: Age Verification
#
# ```python
# age = 21
#
# if age > 18:
#     print("Adult")
# ```
#
# ##### Output
#
# ```text
# Adult
# ```
#
# ---
#
# ##### Example 2: Highest Score
#
# ```python
# score = 92
#
# if score > 90:
#     print("Excellent")
# ```
#
# ##### Output
#
# ```text
# Excellent
# ```
#
# ---
#
# ##### Example 3: Product Stock
#
# ```python
# stock = 8
#
# if stock > 0:
#     print("Product Available")
# ```
#
# ##### Output
#
# ```text
# Product Available
# ```
#
# ---
#
# ##### 9. Common Use Cases
#
# The Greater Than operator is commonly used in:
#
# - Age verification
# - Marks and grading systems
# - Salary comparisons
# - Inventory management
# - Data filtering
# - Ranking systems
# - Performance analysis
# - Conditional statements
#
# ---
#
# ##### 10. Common Mistakes
#
# Avoid these common mistakes while using the Greater Than operator.
#
# ##### Reversing the Operands
#
# **Incorrect Logic**
#
# ```python
# age = 18
#
# print(18 > age)
# ```
#
# ##### Output
#
# ```text
# False
# ```
#
# > **Why?** Ensure the operands are placed in the intended order.
#
# ---
#
# ##### Comparing Strings Numerically
#
# ```python
# print("100" > "20")
# ```
#
# ##### Output
#
# ```text
# False
# ```
#
# > **Why?** Strings are compared alphabetically (lexicographically), not numerically.
#
# ---
#
# ##### Comparing Incompatible Data Types
#
# ```python
# print(25 > "20")
# ```
#
# ##### Output
#
# ```text
# TypeError
# ```
#
# ---
#
# ##### 11. Best Practices
#
# Follow these recommended practices when using the Greater Than operator.
#
# - Use `>` only when checking whether one value is greater than another.
# - Compare compatible data types whenever possible.
# - Convert user input to the appropriate data type before comparison.
# - Use meaningful variable names.
# - Keep comparison expressions simple and readable.
#
# ---
#
# #### 📊 Summary
#
# | Feature | Description |
# |---------|-------------|
# | Operator | `>` |
# | Category | Comparison Operator |
# | Purpose | Checks whether the left value is greater than the right value |
# | Returns | `True` or `False` |
# | Works With | `int`, `float`, `str`, `bool`, and other comparable data types |
# | Case Sensitive | Yes (for strings) |
#
# ---
#
# > **Note:** The Greater Than (`>`) operator is an essential comparison operator for evaluating numeric and comparable values. It is widely used in decision-making, filtering, validation, and control flow, making it a fundamental part of Python programming.

# %%
# Greater Than
a = 20
b = 10

result = a > b
print(result)
# Out:
# True

# %%
# Equal Values
a = 10
b = 10

print(a > b)
# Out:
# False

# %%
# Integer Comparison

print(20 > 10)
print(10 > 20)
# Out:
# True
# False

# %%
# Float Comparison

print(10.5 > 5.5)
print(5.5 > 10.5)
# Out:
# True
# False

# %%
# Integer and Float

print(10 > 5.5)
print(5 > 10.0)
# Out:
# True
# False

# %%
# Negative Numbers

print(-5 > -10)
print(-10 > -5)
# Out:
# True
# False

# %%
# Positive and Negative

print(10 > -5)
print(-5 > 10)
# Out:
# True
# False

# %%
# String Comparison

print("Banana" > "Apple")
print("Apple" > "Banana")
# Out:
# True
# False

# %%
# Case-Sensitive Comparison

print("Python" > "python")
print("python" > "Python")
# Out:
# False
# True

# %%
# Boolean Comparison

print(True > False)
print(False > True)
# Out:
# True
# False

# %%
# Boolean and Integer

print(True > 0)
print(False > 0)
# Out:
# True
# False

# %%
# Variables
age1 = 25
age2 = 21

print(age1 > age2)
# Out:
# True

# %%
# if Statement
age = 21

if age > 18:
    print("Age is greater than 18")
# Out:
# Age is greater than 18

# %%
# if-else
number = 25

if number > 50:
    print("Greater than 50")
else:
    print("Not greater than 50")
# Out:
# Not greater than 50

# %%
# Comparing Marks
marks = 85

if marks > 50:
    print("Marks are greater than 50")
# Out:
# Marks are greater than 50

# %%
# Finding Greater Number
a = 50
b = 30

if a > b:
    print("a is greater")
else:
    print("b is greater")
# Out:
# a is greater

# %%
# User Input
number = int(input("Enter a number: "))

if number > 100:
    print("Number is greater than 100")
else:
    print("Number is not greater than 100")
# Out:
# Number is greater than 100

# %%
# Comparing Expressions
a = 10
b = 5

print(a + b > 10)
print(a * b > 40)
print(a - b > 2)
# Out:
# True
# True
# True

# %%
# Arithmetic and Comparison
result = 10 + 5 > 12

print(result)
# Out:
# True

# %%
# Parentheses
result = (10 + 5) > 12

print(result)
# Out:
# True

# %%
# Chained Comparison
a = 30
b = 20
c = 10

print(a > b > c)
# Out:
# True

# %%
# Chained Comparison
a = 30
b = 20
c = 25

print(a > b > c)
# Out:
# False

# %%
# Greater Than in a Loop
for number in range(1, 6):
    if number > 3:
        print(number)
# Out:
# 4
# 5

# %%
# Finding Greater Values
numbers = [10, 25, 40, 15, 50]

for number in numbers:
    if number > 20:
        print(number)
# Out:
# 25
# 40
# 50

# %%
# Finding Highest Value
a = 25
b = 50

if a > b:
    print(a)
else:
    print(b)
# Out:
# 50

# %%
# Greater Than vs Equal
print(10 > 10)
print(10 == 10)
# Out:
# False
# True

# %%
# Greater Than or Equal To
print(10 >= 10)
# Out:
# True

# %%
# Age Comparison
age = 25

if age > 18:
    print("Age is above 18")
# Out:
# Age is above 18

# %%
# Salary Comparison
salary = 50000

if salary > 30000:
    print("Salary is above 30000")
# Out:
# Salary is above 30000

# %%
# Temperature Comparison
temperature = 35

if temperature > 30:
    print("Temperature is high")
else:
    print("Temperature is normal")
# Out:
# Temperature is high

# %%
# Boolean Result
result = 20 > 10

print(result)
print(type(result))
# Out:
# True
# <class 'bool'>

# %% [markdown]
# | Expression           | Result  |
# | -------------------- | ------- |
# | `20 > 10`            | `True`  |
# | `10 > 20`            | `False` |
# | `10 > 10`            | `False` |
# | `10.5 > 5.5`         | `True`  |
# | `-5 > -10`           | `True`  |
# | `True > False`       | `True`  |
# | `"Banana" > "Apple"` | `True`  |
