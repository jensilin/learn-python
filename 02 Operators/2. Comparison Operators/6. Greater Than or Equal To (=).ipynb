# %% [markdown]
# #### ⚖️ Greater Than or Equal To Operator (`>=`)
#
# The **Greater Than or Equal To (`>=`) operator** is a comparison operator in Python used to **check whether the value on the left is greater than or equal to the value on the right**.
#
# If the left operand is either **greater than** or **equal to** the right operand, the operator returns **`True`**. Otherwise, it returns **`False`**.
#
# The Greater Than or Equal To operator is commonly used in conditional statements, loops, validation, eligibility checks, grading systems, and decision-making.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Greater Than or Equal To operator is.
# - Syntax of the Greater Than or Equal To operator.
# - How it works.
# - Comparing different data types.
# - Practical programming examples.
# - Common real-world applications.
# - Common mistakes.
# - Best practices.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# a = 20
# b = 20
#
# print(a >= b)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Greater Than or Equal To Operator
#
# The Greater Than or Equal To operator (`>=`) compares two values and checks whether the **left operand is greater than or equal to the right operand**.
#
# If the condition is true, Python returns `True`; otherwise, it returns `False`.
#
# **Example**
#
# ```python
# print(18 >= 18)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ##### 2. Syntax
#
# ##### Syntax
#
# ```python
# operand1 >= operand2
# ```
#
# ##### Explanation
#
# - `operand1` → Left value
# - `>=` → Greater Than or Equal To operator
# - `operand2` → Right value
#
# The result is always either `True` or `False`.
#
# ---
#
# ##### 3. Comparing Integers
#
# The operator works with integer values.
#
# **Example**
#
# ```python
# x = 35
# y = 25
#
# print(x >= y)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ```python
# print(20 >= 20)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ```python
# print(15 >= 25)
# ```
#
# ##### Output
#
# ```text
# False
# ```
#
# ---
#
# ##### 4. Comparing Floating-Point Numbers
#
# The operator also works with floating-point numbers.
#
# **Example**
#
# ```python
# print(8.5 >= 8.5)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ```python
# print(7.2 >= 9.1)
# ```
#
# ##### Output
#
# ```text
# False
# ```
#
# ---
#
# ##### 5. Comparing Strings
#
# Strings are compared lexicographically (dictionary order).
#
# **Example**
#
# ```python
# print("Python" >= "Programming")
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ```python
# print("Apple" >= "Banana")
# ```
#
# ##### Output
#
# ```text
# False
# ```
#
# > **Note:** String comparison is **case-sensitive**.
#
# ---
#
# ##### 6. Comparing Boolean Values
#
# Boolean values can also be compared.
#
# **Example**
#
# ```python
# print(True >= False)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ```python
# print(False >= True)
# ```
#
# ##### Output
#
# ```text
# False
# ```
#
# > **Explanation:** `True` is treated as `1` and `False` as `0` during numeric comparison.
#
# ---
#
# ##### 7. Comparing Different Data Types
#
# Compatible numeric data types can be compared.
#
# **Example**
#
# ```python
# print(15 >= 14.5)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# Comparing incompatible data types raises an error.
#
# ```python
# print(15 >= "14")
# ```
#
# ##### Output
#
# ```text
# TypeError
# ```
#
# ---
#
# ##### 8. Practical Examples
#
# Apply the Greater Than or Equal To operator through practical programming examples.
#
# ##### Example 1: Voting Eligibility
#
# ```python
# age = 18
#
# if age >= 18:
#     print("Eligible to Vote")
# ```
#
# ##### Output
#
# ```text
# Eligible to Vote
# ```
#
# ---
#
# ##### Example 2: Passing Marks
#
# ```python
# marks = 40
#
# if marks >= 40:
#     print("Passed")
# ```
#
# ##### Output
#
# ```text
# Passed
# ```
#
# ---
#
# ##### Example 3: Minimum Account Balance
#
# ```python
# balance = 1000
#
# if balance >= 1000:
#     print("Minimum Balance Maintained")
# ```
#
# ##### Output
#
# ```text
# Minimum Balance Maintained
# ```
#
# ---
#
# ##### 9. Common Use Cases
#
# The Greater Than or Equal To operator is commonly used in:
#
# - Eligibility checks
# - Academic grading systems
# - Banking applications
# - Inventory management
# - Salary validation
# - Age verification
# - Data filtering
# - Conditional statements
#
# ---
#
# ##### 10. Common Mistakes
#
# Avoid these common mistakes while using the Greater Than or Equal To operator.
#
# ##### Confusing `>` with `>=`
#
# ```python
# age = 18
#
# print(age > 18)
# ```
#
# ##### Output
#
# ```text
# False
# ```
#
# Correct:
#
# ```python
# print(age >= 18)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ##### Comparing Strings Numerically
#
# ```python
# print("100" >= "20")
# ```
#
# ##### Output
#
# ```text
# False
# ```
#
# > **Why?** Strings are compared alphabetically (lexicographically), not numerically.
#
# ---
#
# ##### Comparing Incompatible Data Types
#
# ```python
# print(50 >= "40")
# ```
#
# ##### Output
#
# ```text
# TypeError
# ```
#
# ---
#
# ##### 11. Best Practices
#
# Follow these recommended practices when using the Greater Than or Equal To operator.
#
# - Use `>=` when equality should also satisfy the condition.
# - Compare compatible data types whenever possible.
# - Convert user input to the correct data type before comparison.
# - Use meaningful variable names.
# - Write simple and readable comparison expressions.
#
# ---
#
# #### 📊 Summary
#
# | Feature | Description |
# |---------|-------------|
# | Operator | `>=` |
# | Category | Comparison Operator |
# | Purpose | Checks whether the left value is greater than or equal to the right value |
# | Returns | `True` or `False` |
# | Works With | `int`, `float`, `str`, `bool`, and other comparable data types |
# | Case Sensitive | Yes (for strings) |
#
# ---
#
# > **Note:** The Greater Than or Equal To (`>=`) operator is an important comparison operator used to evaluate minimum requirements and threshold conditions. It is widely used in eligibility checks, validation, grading systems, banking applications, and many other real-world programming scenarios.

# %%
# Greater Than or Equal To
a = 20
b = 10

result = a >= b
print(result)
# Out:
# True

# %%
# Equal Values
a = 10
b = 10

print(a >= b)
# Out:
# True

# %%
# Greater Value
print(20 >= 10)
# Out:
# True

# %%
# Smaller Value
print(10 >= 20)
# Out:
# False

# %%
# Integer Comparison

print(50 >= 30)
print(30 >= 50)
print(30 >= 30)
# Out:
# True
# False
# True

# %%
# Float Comparison

print(10.5 >= 5.5)
print(5.5 >= 10.5)
print(10.5 >= 10.5)
# Out:
# True
# False
# True

# %%
# Integer and Float

print(10 >= 10.0)
print(10.5 >= 10)
print(5 >= 10.5)
# Out:
# True
# True
# False

# %%
# Negative Numbers

print(-5 >= -10)
print(-10 >= -5)
print(-5 >= -5)
# Out:
# True
# False
# True

# %%
# Positive and Negative

print(10 >= -5)
print(-5 >= 10)
# Out:
# True
# False

# %%
# String Comparison

print("Banana" >= "Apple")
print("Apple" >= "Banana")
# Out:
# True
# False

# %%
# Equal Strings

print("Python" >= "Python")
# Out:
# True

# %%
# Case-Sensitive Comparison

print("Python" >= "python")
print("python" >= "Python")
# Out:
# False
# True

# %%
# Boolean Comparison

print(True >= False)
print(False >= True)
print(True >= True)
# Out:
# True
# False
# True

# %%
# Boolean and Integer

print(True >= 1)
print(False >= 0)
print(True >= 2)
# Out:
# True
# True
# False

# %%
# Variables
age = 23
required_age = 18

print(age >= required_age)
# Out:
# True

# %%
# if Statement
age = 21

if age >= 18:
    print("Eligible")
# Out:
# Eligible

# %%
# if-else
marks = 50

if marks >= 50:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %%
# Minimum Value
balance = 1000

if balance >= 500:
    print("Minimum balance requirement met")
# Out:
# Minimum balance requirement met

# %%
# User Input
number = int(input("Enter a number: "))

if number >= 100:
    print("Number is 100 or greater")
else:
    print("Number is less than 100")
# Out:
# Number is 100 or greater

# %%
# Age Eligibility
age = 18

if age >= 18:
    print("Eligible")
else:
    print("Not eligible")
# Out:
# Eligible

# %%
# Marks
marks = 75

if marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Pass

# %%
# Comparing Expressions
a = 10
b = 5

print(a + b >= 15)
print(a * b >= 50)
print(a - b >= 5)
# Out:
# True
# True
# True

# %%
# Arithmetic and Comparison
result = 10 + 5 >= 15

print(result)
# Out:
# True

# %%
# Parentheses
result = (10 + 5) >= 15

print(result)
# Out:
# True

# %%
# Chained Comparison
age = 25

print(18 <= age >= 21)
# Out:
# True

# %%
# Range Check
age = 25

print(18 <= age <= 60)
# Out:
# True

# %%
# Greater Than or Equal To in a Loop

for number in range(1, 6):
    if number >= 3:
        print(number)
# Out:
# 3
# 4
# 5

# %%
# Finding Values
numbers = [10, 20, 30, 40, 50]

for number in numbers:
    if number >= 30:
        print(number)
# Out:
# 30
# 40
# 50

# %%
# Finding Greater Value
a = 25
b = 50

if a >= b:
    print(a)
else:
    print(b)
# Out:
# 50

# %%
# Boolean Result
result = 20 >= 10

print(result)
print(type(result))
# Out:
# True
# <class 'bool'>

# %% [markdown]
# | Expression             | Result  |
# | ---------------------- | ------- |
# | `20 >= 10`             | `True`  |
# | `10 >= 20`             | `False` |
# | `10 >= 10`             | `True`  |
# | `10.5 >= 10.5`         | `True`  |
# | `-5 >= -10`            | `True`  |
# | `True >= False`        | `True`  |
# | `"Python" >= "Python"` | `True`  |
