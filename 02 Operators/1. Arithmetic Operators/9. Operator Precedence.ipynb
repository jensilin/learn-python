# %% [markdown]
# #### 📊 Operator Precedence
#
# **Operator Precedence** determines the **order in which Python evaluates operators in an expression**.
#
# When an expression contains multiple operators, Python follows a predefined order of precedence to decide which operation should be performed first. Understanding operator precedence helps you write correct expressions and avoid unexpected results.
#
# When operators have the same precedence, Python usually evaluates them **from left to right** (except for exponentiation, which is evaluated from **right to left**).
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What operator precedence is.
# - Why operator precedence is important.
# - Order of operator precedence in Python.
# - Associativity of operators.
# - Using parentheses to control evaluation.
# - Practical programming examples.
# - Common mistakes.
# - Best practices.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# result = 5 + 2 * 3
#
# print(result)
# ```
#
# ##### Output
#
# ```text
# 11
# ```
#
# > **Explanation:** Multiplication (`*`) has higher precedence than Addition (`+`), so `2 * 3` is evaluated first.
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to Operator Precedence
#
# When an expression contains multiple operators, Python does **not** evaluate them from left to right automatically.
#
# Instead, it follows predefined precedence rules.
#
# **Example**
#
# ```python
# print(10 + 5 * 2)
# ```
#
# ##### Output
#
# ```text
# 20
# ```
#
# **Explanation**
#
# ```text
# 10 + (5 × 2)
# = 10 + 10
# = 20
# ```
#
# ---
#
# ##### 2. Why Operator Precedence Matters
#
# Without understanding precedence, expressions may produce unexpected results.
#
# **Example**
#
# ```python
# print(20 - 6 / 2)
# ```
#
# ##### Output
#
# ```text
# 17.0
# ```
#
# **Explanation**
#
# ```text
# 20 - (6 / 2)
# = 20 - 3
# = 17.0
# ```
#
# ---
#
# ##### 3. Operator Precedence Table
#
# The following table shows common Python operators from **highest** to **lowest** precedence.
#
# | Precedence | Operator | Description |
# |------------|----------|-------------|
# | Highest | `()` | Parentheses |
# | | `**` | Exponentiation |
# | | `+x`, `-x`, `~x` | Unary operators |
# | | `*`, `/`, `//`, `%` | Multiplication, Division, Floor Division, Modulus |
# | | `+`, `-` | Addition, Subtraction |
# | | `<<`, `>>` | Bitwise Shift |
# | | `&` | Bitwise AND |
# | | `^` | Bitwise XOR |
# | | `\|` | Bitwise OR |
# | | `==`, `!=`, `>`, `<`, `>=`, `<=`, `is`, `is not`, `in`, `not in` | Comparison, Identity, Membership |
# | | `not` | Logical NOT |
# | | `and` | Logical AND |
# | Lowest | `or` | Logical OR |
#
# ---
#
# ##### 4. Operator Associativity
#
# Associativity determines the evaluation order when operators have the same precedence.
#
# ##### Left-to-Right Associativity
#
# Most operators follow left-to-right evaluation.
#
# **Example**
#
# ```python
# print(20 - 5 - 3)
# ```
#
# ##### Output
#
# ```text
# 12
# ```
#
# **Explanation**
#
# ```text
# (20 - 5) - 3
# = 15 - 3
# = 12
# ```
#
# ---
#
# ##### Right-to-Left Associativity
#
# The Exponentiation operator (`**`) is evaluated from right to left.
#
# **Example**
#
# ```python
# print(2 ** 3 ** 2)
# ```
#
# ##### Output
#
# ```text
# 512
# ```
#
# **Explanation**
#
# ```text
# 2 ** (3 ** 2)
# = 2 ** 9
# = 512
# ```
#
# ---
#
# ##### 5. Using Parentheses
#
# Parentheses have the **highest precedence** and make expressions easier to understand.
#
# **Example**
#
# ```python
# print((5 + 2) * 3)
# ```
#
# ##### Output
#
# ```text
# 21
# ```
#
# Without parentheses:
#
# ```python
# print(5 + 2 * 3)
# ```
#
# ##### Output
#
# ```text
# 11
# ```
#
# ---
#
# ##### 6. Practical Examples
#
# Apply operator precedence through practical programming examples.
#
# ##### Example 1
#
# ```python
# result = 10 + 6 // 2
#
# print(result)
# ```
#
# ##### Output
#
# ```text
# 13
# ```
#
# ---
#
# ##### Example 2
#
# ```python
# result = (10 + 6) // 2
#
# print(result)
# ```
#
# ##### Output
#
# ```text
# 8
# ```
#
# ---
#
# ##### Example 3
#
# ```python
# result = 2 + 3 * 4 ** 2
#
# print(result)
# ```
#
# ##### Output
#
# ```text
# 50
# ```
#
# **Explanation**
#
# ```text
# 4 ** 2 = 16
# 3 * 16 = 48
# 2 + 48 = 50
# ```
#
# ---
#
# ##### 7. Common Use Cases
#
# Operator precedence is important in:
#
# - Mathematical calculations
# - Scientific computing
# - Financial applications
# - Engineering software
# - Data analysis
# - Machine learning
# - Game development
# - Automation scripts
#
# ---
#
# ##### 8. Common Mistakes
#
# Avoid these common mistakes when working with operator precedence.
#
# ##### Assuming Left-to-Right Evaluation
#
# **Incorrect Assumption**
#
# ```python
# print(5 + 10 * 2)
# ```
#
# Expected:
#
# ```text
# 30
# ```
#
# Actual Output
#
# ```text
# 25
# ```
#
# ---
#
# ##### Forgetting Parentheses
#
# **Example**
#
# ```python
# print(100 / 5 * 2)
# ```
#
# ##### Output
#
# ```text
# 40.0
# ```
#
# If you intended:
#
# ```python
# print(100 / (5 * 2))
# ```
#
# ##### Output
#
# ```text
# 10.0
# ```
#
# ---
#
# ##### Confusing `^` with `**`
#
# ```python
# print(2 ^ 3)
# ```
#
# ##### Output
#
# ```text
# 1
# ```
#
# The correct exponentiation operator is:
#
# ```python
# print(2 ** 3)
# ```
#
# ##### Output
#
# ```text
# 8
# ```
#
# ---
#
# ##### 9. Best Practices
#
# Follow these recommended practices when writing expressions.
#
# - Use parentheses to improve readability.
# - Do not rely entirely on operator precedence for complex expressions.
# - Break long expressions into smaller parts.
# - Use meaningful variable names.
# - Remember that `**` is evaluated from right to left.
#
# ---
#
# #### 📊 Summary
#
# | Feature | Description |
# |---------|-------------|
# | Purpose | Determines the order in which operators are evaluated |
# | Highest Precedence | `()` (Parentheses) |
# | Lowest Precedence | `or` |
# | Most Operators | Left-to-right associativity |
# | Exception | `**` uses right-to-left associativity |
# | Best Practice | Use parentheses to improve readability |
#
# ---
#
# > **Note:** Understanding operator precedence is essential for writing accurate and readable Python expressions. Although Python follows predefined precedence rules, using **parentheses** is always recommended when expressions become complex, as it improves clarity and reduces the chance of logical errors.

# %%
# Basic Precedence
result = 10 + 5 * 2

print(result)
# Out:
# 20

# %%
# Addition and Subtraction
result = 20 - 5 + 3

print(result)
# Out:
# 18

# %%
# Multiplication and Division
result = 20 / 5 * 2

print(result)
# Out:
# 8.0

# %%
# Multiplication before Addition
result = 10 + 5 * 3

print(result)
# Out:
# 25

# %%
# Division before Addition
result = 20 + 10 / 2

print(result)
# Out:
# 25.0

# %%
# Floor Division before Addition
result = 20 + 10 // 3

print(result)
# Out:
# 23

# %%
# Modulus before Addition
result = 20 + 10 % 3

print(result)
# Out:
# 21

# %%
# Exponentiation before Multiplication
result = 2 * 3 ** 2

print(result)
# Out:
# 18

# %%
# Parentheses
result = (10 + 5) * 2

print(result)
# Out:
# 30

# %%
result = 10 + 5 * 2
print(result)
# Out:
# 20

# %%
# Nested Parentheses
result = ((10 + 5) * 2) - 5

print(result)
# Out:
# 25

# %%
# Multiple Operators
result = 10 + 5 * 2 - 4

print(result)
# Out:
# 16

# %%
# Arithmetic Expression
result = 10 + 20 * 3 - 15 / 5

print(result)
# Out:
# 67.0

# %%
# Exponentiation
result = (2 + 3) ** 2

print(result)
# Out:
# 25

# %%
# Chained Exponentiation
result = 2 ** 3 ** 2

print(result)
# Out:
# 512

# %%
# Unary Minus and Exponentiation
result = -2 ** 2

print(result)
# Out:
# -4

# %%
result = (-2) ** 2
print(result)
# Out:
# 4

# %%
# Arithmetic and Comparison
result = 10 + 5 > 12

print(result)
# Out:
# True

# %%
# Comparison and Logical Operator
result = 10 > 5 and 20 > 15

print(result)
# Out:
# True

# %%
# and before or
result = True or False and False

print(result)
# Out:
# True

# %%
# Logical Operators with Parentheses
result = (True or False) and False

print(result)
# Out:
# False

# %%
# Assignment
result = 10 + 5 * 2

print(result)
# Out:
# 20

# %%
# Complex Expression
result = (10 + 5) * 2 ** 3 - 20 / 4

print(result)
# Out:
# 115.0

# %%
# Variables and Precedence
a = 10
b = 5
c = 2

result = a + b * c
print(result)
# Out:
# 20

# %%
# Parentheses
a = 10
b = 5
c = 2

result = (a + b) * c
print(result)
# Out:
# 30

# %%
result = a + b * c
print(result)
# Out:
# 20

# %% [markdown]
# | Priority | Operators                        | Description                                       |
# | -------: | -------------------------------- | ------------------------------------------------- |
# |        1 | `()`                             | Parentheses                                       |
# |        2 | `**`                             | Exponentiation                                    |
# |        3 | `+x`, `-x`                       | Unary plus/minus                                  |
# |        4 | `*`, `/`, `//`, `%`              | Multiplication, division, floor division, modulus |
# |        5 | `+`, `-`                         | Addition, subtraction                             |
# |        6 | `==`, `!=`, `<`, `>`, `<=`, `>=` | Comparisons                                       |
# |        7 | `not`                            | Logical NOT                                       |
# |        8 | `and`                            | Logical AND                                       |
# |        9 | `or`                             | Logical OR                                        |
# |       10 | `=`, `+=`, `-=`, `*=`, `/=` etc. | Assignment                                        |
