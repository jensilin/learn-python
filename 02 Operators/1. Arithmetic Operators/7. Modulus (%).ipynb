# %% [markdown]
# #### 🧮 Modulus Operator (`%`)
#
# The **Modulus (`%`) operator** is an arithmetic operator in Python used to **find the remainder** after dividing one number by another.
#
# Instead of returning the quotient, the Modulus operator returns the **remaining value** after the division is completed. It is widely used in programming for checking even or odd numbers, cyclic operations, time calculations, hashing, and many algorithmic problems.
#
# The Modulus operator works with **integers (`int`)** and **floating-point numbers (`float`)**.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Modulus operator is.
# - Syntax of the Modulus operator.
# - How the Modulus operator works.
# - Modulus with integers and floating-point numbers.
# - Modulus with negative numbers.
# - Practical programming examples.
# - Common real-world applications.
# - Common mistakes.
# - Best practices.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# a = 17
# b = 5
#
# print(a % b)
# ```
#
# ##### Output
#
# ```text
# 2
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Modulus Operator
#
# The Modulus operator (`%`) returns the **remainder** after division.
#
# It does **not** return the quotient.
#
# **Example**
#
# ```python
# print(20 % 6)
# ```
#
# ##### Output
#
# ```text
# 2
# ```
#
# **Explanation**
#
# ```text
# 20 ÷ 6 = 3 remainder 2
# ```
#
# ---
#
# ##### 2. Syntax
#
# ##### Syntax
#
# ```python
# operand1 % operand2
# ```
#
# ##### Explanation
#
# - `operand1` → Dividend (number being divided)
# - `%` → Modulus operator
# - `operand2` → Divisor
#
# The result is the remainder after division.
#
# ---
#
# ##### 3. Modulus with Integers
#
# The Modulus operator works with integer values.
#
# **Example**
#
# ```python
# a = 25
# b = 7
#
# print(a % b)
# ```
#
# ##### Output
#
# ```text
# 4
# ```
#
# ---
#
# ##### 4. Modulus with Floating-Point Numbers
#
# The Modulus operator also works with decimal numbers.
#
# **Example**
#
# ```python
# a = 10.5
# b = 3
#
# print(a % b)
# ```
#
# ##### Output
#
# ```text
# 1.5
# ```
#
# ---
#
# ##### 5. Modulus with Negative Numbers
#
# Python follows the rule that the remainder has the **same sign as the divisor**.
#
# **Example**
#
# ```python
# print(-17 % 5)
# ```
#
# ##### Output
#
# ```text
# 3
# ```
#
# **Explanation**
#
# ```text
# -17 = (5 × -4) + 3
# ```
#
# Another example:
#
# ```python
# print(17 % -5)
# ```
#
# ##### Output
#
# ```text
# -3
# ```
#
# ---
#
# ##### 6. Common Uses of the Modulus Operator
#
# The Modulus operator is frequently used for:
#
# - Checking even or odd numbers
# - Finding multiples
# - Wrapping values
# - Time calculations
# - Cyclic operations
# - Hashing algorithms
#
# ---
#
# ##### 7. Practical Examples
#
# Apply the Modulus operator through practical programming examples.
#
# ##### Example 1: Check Even or Odd
#
# ```python
# number = 14
#
# if number % 2 == 0:
#     print("Even")
# else:
#     print("Odd")
# ```
#
# ##### Output
#
# ```text
# Even
# ```
#
# ---
#
# ##### Example 2: Check Divisibility
#
# ```python
# number = 25
#
# if number % 5 == 0:
#     print("Divisible by 5")
# ```
#
# ##### Output
#
# ```text
# Divisible by 5
# ```
#
# ---
#
# ##### Example 3: Convert Minutes to Hours
#
# ```python
# minutes = 135
#
# remaining_minutes = minutes % 60
#
# print(remaining_minutes)
# ```
#
# ##### Output
#
# ```text
# 15
# ```
#
# ---
#
# ##### 8. Common Use Cases
#
# The Modulus operator is commonly used in:
#
# - Even and odd number checking
# - Leap year calculations
# - Calendar applications
# - Digital clocks
# - Scheduling systems
# - Cryptography
# - Hash tables
# - Circular queues
#
# **Example**
#
# ```python
# seconds = 125
#
# print(seconds % 60)
# ```
#
# ##### Output
#
# ```text
# 5
# ```
#
# ---
#
# ##### 9. Common Mistakes
#
# Avoid these common mistakes while using the Modulus operator.
#
# ##### Dividing by Zero
#
# **Incorrect**
#
# ```python
# print(15 % 0)
# ```
#
# ##### Output
#
# ```text
# ZeroDivisionError
# ```
#
# ---
#
# ##### Confusing Modulus with Division
#
# **Example**
#
# ```python
# print(10 / 3)
# print(10 % 3)
# ```
#
# ##### Output
#
# ```text
# 3.3333333333333335
# 1
# ```
#
# ---
#
# ##### Ignoring Negative Number Behavior
#
# **Example**
#
# ```python
# print(-10 % 3)
# ```
#
# ##### Output
#
# ```text
# 2
# ```
#
# > **Why?** Python calculates the remainder so that the result has the same sign as the divisor.
#
# ---
#
# ##### 10. Best Practices
#
# Follow these recommended practices when using the Modulus operator.
#
# - Use `%` when the remainder is required.
# - Use it for divisibility checks.
# - Always ensure the divisor is not zero.
# - Understand how Python handles negative operands.
# - Use meaningful variable names.
#
# ---
#
# #### 📊 Summary
#
# | Feature | Description |
# |---------|-------------|
# | Operator | `%` |
# | Category | Arithmetic Operator |
# | Purpose | Returns the remainder after division |
# | Works With | `int`, `float` |
# | Common Uses | Even/Odd checks, divisibility, cyclic operations, time calculations |
# | Division by Zero | Raises `ZeroDivisionError` |
#
# ---
#
# > **Note:** The Modulus (`%`) operator is one of the most useful arithmetic operators in Python. It is extensively used for remainder calculations, divisibility checks, cyclic operations, and solving algorithmic problems. Mastering this operator will help you write efficient and elegant Python programs.

# %%
# Modulus
a = 10
b = 3

result = a % b
print(result)
# Out:
# 1

# %%
# Modulus with Exact Division
a = 20
b = 5

result = a % b
print(result)
# Out:
# 0

# %%
# Modulus

print(15 % 4)
print(20 % 6)
print(25 % 7)
# Out:
# 3
# 2
# 4

# %%
# Floating-Point Modulus
a = 10.5
b = 3

result = a % b
print(result)
# Out:
# 1.5

# %%
# Negative Number
a = -10
b = 3

result = a % b
print(result)
# Out:
# 2

# %%
# Negative Divisor
a = 10
b = -3

result = a % b
print(result)
# Out:
# -2

# %%
# Both Negative
a = -10
b = -3

result = a % b
print(result)
# Out:
# -1

# %%
# Variables
number = 25
divisor = 4

remainder = number % divisor
print(remainder)
# Out:
# 1

# %%
# User Input
number = int(input("Enter a number: "))
divisor = int(input("Enter divisor: "))

remainder = number % divisor
print(remainder)
# Out:
# 3

# %%
# Even or Odd
number = 10

if number % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %%
number = 7

if number % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %%
# Divisibility
number = 20

if number % 5 == 0:
    print("Divisible by 5")
else:
    print("Not divisible by 5")
# Out:
# Divisible by 5

# %%
# Divisibility by 3
number = 27

if number % 3 == 0:
    print("Divisible by 3")
else:
    print("Not divisible by 3")
# Out:
# Divisible by 3

# %%
# Remainders

for number in range(1, 6):
    print(number % 2)
# Out:
# 1
# 0
# 1
# 0
# 1

# %%
# Modulus with Loop

for number in range(1, 11):
    if number % 3 == 0:
        print(number)
# Out:
# 3
# 6
# 9

# %%
# Specific Remainder

for number in range(1, 11):
    if number % 3 == 1:
        print(number)
# Out:
# 1
# 4
# 7
# 10

# %%
# Modulus Assignment
number = 17
number %= 5

print(number)
# Out:
# 2

# %%
# Floor Division and Modulus
number = 17
divisor = 5

quotient = number // divisor
remainder = number % divisor

print(quotient)
print(remainder)
# Out:
# 3
# 2

# %%
# Division and Modulus
a = 10
b = 3

print(a / b)
print(a % b)
# Out:
# 3.3333333333333335
# 1

# %%
# Remaining Items
items = 23
items_per_box = 5

remaining = items % items_per_box
print(remaining)
# Out:
# 3

# %%
# Hours and Minutes
minutes = 135

hours = minutes // 60
remaining_minutes = minutes % 60

print(hours)
print(remaining_minutes)
# Out:
# 2
# 15

# %%
# Last Digit
number = 12345

last_digit = number % 10
print(last_digit)
# Out:
# 5

# %%
# Last Two Digits
number = 12345

last_two_digits = number % 100
print(last_two_digits)
# Out:
# 45

# %%
# Boolean Values

print(True % 2)
print(False % 2)
# Out:
# 1
# 0

# %%
# Modulus by Zero
number = 10
divisor = 0

# print(number % divisor)

# %%
# Checking for Zero
number = 10
divisor = 0

if divisor != 0:
    print(number % divisor)
else:
    print("Cannot find remainder with zero")
# Out:
# Cannot find remainder with zero

# %%
# Complex Numbers
a = 10 + 5j
b = 2 + 1j

# print(a % b)

# %%
# Quotient and Remainder
a = 23
b = 5

quotient = a // b
remainder = a % b

print(quotient)
print(remainder)
# Out:
# 4
# 3

# %% [markdown]
# | Operator | Name           | Example   | Result |
# | -------- | -------------- | --------- | -----: |
# | `/`      | Division       | `23 / 5`  |  `4.6` |
# | `//`     | Floor Division | `23 // 5` |    `4` |
# | `%`      | Modulus        | `23 % 5`  |    `3` |
