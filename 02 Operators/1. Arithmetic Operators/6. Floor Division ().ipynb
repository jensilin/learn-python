# %% [markdown]
# #### ⌊⌋ Floor Division Operator (`//`)
#
# The **Floor Division (`//`) operator** is an arithmetic operator in Python used to **divide one number by another and return the largest whole number less than or equal to the result**.
#
# Unlike the Division (`/`) operator, which returns a floating-point result, the Floor Division operator **discards the fractional part** of the quotient by rounding the result down (towards negative infinity).
#
# The Floor Division operator works with **integers (`int`)** and **floating-point numbers (`float`)**.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Floor Division operator is.
# - Syntax of the Floor Division operator.
# - How floor division works.
# - Floor division with integers and floats.
# - Floor division with negative numbers.
# - Practical programming examples.
# - Common real-world applications.
# - Common mistakes.
# - Best practices.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# a = 17
# b = 5
#
# print(a // b)
# ```
#
# ##### Output
#
# ```text
# 3
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Floor Division Operator
#
# The Floor Division operator (`//`) divides two operands and returns the **floor value** of the quotient.
#
# Instead of returning the decimal part, Python rounds the result **down** to the nearest whole number.
#
# **Example**
#
# ```python
# print(20 // 6)
# ```
#
# ##### Output
#
# ```text
# 3
# ```
#
# ---
#
# ##### 2. Syntax
#
# ##### Syntax
#
# ```python
# operand1 // operand2
# ```
#
# ##### Explanation
#
# - `operand1` → Dividend (number being divided).
# - `//` → Floor Division operator.
# - `operand2` → Divisor (number used for division).
#
# The result is the floor value of the quotient.
#
# ---
#
# ##### 3. Floor Division with Integers
#
# The operator works with integer values.
#
# **Example**
#
# ```python
# a = 22
# b = 4
#
# print(a // b)
# ```
#
# ##### Output
#
# ```text
# 5
# ```
#
# ---
#
# ##### 4. Floor Division with Floating-Point Numbers
#
# The operator also works with decimal numbers.
#
# **Example**
#
# ```python
# a = 15.5
# b = 2
#
# print(a // b)
# ```
#
# ##### Output
#
# ```text
# 7.0
# ```
#
# > **Note:** If either operand is a `float`, the result is also returned as a `float`.
#
# ---
#
# ##### 5. Floor Division with Negative Numbers
#
# For negative numbers, Python rounds the result **down toward negative infinity**, not toward zero.
#
# **Example**
#
# ```python
# print(-17 // 5)
# ```
#
# ##### Output
#
# ```text
# -4
# ```
#
# **Explanation**
#
# ```text
# -17 / 5 = -3.4
#
# Floor Value = -4
# ```
#
# ---
#
# ##### 6. Division vs Floor Division
#
# Understanding the difference between `/` and `//` is important.
#
# | Expression | Result |
# |------------|--------|
# | `17 / 5` | `3.4` |
# | `17 // 5` | `3` |
# | `17.0 // 5` | `3.0` |
# | `-17 // 5` | `-4` |
#
# ---
#
# ##### 7. Practical Examples
#
# Apply the Floor Division operator through practical programming examples.
#
# Examples include:
#
# - Finding the number of complete groups
# - Pagination calculations
# - Calculating completed hours
# - Packet distribution
# - Inventory allocation
# - Seating arrangement
#
# ---
#
# ##### 8. Common Use Cases
#
# The Floor Division operator is commonly used in:
#
# - Inventory management
# - Resource allocation
# - Page numbering
# - Batch processing
# - Ticket booking systems
# - Manufacturing software
# - Data processing
#
# **Example**
#
# ```python
# students = 47
# students_per_bus = 10
#
# buses = students // students_per_bus
#
# print(buses)
# ```
#
# ##### Output
#
# ```text
# 4
# ```
#
# > **Note:** This calculates the number of **completely filled buses**. One additional bus would still be required for the remaining students.
#
# ---
#
# ##### 9. Common Mistakes
#
# Avoid these common mistakes while using the Floor Division operator.
#
# ##### Confusing `//` with `/`
#
# **Example**
#
# ```python
# print(10 / 3)
# print(10 // 3)
# ```
#
# ##### Output
#
# ```text
# 3.3333333333333335
# 3
# ```
#
# ---
#
# ##### Ignoring Negative Numbers
#
# **Example**
#
# ```python
# print(-10 // 3)
# ```
#
# ##### Output
#
# ```text
# -4
# ```
#
# > **Why?** Python rounds the result **down** (toward negative infinity), not toward zero.
#
# ---
#
# ##### Dividing by Zero
#
# **Incorrect**
#
# ```python
# print(15 // 0)
# ```
#
# ##### Output
#
# ```text
# ZeroDivisionError: integer division or modulo by zero
# ```
#
# ---
#
# ##### 10. Best Practices
#
# Follow these recommended practices when using the Floor Division operator.
#
# - Use `//` when only the whole-number quotient is required.
# - Use `/` when decimal precision is needed.
# - Be careful when working with negative numbers.
# - Always check that the divisor is not zero.
# - Use meaningful variable names for readability.
#
# ---
#
# #### 📊 Summary
#
# | Feature | Description |
# |---------|-------------|
# | Operator | `//` |
# | Category | Arithmetic Operator |
# | Purpose | Divides two operands and returns the floor value of the quotient |
# | Works With | `int`, `float` |
# | Returns | Whole-number quotient (or `float` if operands include a float) |
# | Division by Zero | Raises `ZeroDivisionError` |
#
# ---
#
# > **Note:** The Floor Division (`//`) operator is useful when only the **whole-number quotient** is needed, such as counting complete groups, allocating resources, or processing data in fixed-size batches. Understanding the difference between `/` and `//` is essential for writing accurate Python programs.

# %%
# Floor Division
a = 10
b = 3

result = a // b
print(result)
# Out:
# 3

# %%
# Exact Floor Division
a = 20
b = 5

result = a // b
print(result)
# Out:
# 4

# %%
# Floating-Point Floor Division
a = 10.0
b = 3.0

result = a // b
print(result)
# Out:
# 3.0

# %%
# Checking Type
result = 10 // 3

print(result)
print(type(result))
# Out:
# 3
# <class 'int'>

# %%
# Division with Remainder
a = 17
b = 5

result = a // b
print(result)
# Out:
# 3

# %%
# Division vs Floor Division
a = 17
b = 5

print(a / b)
print(a // b)
# Out:
# 3.4
# 3

# %%
# Positive Numbers

print(10 // 3)
print(20 // 6)
print(25 // 4)
# Out:
# 3
# 3
# 6

# %%
# Negative Dividend
a = -10
b = 3

result = a // b
print(result)
# Out:
# -4

# %%
# Negative Divisor
a = 10
b = -3

result = a // b
print(result)
# Out:
# -4

# %%
# Both Negative
a = -10
b = -3

result = a // b
print(result)
# Out:
# 3

# %%
# Floor Division by Zero
a = 10
b = 0

# print(a // b)

# %%
# Floor Division Assignment
number = 17
number //= 5

print(number)
# Out:
# 3

# %%
# Variables
total_items = 25
items_per_box = 4

boxes = total_items // items_per_box
print(boxes)
# Out:
# 6

# %%
# Complete Groups
students = 28
students_per_group = 5

groups = students // students_per_group
print(groups)
# Out:
# 5

# %%
# Hours from Minutes
minutes = 135

hours = minutes // 60
print(hours)
# Out:
# 2

# %%
# Hours and Remaining Minutes
minutes = 135

hours = minutes // 60
remaining_minutes = minutes % 60

print(hours)
print(remaining_minutes)
# Out:
# 2
# 15

# %%
# Floor Division in a Loop
number = 100

for i in range(3):
    number = number // 2
    print(number)
# Out:
# 50
# 25
# 12

# %%
# Operator Precedence
result = 10 + 20 // 5

print(result)
# Out:
# 14

# %%
# Parentheses
result = (10 + 20) // 5

print(result)
# Out:
# 6

# %%
result = 10 + 20 // 5

print(result)
# Out:
# 14

# %%
# Boolean Values

print(True // 2)
print(False // 2)
# Out:
# 0
# 0

# %%
# Complex Numbers
a = 10 + 5j
b = 2 + 1j

# print(a // b)

# %%
# Floor Division and Modulus
a = 17
b = 5

quotient = a // b
remainder = a % b

print(quotient)
print(remainder)
# Out:
# 3
# 2

# %% [markdown]
# | Operator | Name           | `17` and `5` | Result |
# | -------- | -------------- | ------------ | -----: |
# | `/`      | Division       | `17 / 5`     |  `3.4` |
# | `//`     | Floor Division | `17 // 5`    |    `3` |
# | `%`      | Modulus        | `17 % 5`     |    `2` |
