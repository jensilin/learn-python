# %% [markdown]
# #### ⬆️ Exponentiation Operator (`**`)
#
# The **Exponentiation (`**`) operator** is an arithmetic operator in Python used to **raise a number to the power of another number**.
#
# It calculates the result of a **base** raised to an **exponent**. The Exponentiation operator is commonly used in mathematics, scientific computing, engineering, finance, data analysis, and machine learning.
#
# The operator works with **integers (`int`)**, **floating-point numbers (`float`)**, and **complex numbers (`complex`)**.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Exponentiation operator is.
# - Syntax of the Exponentiation operator.
# - How exponentiation works.
# - Exponentiation with different numeric data types.
# - Practical programming examples.
# - Common real-world applications.
# - Common mistakes.
# - Best practices.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# base = 2
# power = 5
#
# print(base ** power)
# ```
#
# ##### Output
#
# ```text
# 32
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Exponentiation Operator
#
# The Exponentiation operator (`**`) raises one number (the base) to the power of another number (the exponent).
#
# **Example**
#
# ```python
# print(3 ** 4)
# ```
#
# ##### Output
#
# ```text
# 81
# ```
#
# **Explanation**
#
# ```text
# 3 × 3 × 3 × 3 = 81
# ```
#
# ---
#
# ##### 2. Syntax
#
# ##### Syntax
#
# ```python
# base ** exponent
# ```
#
# ##### Explanation
#
# - `base` → The number to be raised.
# - `**` → Exponentiation operator.
# - `exponent` → The power.
#
# The result is the value of the base raised to the given exponent.
#
# ---
#
# ##### 3. Exponentiation with Integers
#
# The operator works with integer values.
#
# **Example**
#
# ```python
# a = 5
# b = 3
#
# print(a ** b)
# ```
#
# ##### Output
#
# ```text
# 125
# ```
#
# ---
#
# ##### 4. Exponentiation with Floating-Point Numbers
#
# The Exponentiation operator also works with decimal values.
#
# **Example**
#
# ```python
# a = 2.5
# b = 2
#
# print(a ** b)
# ```
#
# ##### Output
#
# ```text
# 6.25
# ```
#
# ---
#
# ##### 5. Exponentiation with Complex Numbers
#
# The operator also supports complex numbers.
#
# **Example**
#
# ```python
# a = 2 + 1j
# b = 2
#
# print(a ** b)
# ```
#
# ##### Output
#
# ```text
# (3+4j)
# ```
#
# ---
#
# ##### 6. Special Cases
#
# ##### Power of Zero
#
# ```python
# print(10 ** 0)
# ```
#
# ##### Output
#
# ```text
# 1
# ```
#
# ---
#
# ##### Power of One
#
# ```python
# print(10 ** 1)
# ```
#
# ##### Output
#
# ```text
# 10
# ```
#
# ---
#
# ##### Zero Raised to a Positive Power
#
# ```python
# print(0 ** 5)
# ```
#
# ##### Output
#
# ```text
# 0
# ```
#
# ---
#
# ##### Fractional Exponents
#
# Fractional exponents can be used to calculate roots.
#
# ```python
# print(16 ** 0.5)
# ```
#
# ##### Output
#
# ```text
# 4.0
# ```
#
# ---
#
# ```python
# print(27 ** (1/3))
# ```
#
# ##### Output
#
# ```text
# 3.0
# ```
#
# > **Note:** Due to floating-point precision, some results may be slightly different (for example, `3.0000000000000004`).
#
# ---
#
# ##### 7. Practical Examples
#
# Apply the Exponentiation operator through practical programming examples.
#
# Examples include:
#
# - Square calculation
# - Cube calculation
# - Area calculation
# - Compound interest
# - Scientific formulas
# - Machine learning algorithms
#
# ---
#
# ##### 8. Common Use Cases
#
# The Exponentiation operator is commonly used in:
#
# - Scientific computing
# - Engineering calculations
# - Financial applications
# - Artificial Intelligence
# - Machine Learning
# - Cryptography
# - Physics simulations
# - Mathematics
#
# **Example**
#
# ```python
# radius = 7
#
# area = 3.14159 * (radius ** 2)
#
# print(area)
# ```
#
# ##### Output
#
# ```text
# 153.93791
# ```
#
# ---
#
# ##### 9. Common Mistakes
#
# Avoid these common mistakes while using the Exponentiation operator.
#
# ##### Confusing `^` with `**`
#
# **Incorrect**
#
# ```python
# print(2 ^ 3)
# ```
#
# ##### Output
#
# ```text
# 1
# ```
#
# > **Why?** The `^` operator performs a **bitwise XOR**, not exponentiation.
#
# ---
#
# ##### Correct
#
# ```python
# print(2 ** 3)
# ```
#
# ##### Output
#
# ```text
# 8
# ```
#
# ---
#
# ##### Large Exponents
#
# Very large exponents can produce extremely large numbers or take longer to compute.
#
# ```python
# print(2 ** 100)
# ```
#
# ##### Output
#
# ```text
# 1267650600228229401496703205376
# ```
#
# ---
#
# ##### 10. Best Practices
#
# Follow these recommended practices when using the Exponentiation operator.
#
# - Use `**` instead of repeated multiplication.
# - Use parentheses in complex expressions.
# - Be aware of floating-point precision with fractional powers.
# - Use meaningful variable names.
# - Avoid unnecessarily large exponents when possible.
#
# ---
#
# #### 📊 Summary
#
# | Feature | Description |
# |---------|-------------|
# | Operator | `**` |
# | Category | Arithmetic Operator |
# | Purpose | Raises a number to the power of another |
# | Works With | `int`, `float`, `complex` |
# | Supports Fractional Powers | ✅ |
# | Common Uses | Squares, cubes, roots, scientific calculations |
#
# ---
#
# > **Note:** The Exponentiation (`**`) operator is an essential arithmetic operator for performing power and root calculations. It is widely used in mathematics, engineering, finance, artificial intelligence, and scientific computing, making it a valuable tool for solving real-world computational problems.

# %%
# Exponentiation
a = 2
b = 3

result = a ** b
print(result)
# Out:
# 8

# %%
# Square
number = 5

result = number ** 2
print(result)
# Out:
# 25

# %%
# Cube
number = 4

result = number ** 3
print(result)
# Out:
# 64

# %%
# Power of 1
number = 10

result = number ** 1
print(result)
# Out:
# 10

# %%
# Power of 0
number = 10

result = number ** 0
print(result)
# Out:
# 1

# %%
# Variables
base = 3
exponent = 4

result = base ** exponent
print(result)
# Out:
# 81

# %%
# Floating-Point Base
base = 2.5
exponent = 2

result = base ** exponent
print(result)
# Out:
# 6.25

# %%
# Floating-Point Exponent
base = 16
exponent = 0.5

result = base ** exponent
print(result)
# Out:
# 4.0

# %%
# Negative Base
base = -2
exponent = 4

result = base ** exponent
print(result)
# Out:
# 16

# %%
# Negative Base
base = -2
exponent = 3

result = base ** exponent
print(result)
# Out:
# -8

# %%
# Negative Exponent
base = 2
exponent = -3

result = base ** exponent
print(result)
# Out:
# 0.125

# %%
# Negative Exponent
number = 10

result = number ** -2
print(result)
# Out:
# 0.01

# %%
# Exponentiation Assignment
number = 5

number **= 2
print(number)
# Out:
# 25

# %%
# User Input
base = int(input("Enter the base: "))
exponent = int(input("Enter the exponent: "))

result = base ** exponent
print(result)
# Out:
# 25

# %%
# Square Root
number = 25
result = number ** 0.5

print(result)
# Out:
# 5.0

# %%
# Cube Root
number = 27
result = number ** (1 / 3)

print(result)
# Out:
# 3.0

# %%
# Complex Number Exponentiation
number = 2 + 3j
result = number ** 2

print(result)
# Out:
# (-5+12j)

# %%
# Exponentiation in a Loop

for number in range(1, 6):
    print(number ** 2)
# Out:
# 1
# 4
# 9
# 16
# 25

# %%
# Powers of 2

for exponent in range(1, 6):
    print(2 ** exponent)
# Out:
# 2
# 4
# 8
# 16
# 32

# %%
# Operator Precedence

result = 2 + 3 ** 2
print(result)
# Out:
# 11

# %%
# Parentheses

result = (2 + 3) ** 2
print(result)
# Out:
# 25

# %%
result = 2 + 3 ** 2
print(result)
# Out:
# 11

# %%
# Chained Exponentiation

result = 2 ** 3 ** 2
print(result)
# Out:
# 512

# %%
# Exponentiation and Multiplication

result = 2 * 3 ** 2
print(result)
# Out:
# 18

# %%
# Compound Growth

principal = 1000
rate = 0.05
years = 2

amount = principal * (1 + rate) ** years
print(amount)
# Out:
# 1102.5

# %%
# Area of a Square
side = 5
area = side ** 2

print(area)
# Out:
# 25

# %%
# Volume of a Cube
side = 4
volume = side ** 3

print(volume)
# Out:
# 64

# %% [markdown]
# | Expression    | Meaning          | Result |
# | ------------- | ---------------- | -----: |
# | `5 ** 2`      | Square           |   `25` |
# | `5 ** 3`      | Cube             |  `125` |
# | `5 ** 0`      | Power of zero    |    `1` |
# | `5 ** -2`     | Reciprocal power | `0.04` |
# | `25 ** 0.5`   | Square root      |  `5.0` |
# | `27 ** (1/3)` | Cube root        |  `3.0` |
