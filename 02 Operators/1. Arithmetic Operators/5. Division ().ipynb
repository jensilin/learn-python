# %% [markdown]
# <h4>Division Operators</h4>
#
# <p>
# Division operators are used to perform <b>division</b> between numeric operands. Python provides three types of division operators:
# </p>
#
# <ol>
#     <li><b>True Division</b> (<code>/</code>)</li>
#     <li><b>Floor Division</b> (<code>//</code>)</li>
#     <li><b>Modulus</b> (<code>%</code>)</li>
# </ol>

# %% [markdown]
# #### ➗ Division Operator (`/`)
#
# The **Division (`/`) operator** is an arithmetic operator in Python used to **divide one number by another**. It returns the quotient of the division.
#
# Unlike some programming languages, the Division operator in Python **always returns a floating-point (`float`) value**, even when the result is a whole number.
#
# The Division operator works with **integers (`int`)**, **floating-point numbers (`float`)**, and **complex numbers (`complex`)** (except division by zero).
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Division operator is.
# - Syntax of the Division operator.
# - Division with different numeric data types.
# - Division by zero.
# - Practical programming examples.
# - Common real-world applications.
# - Common mistakes.
# - Best practices.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# a = 20
# b = 5
#
# print(a / b)
# ```
#
# ##### Output
#
# ```text
# 4.0
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Division Operator
#
# The Division operator (`/`) divides the first operand by the second operand.
#
# The result is **always a floating-point number**, regardless of whether the operands are integers or floats.
#
# **Example**
#
# ```python
# x = 15
# y = 3
#
# print(x / y)
# ```
#
# ##### Output
#
# ```text
# 5.0
# ```
#
# ---
#
# ##### 2. Syntax
#
# ##### Syntax
#
# ```python
# operand1 / operand2
# ```
#
# ##### Explanation
#
# - `operand1` → Dividend (number being divided).
# - `/` → Division operator.
# - `operand2` → Divisor (number used for division).
#
# The result is the quotient.
#
# ---
#
# ##### 3. Division with Integers
#
# Integer division using `/` always produces a float.
#
# **Example**
#
# ```python
# a = 18
# b = 4
#
# print(a / b)
# ```
#
# ##### Output
#
# ```text
# 4.5
# ```
#
# ---
#
# ##### 4. Division with Floating-Point Numbers
#
# The Division operator works with decimal values.
#
# **Example**
#
# ```python
# a = 15.5
# b = 2.5
#
# print(a / b)
# ```
#
# ##### Output
#
# ```text
# 6.2
# ```
#
# ---
#
# ##### 5. Division with Complex Numbers
#
# The Division operator also supports complex numbers.
#
# **Example**
#
# ```python
# a = 4 + 2j
# b = 1 + 1j
#
# print(a / b)
# ```
#
# ##### Output
#
# ```text
# (3-1j)
# ```
#
# ---
#
# ##### 6. Division by Zero
#
# Division by zero is not allowed in Python.
#
# Attempting to divide by zero raises a **ZeroDivisionError**.
#
# **Example**
#
# ```python
# print(10 / 0)
# ```
#
# ##### Output
#
# ```text
# ZeroDivisionError: division by zero
# ```
#
# ---
#
# ##### 7. Practical Examples
#
# Apply the Division operator through practical programming examples.
#
# Examples include:
#
# - Calculating average marks
# - Speed calculation
# - Unit conversion
# - Percentage calculation
# - Price per item
# - Scientific calculations
#
# ---
#
# ##### 8. Common Use Cases
#
# The Division operator is commonly used in:
#
# - Financial applications
# - Statistical analysis
# - Scientific computing
# - Engineering calculations
# - Data analysis
# - Machine learning
# - Business reporting
#
# **Example**
#
# ```python
# total_marks = 450
# subjects = 5
#
# average = total_marks / subjects
#
# print(average)
# ```
#
# ##### Output
#
# ```text
# 90.0
# ```
#
# ---
#
# ##### 9. Common Mistakes
#
# Avoid these common mistakes while using the Division operator.
#
# ##### Dividing by Zero
#
# **Incorrect**
#
# ```python
# number = 25
#
# print(number / 0)
# ```
#
# ##### Output
#
# ```text
# ZeroDivisionError
# ```
#
# ---
#
# ##### Expecting an Integer Result
#
# **Example**
#
# ```python
# print(10 / 2)
# ```
#
# ##### Output
#
# ```text
# 5.0
# ```
#
# > **Note:** Even though the mathematical result is `5`, Python returns `5.0` because the `/` operator always performs true division.
#
# ---
#
# ##### 10. Best Practices
#
# Follow these recommended practices when using the Division operator.
#
# - Always check that the divisor is not zero.
# - Use `/` when a floating-point result is expected.
# - Use `//` (Floor Division) when an integer quotient is required.
# - Use meaningful variable names.
# - Keep expressions simple and readable.
#
# ---
#
# #### 📊 Summary
#
# | Feature | Description |
# |---------|-------------|
# | Operator | `/` |
# | Category | Arithmetic Operator |
# | Purpose | Divides one operand by another |
# | Works With | `int`, `float`, `complex` |
# | Returns | `float` (or `complex` for complex operands) |
# | Division by Zero | Raises `ZeroDivisionError` |
#
# ---
#
# > **Note:** The Division (`/`) operator performs **true division** in Python, always returning a floating-point result. Understanding this behavior is essential before learning **Floor Division (`//`)**, which returns the integer quotient by discarding the fractional part.

# %%
# Division
a = 10
b = 5

result = a / b
print(result)
# Out:
# 2.0

# %%
# Division
a = 20
b = 4

print(a / b)
# Out:
# 5.0

# %%
# Floating-Point Division
a = 10.5
b = 2.5

result = a / b
print(result)
# Out:
# 4.2

# %%
# Division returns float
a = 10
b = 2

result = a / b
print(result)
print(type(result))
# Out:
# 5.0
# <class 'float'>

# %%
# Division with Remainder
a = 10
b = 3

result = a / b
print(result)
# Out:
# 3.3333333333333335

# %%
# Division by 1
number = 100

result = number / 1
print(result)
# Out:
# 100.0

# %%
# Division by Decimal
a = 10
b = 0.5

result = a / b
print(result)
# Out:
# 20.0

# %%
# Negative Division
a = -10
b = 2

result = a / b
print(result)
# Out:
# -5.0

# %%
# Negative / Negative
a = -10
b = -2

result = a / b
print(result)
# Out:
# 5.0

# %%
# Positive / Negative
a = 10
b = -2

result = a / b
print(result)
# Out:
# -5.0

# %%
# Variables
total_marks = 450
number_of_subjects = 5

average = total_marks / number_of_subjects
print(average)
# Out:
# 90.0

# %%
# User Input
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

result = a / b
print(result)
# Out:
# 1.4285714285714286

# %%
# Decimal Input
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

result = a / b
print(result)
# Out:
# 0.015512355193158654

# %%
# Division Assignment
number = 20
number /= 4

print(number)
# Out:
# 5.0

# %%
number = number / 4

# %%
# Division in a Loop
number = 100

for value in range(1, 5):
    number = number / 2
    print(number)
# Out:
# 50.0
# 25.0
# 12.5
# 6.25

# %%
# Complex Number Division
a = 10 + 5j
b = 2 + 1j

result = a / b
print(result)
# Out:
# (5+0j)

# %%
# Division by Zero
a = 10
b = 0

# print(a / b)

# %%
# Checking for Zero
a = 10
b = 0

if b != 0:
    print(a / b)
else:
    print("Cannot divide by zero")
# Out:
# Cannot divide by zero

# %%
# Average
mark1 = 80
mark2 = 90
mark3 = 70

average = (mark1 + mark2 + mark3) / 3
print(average)
# Out:
# 80.0

# %%
# Percentage
obtained_marks = 450
total_marks = 500

percentage = (obtained_marks / total_marks) * 100
print(percentage)
# Out:
# 90.0

# %%
# Division
print(10 / 3)

# Floor Division
print(10 // 3)
# Out:
# 3.3333333333333335
# 3

# %%
# Operator Precedence
result = 20 + 10 / 2

print(result)
# Out:
# 25.0

# %%
# Parentheses
result = (20 + 10) / 2

print(result)
# Out:
# 15.0

# %% [markdown]
# | Expression |              Result |
# | ---------- | ------------------: |
# | `10 / 2`   |               `5.0` |
# | `10 / 3`   |          `3.333...` |
# | `20 / 4`   |               `5.0` |
# | `10 / 0`   | `ZeroDivisionError` |
# | `-10 / 2`  |              `-5.0` |
# | `-10 / -2` |               `5.0` |
