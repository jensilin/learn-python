# %% [markdown]
# #### ⬆️ Exponent Assignment Operator (`**=`)
#
# The **Exponent Assignment (`**=`) operator** is a compound assignment operator in Python used to **raise a variable to a specified power and assign the updated result back to the same variable**.
#
# Instead of writing `x = x ** value`, you can write `x **= value`, making your code shorter, cleaner, and easier to read.
#
# The Exponent Assignment operator works with **integers (`int`)**, **floating-point numbers (`float`)**, and **complex numbers (`complex`)**.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Exponent Assignment operator is.
# - Syntax of the Exponent Assignment operator.
# - How it works.
# - Using `**=` with different numeric data types.
# - Practical programming examples.
# - Common real-world applications.
# - Common mistakes.
# - Best practices.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# number = 5
#
# number **= 2
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 25
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Exponent Assignment Operator
#
# The Exponent Assignment operator (`**=`) raises the current value of a variable to a specified power and stores the result back in the same variable.
#
# Instead of writing:
#
# ```python
# number = number ** 2
# ```
#
# you can simply write:
#
# ```python
# number **= 2
# ```
#
# Both statements produce the same result.
#
# ---
#
# ##### 2. Syntax
#
# ##### Syntax
#
# ```python
# variable **= value
# ```
#
# ##### Equivalent To
#
# ```python
# variable = variable ** value
# ```
#
# ##### Explanation
#
# - `variable` → Variable whose value will be updated.
# - `**=` → Exponent Assignment operator.
# - `value` → Power (exponent).
#
# ---
#
# ##### 3. Exponent Assignment with Integers
#
# The operator works with integer values.
#
# **Example**
#
# ```python
# number = 4
#
# number **= 3
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 64
# ```
#
# ---
#
# ##### 4. Exponent Assignment with Floating-Point Numbers
#
# The operator also works with floating-point numbers.
#
# **Example**
#
# ```python
# value = 2.5
#
# value **= 2
#
# print(value)
# ```
#
# ##### Output
#
# ```text
# 6.25
# ```
#
# ---
#
# ##### 5. Exponent Assignment with Complex Numbers
#
# The operator supports complex numbers.
#
# **Example**
#
# ```python
# number = 2 + 1j
#
# number **= 2
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# (3+4j)
# ```
#
# ---
#
# ##### 6. Using Fractional Powers
#
# Fractional exponents can be used to calculate roots.
#
# **Example**
#
# ```python
# number = 16
#
# number **= 0.5
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 4.0
# ```
#
# ---
#
# ##### 7. Practical Examples
#
# Apply the Exponent Assignment operator through practical programming examples.
#
# ##### Example 1: Calculate the Square of a Number
#
# ```python
# length = 12
#
# length **= 2
#
# print(length)
# ```
#
# ##### Output
#
# ```text
# 144
# ```
#
# ---
#
# ##### Example 2: Calculate the Cube of a Number
#
# ```python
# number = 5
#
# number **= 3
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 125
# ```
#
# ---
#
# ##### Example 3: Calculate Compound Growth
#
# ```python
# investment = 2
#
# investment **= 5
#
# print(investment)
# ```
#
# ##### Output
#
# ```text
# 32
# ```
#
# ---
#
# ##### 8. Common Use Cases
#
# The Exponent Assignment operator is commonly used in:
#
# - Mathematical calculations
# - Scientific computing
# - Engineering applications
# - Financial modeling
# - Machine learning
# - Physics simulations
# - Cryptography
# - Data analysis
#
# ---
#
# ##### 9. Common Mistakes
#
# Avoid these common mistakes while using the Exponent Assignment operator.
#
# ##### Using an Uninitialized Variable
#
# **Incorrect**
#
# ```python
# number **= 2
# ```
#
# ##### Output
#
# ```text
# NameError
# ```
#
# **Correct**
#
# ```python
# number = 5
#
# number **= 2
# ```
#
# ---
#
# ##### Confusing `^=` with `**=`
#
# ```python
# number = 2
#
# number ^= 3
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 1
# ```
#
# > **Why?** `^=` performs a **Bitwise XOR Assignment**, not exponentiation.
#
# Correct:
#
# ```python
# number = 2
#
# number **= 3
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 8
# ```
#
# ---
#
# ##### Using Very Large Exponents
#
# ```python
# number = 2
#
# number **= 100
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 1267650600228229401496703205376
# ```
#
# > **Note:** Very large exponents can produce extremely large numbers and may increase computation time.
#
# ---
#
# ##### 10. Best Practices
#
# Follow these recommended practices when using the Exponent Assignment operator.
#
# - Initialize variables before using `**=`.
# - Use `**=` instead of `variable = variable ** value` for cleaner code.
# - Be careful with very large exponents.
# - Use meaningful variable names.
# - Follow Python style guidelines by adding spaces around operators.
#
# ---
#
# #### 📊 Summary
#
# | Feature | Description |
# |---------|-------------|
# | Operator | `**=` |
# | Category | Assignment Operator |
# | Purpose | Raises a value to a power and assigns the result back to the variable |
# | Equivalent To | `variable = variable ** value` |
# | Works With | `int`, `float`, `complex` |
# | Supports Fractional Powers | ✅ Yes |
# | Common Uses | Mathematical formulas, scientific computing, financial calculations, machine learning |
#
# ---
#
# > **Note:** The Exponent Assignment (`**=`) operator combines exponentiation and assignment into a single statement, making code more concise and readable. It is especially useful in mathematical, scientific, engineering, and financial applications where values are repeatedly raised to a power.

# %%
# Exponent Assignment
number = 2
number **= 3

print(number)
# Out:
# 8

# %%
# Squaring
number = 5
number **= 2

print(number)
# Out:
# 25

# %%
# Cubing
number = 4
number **= 3

print(number)
# Out:
# 64

# %%
# Power of 1
number = 100
number **= 1

print(number)
# Out:
# 100

# %%
# Power of 0
number = 100
number **= 0

print(number)
# Out:
# 1

# %%
# Negative Exponent
number = 2
number **= -2

print(number)
# Out:
# 0.25

# %%
# Variables
number = 3
power = 4

number **= power
print(number)
# Out:
# 81

# %%
# Multiple Exponent Assignments
number = 2

number **= 3
number **= 2

print(number)
# Out:
# 64

# %%
# Float

number = 4.0
number **= 2

print(number)
# Out:
# 16.0

# %%
# Square Root

number = 16
number **= 0.5

print(number)
# Out:
# 4.0

# %%
# Cube Root

number = 27
number **= (1 / 3)

print(number)
# Out:
# 3.0

# %%
# User Input

number = int(input("Enter a number: "))
power = int(input("Enter the power: "))

number **= power
print(number)
# Out:
# 4356

# %%
# Loop
number = 2

for i in range(3):
    number **= 2
    
print(number)
# Out:
# 256

# %%
# Expression

number = 2
number **= 2 + 1

print(number)
# Out:
# 8

# %%
# Expression

number = 2
number **= 2 * 2

print(number)
# Out:
# 16

# %%
# Variable Power
base = 5
power = 2

base **= power

print(base)
# Out:
# 25

# %%
# Conditional
number = 5

if number > 0:
    number **= 2

print(number)
# Out:
# 25

# %%
# Area of a Square
side = 5

area = side
area **= 2

print(area)
# Out:
# 25

# %%
# Volume of a Cube
side = 4

volume = side
volume **= 3

print(volume)
# Out:
# 64

# %%
# Compound Growth

amount = 2
amount **= 3

print(amount)
# Out:
# 8

# %%
# Exponentiation

number = 2
result = number ** 3

print(number)
print(result)
# Out:
# 2
# 8

# %%
# Negative Base

number = -2
number **= 3

print(number)
# Out:
# -8

# %%
# Even Power

number = -2
number **= 2

print(number)
# Out:
# 4

# %%
# Fractional Base

number = 0.5
number **= 2

print(number)
# Out:
# 0.25

# %%
# Result Type

number = 2
number **= 3

print(number)
print(type(number))
# Out:
# 8
# <class 'int'>

# %%
number = 2
number **= -2

print(number)
print(type(number))
# Out:
# 0.25
# <class 'float'>

# %%
# Large Power

number = 10
number **= 6

print(number)
# Out:
# 1000000

# %%
# Exponential Growth
value = 2

for i in range(4):
    value **= 2
print(value)
# Out:
# 65536

# %%
number = 2
number **= 3

print(number)
# Out:
# 8

# %% [markdown]
# | Expression  | Equivalent     | Meaning                      |
# | ----------- | -------------- | ---------------------------- |
# | `x **= 2`   | `x = x ** 2`   | Square                       |
# | `x **= 3`   | `x = x ** 3`   | Cube                         |
# | `x **= 1`   | `x = x ** 1`   | No numeric change            |
# | `x **= 0`   | `x = x ** 0`   | Becomes `1` for non-zero `x` |
# | `x **= -2`  | `x = x ** -2`  | Reciprocal of square         |
# | `x **= 0.5` | `x = x ** 0.5` | Square root                  |
