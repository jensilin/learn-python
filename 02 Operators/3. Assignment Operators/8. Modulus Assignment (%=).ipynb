# %% [markdown]
# #### 🧮 Modulus Assignment Operator (`%=`)
#
# The **Modulus Assignment (`%=`) operator** is a compound assignment operator in Python used to **find the remainder after division and assign the result back to the same variable**.
#
# Instead of writing `x = x % value`, you can write `x %= value`, making your code shorter, cleaner, and easier to read.
#
# The Modulus Assignment operator works with **integers (`int`)** and **floating-point numbers (`float`)**. It is commonly used for checking divisibility, cyclic operations, time calculations, and remainder-based algorithms.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Modulus Assignment operator is.
# - Syntax of the Modulus Assignment operator.
# - How it works.
# - Using `%=` with integers and floating-point numbers.
# - Practical programming examples.
# - Common real-world applications.
# - Common mistakes.
# - Best practices.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# number = 17
#
# number %= 5
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 2
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Modulus Assignment Operator
#
# The Modulus Assignment operator (`%=`) finds the remainder after dividing the current value of a variable by another value and stores the result back in the same variable.
#
# Instead of writing:
#
# ```python
# number = number % 5
# ```
#
# you can simply write:
#
# ```python
# number %= 5
# ```
#
# Both statements produce the same result.
#
# ---
#
# ##### 2. Syntax
#
# ##### Syntax
#
# ```python
# variable %= value
# ```
#
# ##### Equivalent To
#
# ```python
# variable = variable % value
# ```
#
# ##### Explanation
#
# - `variable` → Variable whose value will be updated.
# - `%=` → Modulus Assignment operator.
# - `value` → Value used as the divisor.
#
# ---
#
# ##### 3. Modulus Assignment with Integers
#
# The operator works with integer values.
#
# **Example**
#
# ```python
# number = 29
#
# number %= 6
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 5
# ```
#
# ---
#
# ##### 4. Modulus Assignment with Floating-Point Numbers
#
# The operator also works with floating-point numbers.
#
# **Example**
#
# ```python
# value = 10.5
#
# value %= 3
#
# print(value)
# ```
#
# ##### Output
#
# ```text
# 1.5
# ```
#
# ---
#
# ##### 5. Modulus Assignment with Negative Numbers
#
# Python calculates the remainder so that the result has the **same sign as the divisor**.
#
# **Example**
#
# ```python
# number = -17
#
# number %= 5
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 3
# ```
#
# ---
#
# ##### 6. Practical Examples
#
# Apply the Modulus Assignment operator through practical programming examples.
#
# ##### Example 1: Remaining Students
#
# ```python
# students = 53
#
# students %= 10
#
# print(students)
# ```
#
# ##### Output
#
# ```text
# 3
# ```
#
# ---
#
# ##### Example 2: Remaining Minutes
#
# ```python
# minutes = 135
#
# minutes %= 60
#
# print(minutes)
# ```
#
# ##### Output
#
# ```text
# 15
# ```
#
# ---
#
# ##### Example 3: Cyclic Counter
#
# ```python
# counter = 17
#
# counter %= 5
#
# print(counter)
# ```
#
# ##### Output
#
# ```text
# 2
# ```
#
# ---
#
# ##### 7. Common Use Cases
#
# The Modulus Assignment operator is commonly used in:
#
# - Even and odd number checking
# - Divisibility tests
# - Time calculations
# - Cyclic counters
# - Circular buffers
# - Hashing algorithms
# - Scheduling systems
# - Game development
#
# ---
#
# ##### 8. Common Mistakes
#
# Avoid these common mistakes while using the Modulus Assignment operator.
#
# ##### Using an Uninitialized Variable
#
# **Incorrect**
#
# ```python
# number %= 5
# ```
#
# ##### Output
#
# ```text
# NameError
# ```
#
# **Correct**
#
# ```python
# number = 20
#
# number %= 5
# ```
#
# ---
#
# ##### Dividing by Zero
#
# ```python
# number = 15
#
# number %= 0
# ```
#
# ##### Output
#
# ```text
# ZeroDivisionError
# ```
#
# ---
#
# ##### Confusing `%=` with `/=`
#
# ```python
# number = 17
#
# number /= 5
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 3.4
# ```
#
# Using Modulus Assignment:
#
# ```python
# number = 17
#
# number %= 5
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 2
# ```
#
# ---
#
# ##### Ignoring Negative Number Behavior
#
# ```python
# number = -10
#
# number %= 3
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 2
# ```
#
# > **Why?** Python returns a remainder with the same sign as the divisor.
#
# ---
#
# ##### 9. Best Practices
#
# Follow these recommended practices when using the Modulus Assignment operator.
#
# - Initialize variables before using `%=`.
# - Ensure the divisor is not zero.
# - Use `%=` when only the remainder is required.
# - Be aware of how Python handles negative numbers.
# - Use meaningful variable names.
# - Follow Python style guidelines by adding spaces around operators.
#
# ---
#
# #### 📊 Summary
#
# | Feature | Description |
# |---------|-------------|
# | Operator | `%=` |
# | Category | Assignment Operator |
# | Purpose | Finds the remainder and assigns the result back to the variable |
# | Equivalent To | `variable = variable % value` |
# | Works With | `int`, `float` |
# | Returns | Remainder after division |
# | Division by Zero | Raises `ZeroDivisionError` |
#
# ---
#
# > **Note:** The Modulus Assignment (`%=`) operator combines the modulus operation and assignment into a single statement. It is widely used for remainder calculations, divisibility checks, cyclic operations, time conversions, and many algorithmic problems where efficient remainder handling is required.

# %%
# Modulus Assignment
number = 10
number %= 3

print(number)
# Out:
# 1

# %%
# Exact Division

number = 20
number %= 5

print(number)
# Out:
# 0

# %%
# Remainder

number = 17
number %= 5

print(number)
# Out:
# 2

# %%
# Result Type

number = 17
number %= 5

print(number)
print(type(number))
# Out:
# 2
# <class 'int'>

# %%
# Floating-Point Modulus

number = 10.5
number %= 3

print(number)
# Out:
# 1.5

# %%
# Integer and Float

number = 10
number %= 2.5

print(number)
# Out:
# 0.0

# %%
# Multiple Modulus Assignments
number = 100

number %= 30
number %= 7

print(number)
# Out:
# 3

# %%
# Variables
number = 25
divisor = 4

number %= divisor

print(number)
# Out:
# 1

# %%
# User Input
number = int(input("Enter a number: "))
divisor = int(input("Enter divisor: "))

number %= divisor
print(number)
# Out:
# 14

# %%
# Even or Odd

number = 17
number %= 2

print(number)
# Out:
# 1

# %%
# Loop
number = 100

for divisor in [30, 7, 3]:
    number %= divisor

print(number)
# Out:
# 0

# %%
# Expression

number = 25
number %= 2 + 3

print(number)
# Out:
# 0

# %%
# Expression

number = 27
number %= 2 * 5

print(number)
# Out:
# 7

# %%
# Exponentiation

number = 30
number %= 2 ** 3

print(number)
# Out:
# 6

# %%
# Positive Numbers

number = 25
number %= 4

print(number)
# Out:
# 1

# %%
# Negative Number

number = -10
number %= 3

print(number)
# Out:
# 2

# %%
# Negative Divisor

number = 10
number %= -3

print(number)
# Out:
# -2

# %%
# Both Negative

number = -10
number %= -3

print(number)
# Out:
# -1

# %%
# Modulus

number = 17
result = number % 5

print(number)
print(result)
# Out:
# 17
# 2

# %%
# Modulus Assignment

number = 17
number %= 5

print(number)
# Out:
# 2

# %%
# Counter

number = 10
number %= 3

print(number)
# Out:
# 1

# %%
# Last Digit

number = 12345
number %= 10

print(number)
# Out:
# 5

# %%
# Last Two Digits

number = 12345
number %= 100

print(number)
# Out:
# 45

# %%
# Remaining Items

items = 23
items_per_box = 5

items %= items_per_box
print(items)
# Out:
# 3

# %%
# Remaining Minutes

minutes = 135
minutes %= 60

print(minutes)
# Out:
# 15

# %%
# Hours and Minutes
minutes = 135

hours = minutes // 60
minutes %= 60

print(hours)
print(minutes)
# Out:
# 2
# 15

# %%
# Divisibility
number = 25
number %= 5

if number == 0:
    print("Divisible by 5")
else:
    print("Not divisible by 5")
# Out:
# Divisible by 5

# %%
# Clock Cycle

hour = 27
hour %= 24

print(hour)
# Out:
# 3

# %%
# Modulus by Zero
number = 10

# number %= 0

# %%
# Safe Modulus
number = 10
divisor = 0

if divisor != 0:
    number %= divisor
    print(number)
else:
    print("Cannot calculate remainder with zero")
# Out:
# Cannot calculate remainder with zero

# %% [markdown]
# | Expression | Equivalent    | Meaning                               |
# | ---------- | ------------- | ------------------------------------- |
# | `x %= 5`   | `x = x % 5`   | Store remainder after dividing by `5` |
# | `x %= 2`   | `x = x % 2`   | Find remainder after dividing by `2`  |
# | `x %= 10`  | `x = x % 10`  | Extract last digit                    |
# | `x %= 100` | `x = x % 100` | Extract last two digits               |
