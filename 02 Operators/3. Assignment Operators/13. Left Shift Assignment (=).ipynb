# %% [markdown]
# #### ⬅️ Left Shift Assignment Operator (`<<=`)
#
# The **Left Shift Assignment (`<<=`) operator** is a compound assignment operator in Python used to **shift the bits of an integer to the left by a specified number of positions and assign the updated result back to the same variable**.
#
# Instead of writing `x = x << value`, you can write `x <<= value`, making your code shorter, cleaner, and easier to read.
#
# The Left Shift Assignment operator works only with **integer (`int`)** values because bitwise operations are performed on the binary representation of numbers.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Left Shift Assignment operator is.
# - Syntax of the Left Shift Assignment operator.
# - How it works.
# - Binary representation of numbers.
# - Practical programming examples.
# - Common real-world applications.
# - Common mistakes.
# - Best practices.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# number = 5
#
# number <<= 2
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 20
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Left Shift Assignment Operator
#
# The Left Shift Assignment operator (`<<=`) shifts all bits of an integer to the **left** by a specified number of positions and stores the result back in the same variable.
#
# Instead of writing:
#
# ```python
# number = number << 2
# ```
#
# you can simply write:
#
# ```python
# number <<= 2
# ```
#
# Both statements produce the same result.
#
# ---
#
# ##### 2. Syntax
#
# ##### Syntax
#
# ```python
# variable <<= value
# ```
#
# ##### Equivalent To
#
# ```python
# variable = variable << value
# ```
#
# ##### Explanation
#
# - `variable` → Integer variable whose value will be updated.
# - `<<=` → Left Shift Assignment operator.
# - `value` → Number of bit positions to shift.
#
# ---
#
# ##### 3. Understanding Left Shift
#
# A **left shift** moves all bits to the left by the specified number of positions.
#
# For every left shift by **1 position**, the value is approximately multiplied by **2**.
#
# For example:
#
# | Operation | Result |
# |-----------|--------|
# | `5 << 1` | 10 |
# | `5 << 2` | 20 |
# | `5 << 3` | 40 |
#
# ---
#
# ##### 4. Example with Binary Representation
#
# ```python
# number = 5
#
# number <<= 2
#
# print(number)
# ```
#
# ##### Binary Calculation
#
# ```text
# Before Shift
#
# 5 = 00000101
#
# Left Shift by 2
#
# 00010100
# ```
#
# ##### Output
#
# ```text
# 20
# ```
#
# ---
#
# ##### 5. Another Example
#
# ```python
# value = 9
#
# value <<= 1
#
# print(value)
# ```
#
# ##### Binary Calculation
#
# ```text
# 9 = 00001001
#
# Shift Left by 1
#
# 00010010
# ```
#
# ##### Output
#
# ```text
# 18
# ```
#
# ---
#
# ##### 6. Practical Examples
#
# Apply the Left Shift Assignment operator through practical programming examples.
#
# ##### Example 1: Doubling a Value
#
# ```python
# number = 12
#
# number <<= 1
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 24
# ```
#
# ---
#
# ##### Example 2: Multiply by Four
#
# ```python
# value = 7
#
# value <<= 2
#
# print(value)
# ```
#
# ##### Output
#
# ```text
# 28
# ```
#
# ---
#
# ##### Example 3: Allocate Memory Blocks
#
# ```python
# blocks = 8
#
# blocks <<= 3
#
# print(blocks)
# ```
#
# ##### Output
#
# ```text
# 64
# ```
#
# ---
#
# ##### 7. Common Use Cases
#
# The Left Shift Assignment operator is commonly used in:
#
# - Fast multiplication by powers of 2
# - Embedded systems
# - Bit masking
# - Cryptography
# - Device drivers
# - Graphics programming
# - Network programming
# - Operating systems
#
# ---
#
# ##### 8. Common Mistakes
#
# Avoid these common mistakes while using the Left Shift Assignment operator.
#
# ##### Using an Uninitialized Variable
#
# **Incorrect**
#
# ```python
# number <<= 2
# ```
#
# ##### Output
#
# ```text
# NameError
# ```
#
# **Correct**
#
# ```python
# number = 5
#
# number <<= 2
# ```
#
# ---
#
# ##### Using Floating-Point Numbers
#
# ```python
# number = 5.5
#
# number <<= 1
# ```
#
# ##### Output
#
# ```text
# TypeError
# ```
#
# > **Why?** Bitwise shift operators work only with integers.
#
# ---
#
# ##### Using a Negative Shift Count
#
# ```python
# number = 10
#
# number <<= -1
# ```
#
# ##### Output
#
# ```text
# ValueError: negative shift count
# ```
#
# ---
#
# ##### Assuming It Always Means Multiplication
#
# Although left shifting by one position is equivalent to multiplying by 2 for positive integers, the operator actually performs a **bitwise shift**, not arithmetic multiplication.
#
# ```python
# number = 3
#
# number <<= 2
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 12
# ```
#
# ---
#
# ##### 9. Best Practices
#
# Follow these recommended practices when using the Left Shift Assignment operator.
#
# - Use `<<=` only with integer values.
# - Understand binary representation before using shift operators.
# - Avoid negative shift counts.
# - Use meaningful variable names.
# - Add comments when performing bit manipulation.
# - Follow Python style guidelines by adding spaces around operators.
#
# ---
#
# #### 📊 Summary
#
# | Feature | Description |
# |---------|-------------|
# | Operator | `<<=` |
# | Category | Assignment Operator |
# | Purpose | Shifts bits to the left and assigns the result back to the variable |
# | Equivalent To | `variable = variable << value` |
# | Works With | `int` |
# | Shift Direction | Left |
# | Effect | Approximately multiplies by \(2^n\) for positive integers |
#
# ---
#
# > **Note:** The Left Shift Assignment (`<<=`) operator combines the left shift and assignment operations into a single statement. It is commonly used in low-level programming, embedded systems, bit manipulation, and performance-critical applications where efficient binary operations are required.

# %%
# Left Shift Assignment

number = 5
number <<= 1

print(number)

print(
'''
5  = 0101
<< 1
     ↓
10 = 1010
'''
)
# Out:
# 10
#
# 5  = 0101
# << 1
#      ↓
# 10 = 1010

# %%
# Left Shift by 2

number = 5
number <<= 2

print(number)
print(
'''
5  = 0101
<< 2
     ↓
20 = 10100
'''
)
# Out:
# 20
#
# 5  = 0101
# << 2
#      ↓
# 20 = 10100

# %%
# Left Shift by 3

number = 3
number <<= 3

print(number)

print(
'''
3  = 0011
<< 3
     ↓
24 = 11000
'''
)
# Out:
# 24
#
# 3  = 0011
# << 3
#      ↓
# 24 = 11000

# %%
# Left Shift by 0

number = 10
number <<= 0

print(number)
# Out:
# 10

# %%
# Multiple Left Shifts

number = 2

number <<= 1
number <<= 1
number <<= 1

print(number)

print(
'''
2 << 1 = 4
4 << 1 = 8
8 << 1 = 16
'''
)
# Out:
# 16
#
# 2 << 1 = 4
# 4 << 1 = 8
# 8 << 1 = 16

# %%
# Variables

number = 5
positions = 2

number <<= positions
print(number)
# Out:
# 20

# %%
# Binary Representation

number = 5
number <<= 2

print(bin(number))
print(number)
# Out:
# 0b10100
# 20

# %%
# Binary Literals

number = 0b101
number <<= 2

print(bin(number))
print(number)
# Out:
# 0b10100
# 20

# %%
# Hexadecimal

number = 0x05
number <<= 2

print(hex(number))
print(number)
# Out:
# 0x14
# 20

# %%
# Left Shift

number = 5
number <<= 3

print(number)

print(
'''
5 × 2³
= 5 × 8
= 40
'''
)
# Out:
# 40
#
# 5 × 2³
# = 5 × 8
# = 40

# %%
# Left Shift

number = 5
number <<= 2

print(number)
# Out:
# 20

# %%
# Loop

number = 1

for i in range(4):
    number <<= 1
print(number)

print(
'''
1 << 1 = 2
2 << 1 = 4
4 << 1 = 8
8 << 1 = 16
'''
)
# Out:
# 16
#
# 1 << 1 = 2
# 2 << 1 = 4
# 4 << 1 = 8
# 8 << 1 = 16

# %%
# Expression

number = 2
number <<= 1 + 2

print(number)
# Out:
# 16

# %%
# User Input

number = int(input("Enter a number: "))
positions = int(input("Enter number of positions: "))

number <<= positions
print(number)
# Out:
# 396

# %%
# Left Shift by 4

number = 3
number <<= 4

print(number)

print(
'''
3 × 2⁴
= 3 × 16
= 48
'''
)
# Out:
# 48
#
# 3 × 2⁴
# = 3 × 16
# = 48

# %%
# Powers of Two

number = 1
number <<= 5

print(number)
# Out:
# 32

# %%
# Bit Flag

READ = 1 << 0
WRITE = 1 << 1
EXECUTE = 1 << 2

print(READ)
print(WRITE)
print(EXECUTE)

print(
'''
READ    = 0001
WRITE   = 0010
EXECUTE = 0100
'''
)
# Out:
# 1
# 2
# 4
#
# READ    = 0001
# WRITE   = 0010
# EXECUTE = 0100

# %%
# Bit Flag

flag = 1
flag <<= 3

print(flag)

print(
'''
1 = 0001
<< 3
    ↓
8 = 1000
'''
)
# Out:
# 8
#
# 1 = 0001
# << 3
#     ↓
# 8 = 1000

# %%
# Bit Flags

flags = 0

flag = 1
flag <<= 2

flags |= flag
print(flags)

print(
'''
flag = 0100
flags = 0000

0000 | 0100 = 0100
'''
)
# Out:
# 4
#
# flag = 0100
# flags = 0000
#
# 0000 | 0100 = 0100

# %%
# Left Shift

number = 5
result = number << 2

print(number)
print(result)
# Out:
# 5
# 20

# %%
# Left Shift Assignment

number = 5
number <<= 2

print(number)
# Out:
# 20

# %%
# Result Type

number = 5
number <<= 2

print(number)
print(type(number))
# Out:
# 20
# <class 'int'>

# %%
# Negative Number

number = -5
number <<= 1

print(number)
# Out:
# -10

# %%
#ValueError: negative shift count
number = 5

# number <<= -1

# %%
#TypeError
number = 5

# number <<= 2.5

# %%
# Zero

number = 0
number <<= 5

print(number)
# Out:
# 0

# %%
# Large Shift

number = 1
number <<= 10

print(number)
# Out:
# 1024

# %%
# Bit Position

position = 3

value = 1
value <<= position

print(value)
# Out:
# 8

# %%
# Building a Flag

flag = 1
flag <<= 4

print(bin(flag))
print(flag)
# Out:
# 0b10000
# 16

# %% [markdown]
# | Expression | Equivalent   | Meaning         |
# | ---------- | ------------ | --------------- |
# | `x <<= 1`  | `x = x << 1` | Shift left by 1 |
# | `x <<= 2`  | `x = x << 2` | Shift left by 2 |
# | `x <<= 3`  | `x = x << 3` | Shift left by 3 |
# | `x <<= 0`  | `x = x << 0` | No change       |
