# %% [markdown]
# #### ➡️ Right Shift Assignment Operator (`>>=`)
#
# The **Right Shift Assignment (`>>=`) operator** is a compound assignment operator in Python used to **shift the bits of an integer to the right by a specified number of positions and assign the updated result back to the same variable**.
#
# Instead of writing `x = x >> value`, you can write `x >>= value`, making your code shorter, cleaner, and easier to read.
#
# The Right Shift Assignment operator works only with **integer (`int`)** values because bitwise operations are performed on the binary representation of numbers.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Right Shift Assignment operator is.
# - Syntax of the Right Shift Assignment operator.
# - How it works.
# - Binary representation of numbers.
# - Practical programming examples.
# - Common real-world applications.
# - Common mistakes.
# - Best practices.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# number = 20
#
# number >>= 2
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 5
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Right Shift Assignment Operator
#
# The Right Shift Assignment operator (`>>=`) shifts all bits of an integer to the **right** by a specified number of positions and stores the result back in the same variable.
#
# Instead of writing:
#
# ```python
# number = number >> 2
# ```
#
# you can simply write:
#
# ```python
# number >>= 2
# ```
#
# Both statements produce the same result.
#
# ---
#
# ##### 2. Syntax
#
# ##### Syntax
#
# ```python
# variable >>= value
# ```
#
# ##### Equivalent To
#
# ```python
# variable = variable >> value
# ```
#
# ##### Explanation
#
# - `variable` → Integer variable whose value will be updated.
# - `>>=` → Right Shift Assignment operator.
# - `value` → Number of bit positions to shift.
#
# ---
#
# ##### 3. Understanding Right Shift
#
# A **right shift** moves all bits to the right by the specified number of positions.
#
# For positive integers, every right shift by **1 position** is approximately equivalent to dividing the number by **2** and discarding the remainder.
#
# For example:
#
# | Operation | Result |
# |-----------|--------|
# | `20 >> 1` | 10 |
# | `20 >> 2` | 5 |
# | `20 >> 3` | 2 |
#
# ---
#
# ##### 4. Example with Binary Representation
#
# ```python
# number = 20
#
# number >>= 2
#
# print(number)
# ```
#
# ##### Binary Calculation
#
# ```text
# Before Shift
#
# 20 = 00010100
#
# Right Shift by 2
#
# 00000101
# ```
#
# ##### Output
#
# ```text
# 5
# ```
#
# ---
#
# ##### 5. Another Example
#
# ```python
# value = 32
#
# value >>= 3
#
# print(value)
# ```
#
# ##### Binary Calculation
#
# ```text
# 32 = 00100000
#
# Shift Right by 3
#
# 00000100
# ```
#
# ##### Output
#
# ```text
# 4
# ```
#
# ---
#
# ##### 6. Right Shift with Negative Numbers
#
# Python preserves the sign bit when shifting negative integers.
#
# **Example**
#
# ```python
# number = -16
#
# number >>= 2
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# -4
# ```
#
# > **Note:** Python performs an **arithmetic right shift**, preserving the sign of negative numbers.
#
# ---
#
# ##### 7. Practical Examples
#
# Apply the Right Shift Assignment operator through practical programming examples.
#
# ##### Example 1: Halving a Value
#
# ```python
# number = 64
#
# number >>= 1
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 32
# ```
#
# ---
#
# ##### Example 2: Divide by Eight
#
# ```python
# value = 80
#
# value >>= 3
#
# print(value)
# ```
#
# ##### Output
#
# ```text
# 10
# ```
#
# ---
#
# ##### Example 3: Reduce Memory Blocks
#
# ```python
# blocks = 128
#
# blocks >>= 2
#
# print(blocks)
# ```
#
# ##### Output
#
# ```text
# 32
# ```
#
# ---
#
# ##### 8. Common Use Cases
#
# The Right Shift Assignment operator is commonly used in:
#
# - Fast division by powers of 2
# - Embedded systems
# - Bit masking
# - Device drivers
# - Image processing
# - Network programming
# - Operating systems
# - Performance optimization
#
# ---
#
# ##### 9. Common Mistakes
#
# Avoid these common mistakes while using the Right Shift Assignment operator.
#
# ##### Using an Uninitialized Variable
#
# **Incorrect**
#
# ```python
# number >>= 2
# ```
#
# ##### Output
#
# ```text
# NameError
# ```
#
# **Correct**
#
# ```python
# number = 20
#
# number >>= 2
# ```
#
# ---
#
# ##### Using Floating-Point Numbers
#
# ```python
# number = 20.5
#
# number >>= 1
# ```
#
# ##### Output
#
# ```text
# TypeError
# ```
#
# > **Why?** Bitwise shift operators work only with integers.
#
# ---
#
# ##### Using a Negative Shift Count
#
# ```python
# number = 16
#
# number >>= -1
# ```
#
# ##### Output
#
# ```text
# ValueError: negative shift count
# ```
#
# ---
#
# ##### Assuming It Always Means Division
#
# Although right shifting positive integers often behaves like division by powers of 2, it actually performs a **bitwise shift**.
#
# ```python
# number = 18
#
# number >>= 2
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 4
# ```
#
# The mathematical division would be:
#
# ```python
# 18 / 4
# ```
#
# Output:
#
# ```text
# 4.5
# ```
#
# The right shift discards fractional parts because it operates on binary integers.
#
# ---
#
# ##### 10. Best Practices
#
# Follow these recommended practices when using the Right Shift Assignment operator.
#
# - Use `>>=` only with integer values.
# - Understand binary representation before using shift operators.
# - Avoid negative shift counts.
# - Be aware of how Python handles negative numbers.
# - Use meaningful variable names.
# - Add comments when performing bit manipulation.
# - Follow Python style guidelines by adding spaces around operators.
#
# ---
#
# #### 📊 Summary
#
# | Feature | Description |
# |---------|-------------|
# | Operator | `>>=` |
# | Category | Assignment Operator |
# | Purpose | Shifts bits to the right and assigns the result back to the variable |
# | Equivalent To | `variable = variable >> value` |
# | Works With | `int` |
# | Shift Direction | Right |
# | Effect | Approximately divides by \(2^n\) for positive integers |
# | Negative Numbers | Uses arithmetic right shift (preserves sign) |
#
# ---
#
# > **Note:** The Right Shift Assignment (`>>=`) operator combines the right shift and assignment operations into a single statement. It is commonly used in embedded systems, operating systems, bit manipulation, and performance-critical applications where efficient binary operations are required.

# %%
# Right Shift Assignment

number = 20
number >>= 1

print(number)

print(
'''
20 = 10100

10100 >> 1
01010 = 10
'''
)
# Out:
# 10
#
# 20 = 10100
#
# 10100 >> 1
# 01010 = 10

# %%
# Right Shift by 2

number = 20
number >>= 2

print(number)

print(
'''
20 = 10100

10100 >> 2
00101 = 5
'''
)
# Out:
# 5
#
# 20 = 10100
#
# 10100 >> 2
# 00101 = 5

# %%
# Right Shift by 3

number = 40
number >>= 3

print(number)
# Out:
# 5

# %%
# Right Shift by 0

number = 20
number >>= 0

print(number)
# Out:
# 20

# %%
# Multiple Right Shifts

number = 80

number >>= 1
number >>= 1
number >>= 1

print(number)

print(
'''
80 >> 1 = 40
40 >> 1 = 20
20 >> 1 = 10
'''
)
# Out:
# 10
#
# 80 >> 1 = 40
# 40 >> 1 = 20
# 20 >> 1 = 10

# %%
# Variables

number = 40
positions = 2

number >>= positions
print(number)
# Out:
# 10

# %%
# Binary Representation

number = 20
number >>= 2

print(bin(number))
print(number)
# Out:
# 0b101
# 5

# %%
# Binary Literals

number = 0b10100
number >>= 2

print(bin(number))
print(number)
# Out:
# 0b101
# 5

# %%
# Hexadecimal

number = 0x20
number >>= 2

print(hex(number))
print(number)
# Out:
# 0x8
# 8

# %%
# Right Shift

number = 20
number >>= 2

print(number)
# Out:
# 5

# %%
# Right Shift

number = 100
number >>= 2

print(number)
# Out:
# 25

# %%
# Expression

number = 32
number >>= 1 + 2

print(number)
# Out:
# 4

# %%
# User Input

number = int(input("Enter a number: "))
positions = int(input("Enter number of positions: "))

number >>= positions
print(number)
# Out:
# 49

# %%
# Loop

number = 64

for i in range(3):
    number >>= 1
print(number)

print(
'''
64 >> 1 = 32
32 >> 1 = 16
16 >> 1 = 8
'''
)
# Out:
# 8
#
# 64 >> 1 = 32
# 32 >> 1 = 16
# 16 >> 1 = 8

# %%
# Repeated Right Shift

number = 128

number >>= 1
number >>= 1
number >>= 1
number >>= 1

print(number)
# Out:
# 8

# %%
# Right Shift by 4

number = 160
number >>= 4

print(number)
# Out:
# 10

# %%
# Shift One

number = 1
number >>= 1

print(number)

print(
'''
1 = 0001

0001 >> 1
0000
'''
)
# Out:
# 0
#
# 1 = 0001
#
# 0001 >> 1
# 0000

# %%
# Shift Zero

number = 0
number >>= 5

print(number)
# Out:
# 0

# %%
# Removing Bits

number = 29
number >>= 2

print(number)

print(
'''
29 = 11101

11101 >> 2
00111
'''
)
# Out:
# 7
#
# 29 = 11101
#
# 11101 >> 2
# 00111

# %%
# Extract Higher Bits

number = 29
number >>= 2

print(number)
# Out:
# 7

# %%
# Bit Position

value = 32
value >>= 3

print(value)
# Out:
# 4

# %%
# Bit Flag

flag = 0b10000
flag >>= 2

print(bin(flag))
print(flag)
# Out:
# 0b100
# 4

# %%
# Right Shift

number = 20
result = number >> 2

print(number)
print(result)
# Out:
# 20
# 5

# %%
# Right Shift Assignment

number = 20
number >>= 2

print(number)
# Out:
# 5

# %%
# Result Type

number = 20
number >>= 2

print(number)
print(type(number))
# Out:
# 5
# <class 'int'>

# %%
# Negative Number

number = -20
number >>= 1

print(number)
# Out:
# -10

# %%
#ValueError: negative shift count
number = 20

# number >>= -1

# %%
#TypeError
number = 20

# number >>= 2.5

# %% [markdown]
# | Expression | Equivalent   | Meaning          |
# | ---------- | ------------ | ---------------- |
# | `x >>= 1`  | `x = x >> 1` | Shift right by 1 |
# | `x >>= 2`  | `x = x >> 2` | Shift right by 2 |
# | `x >>= 3`  | `x = x >> 3` | Shift right by 3 |
# | `x >>= 0`  | `x = x >> 0` | No change        |
