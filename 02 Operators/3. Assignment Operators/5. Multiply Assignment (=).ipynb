# %% [markdown]
# #### ✖️ Multiply Assignment Operator (`*=`)
#
# The **Multiply Assignment (`*=`) operator** is a compound assignment operator in Python used to **multiply a variable by a value and assign the updated result back to the same variable**.
#
# Instead of writing `x = x * value`, you can write `x *= value`, making your code shorter, cleaner, and easier to read.
#
# The Multiply Assignment operator works with **integers (`int`)**, **floating-point numbers (`float`)**, **complex numbers (`complex`)**, and sequence types like **strings (`str`)**, **lists (`list`)**, and **tuples (`tuple`)** when multiplied by an integer.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Multiply Assignment operator is.
# - Syntax of the Multiply Assignment operator.
# - How it works.
# - Using `*=` with different data types.
# - Practical programming examples.
# - Common real-world applications.
# - Common mistakes.
# - Best practices.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# quantity = 8
#
# quantity *= 5
#
# print(quantity)
# ```
#
# ##### Output
#
# ```text
# 40
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Multiply Assignment Operator
#
# The Multiply Assignment operator (`*=`) multiplies the current value of a variable by another value and stores the result back in the same variable.
#
# Instead of writing:
#
# ```python
# quantity = quantity * 5
# ```
#
# you can simply write:
#
# ```python
# quantity *= 5
# ```
#
# Both statements produce the same result.
#
# ---
#
# ##### 2. Syntax
#
# ##### Syntax
#
# ```python
# variable *= value
# ```
#
# ##### Equivalent To
#
# ```python
# variable = variable * value
# ```
#
# ##### Explanation
#
# - `variable` → Variable whose value will be updated.
# - `*=` → Multiply Assignment operator.
# - `value` → Value used for multiplication.
#
# ---
#
# ##### 3. Multiplying Integers
#
# The Multiply Assignment operator works with integers.
#
# **Example**
#
# ```python
# number = 12
#
# number *= 4
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 48
# ```
#
# ---
#
# ##### 4. Multiplying Floating-Point Numbers
#
# The operator also works with floating-point numbers.
#
# **Example**
#
# ```python
# price = 19.5
#
# price *= 2
#
# print(price)
# ```
#
# ##### Output
#
# ```text
# 39.0
# ```
#
# ---
#
# ##### 5. Multiplying Complex Numbers
#
# The operator supports complex numbers.
#
# **Example**
#
# ```python
# num = 2 + 3j
#
# num *= 2
#
# print(num)
# ```
#
# ##### Output
#
# ```text
# (4+6j)
# ```
#
# ---
#
# ##### 6. Multiplying Strings
#
# When multiplied by an integer, strings are repeated.
#
# **Example**
#
# ```python
# text = "Hi "
#
# text *= 3
#
# print(text)
# ```
#
# ##### Output
#
# ```text
# Hi Hi Hi
# ```
#
# ---
#
# ##### 7. Multiplying Lists
#
# Lists can also be repeated.
#
# **Example**
#
# ```python
# numbers = [1, 2]
#
# numbers *= 3
#
# print(numbers)
# ```
#
# ##### Output
#
# ```text
# [1, 2, 1, 2, 1, 2]
# ```
#
# ---
#
# ##### 8. Multiplying Tuples
#
# Tuples can be repeated using the Multiply Assignment operator.
#
# **Example**
#
# ```python
# colors = ("Red", "Blue")
#
# colors *= 2
#
# print(colors)
# ```
#
# ##### Output
#
# ```text
# ('Red', 'Blue', 'Red', 'Blue')
# ```
#
# ---
#
# ##### 9. Practical Examples
#
# Apply the Multiply Assignment operator through practical programming examples.
#
# ##### Example 1: Salary Increment Factor
#
# ```python
# salary = 25000
#
# salary *= 2
#
# print(salary)
# ```
#
# ##### Output
#
# ```text
# 50000
# ```
#
# ---
#
# ##### Example 2: Area Scaling
#
# ```python
# length = 15
#
# length *= 3
#
# print(length)
# ```
#
# ##### Output
#
# ```text
# 45
# ```
#
# ---
#
# ##### Example 3: Repeat Warning Message
#
# ```python
# warning = "Warning! "
#
# warning *= 2
#
# print(warning)
# ```
#
# ##### Output
#
# ```text
# Warning! Warning!
# ```
#
# ---
#
# ##### 10. Common Use Cases
#
# The Multiply Assignment operator is commonly used in:
#
# - Scientific calculations
# - Financial computations
# - Data scaling
# - Image processing
# - Game development
# - Sequence repetition
# - Mathematical algorithms
# - Simulation programs
#
# ---
#
# ##### 11. Common Mistakes
#
# Avoid these common mistakes while using the Multiply Assignment operator.
#
# ##### Using an Uninitialized Variable
#
# **Incorrect**
#
# ```python
# count *= 2
# ```
#
# ##### Output
#
# ```text
# NameError
# ```
#
# **Correct**
#
# ```python
# count = 5
#
# count *= 2
# ```
#
# ---
#
# ##### Multiplying Incompatible Data Types
#
# ```python
# number = 10
#
# number *= "5"
# ```
#
# ##### Output
#
# ```text
# TypeError
# ```
#
# ---
#
# ##### Forgetting Spaces Around Operators
#
# Although valid,
#
# ```python
# value*=4
# ```
#
# is less readable than
#
# ```python
# value *= 4
# ```
#
# ---
#
# ##### 12. Best Practices
#
# Follow these recommended practices when using the Multiply Assignment operator.
#
# - Initialize variables before using `*=`.
# - Use `*=` instead of `variable = variable * value` for cleaner code.
# - Ensure operands are compatible.
# - Use meaningful variable names.
# - Follow Python style guidelines by adding spaces around operators.
#
# ---
#
# #### 📊 Summary
#
# | Feature | Description |
# |---------|-------------|
# | Operator | `*=` |
# | Category | Assignment Operator |
# | Purpose | Multiplies a value and assigns the result back to the variable |
# | Equivalent To | `variable = variable * value` |
# | Works With | `int`, `float`, `complex`, `str`, `list`, `tuple` |
# | Common Uses | Scaling values, sequence repetition, mathematical calculations |
#
# ---
#
# > **Note:** The Multiply Assignment (`*=`) operator combines multiplication and assignment into a single statement, making Python code more concise and readable. It is widely used in numerical computations, scaling operations, and repeating sequence data such as strings, lists, and tuples.

# %%
# Multiply Assignment
number = 10
number *= 5

print(number)
# Out:
# 50

# %%
# Integer
number = 100
number *= 2

print(number)
# Out:
# 200

# %%
# Float
number = 10
number *= 2.5

print(number)
# Out:
# 25.0

# %%
# Float Variable
number = 10.5
number *= 2

print(number)
# Out:
# 21.0

# %%
# Multiplication by Zero
number = 100
number *= 0

print(number)
# Out:
# 0

# %%
# Multiplication by One
number = 100
number *= 1

print(number)
# Out:
# 100

# %%
# Negative Multiplier
number = 10
number *= -2

print(number)
# Out:
# -20

# %%
# Multiple Multiply Assignments
number = 2

number *= 3
number *= 4
number *= 5

print(number)
# Out:
# 120

# %%
# Variables
number = 10
value = 5

number *= value
print(number)
# Out:
# 50

# %%
# User Input
number = int(input("Enter a number: "))
value = int(input("Enter multiplier: "))

number *= value
print(number)
# Out:
# 3080

# %%
# Loop
number = 2
for i in range(4):
    number *= 2

print(number)
# Out:
# 32

# %%
# Running Product
result = 1

for number in range(1, 6):
    result *= number
print(result)
# Out:
# 120

# %%
# Expression
number = 10

number *= 2 + 3
print(number)
# Out:
# 50

# %%
# Expression
number = 5

number *= 2 ** 3
print(number)
# Out:
# 40

# %%
# Expression
number = 10

number *= 20 / 5
print(number)
# Out:
# 40.0

# %%
# String Repetition
text = "Python"

text *= 3
print(text)
# Out:
# PythonPythonPython

# %%
# String Repetition
text = "Hi "

text *= 3
print(text)
# Out:
# Hi Hi Hi

# %%
# List Repetition
numbers = [1, 2]

numbers *= 3
print(numbers)
# Out:
# [1, 2, 1, 2, 1, 2]

# %%
# Boolean
number = 10

number *= True
print(number)
# Out:
# 10

# %%
# Conditional

price = 1000
discount_multiplier = 0.9

if True:
    price *= discount_multiplier
print(price)
# Out:
# 900.0

# %%
# Total Price

price = 500
quantity = 3

total = price
total *= quantity

print(total)
# Out:
# 1500

# %%
# Game Score
score = 100
score *= 2

print(score)
# Out:
# 200

# %%
# Scaling
value = 50
value *= 1.5

print(value)
# Out:
# 75.0

# %%
# Compound Growth
amount = 1000
amount *= 1.10

print(amount)
# Out:
# 1100.0

# %%
# Multiplication
number = 10
result = number * 5

print(number)
print(result)
# Out:
# 10
# 50

# %%
# Multiply Assignment
number = 10
number *= 5

print(number)
# Out:
# 50

# %%
number = 10
number *= 5
number *= 2
number
# Out:
# 100

# %%
# Result Type
number = 10
number *= 5

print(number)
print(type(number))
# Out:
# 50
# <class 'int'>

# %%
number = 10
number *= 2.5

print(type(number))
# Out:
# <class 'float'>

# %%
# Fractional Multiplier
number = 100
number *= 0.5

print(number)
# Out:
# 50.0

# %%
number = 10
# number *= "5"

# %%
text = "Python"
text *= 2

print(text)
# Out:
# PythonPython

# %% [markdown]
# | Expression  | Equivalent        | Meaning          |
# | ----------- | ----------------- | ---------------- |
# | `x *= 5`    | `x = x * 5`       | Multiply by `5`  |
# | `x *= 10`   | `x = x * 10`      | Multiply by `10` |
# | `x *= 0`    | `x = x * 0`       | Becomes `0`      |
# | `x *= 1`    | `x = x * 1`       | No change        |
# | `x *= -2`   | `x = x * -2`      | Multiply by `-2` |
# | `text *= 3` | `text = text * 3` | Repeat string    |
# | `list *= 3` | `list = list * 3` | Repeat list      |
