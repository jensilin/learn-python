# %% [markdown]
# #### 📝 Assignment Operator (`=`)
#
# The **Assignment (`=`) operator** is the most fundamental assignment operator in Python. It is used to **assign a value to a variable**.
#
# When Python executes an assignment statement, the value on the **right-hand side** is evaluated first, and the resulting value is stored in the variable on the **left-hand side**.
#
# The Assignment operator is used throughout every Python program to store data such as numbers, strings, lists, dictionaries, objects, and function results.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Assignment operator is.
# - Syntax of the Assignment operator.
# - How assignment works.
# - Assigning different data types.
# - Multiple assignment.
# - Practical programming examples.
# - Common mistakes.
# - Best practices.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# name = "Alice"
#
# print(name)
# ```
#
# ##### Output
#
# ```text
# Alice
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Assignment Operator
#
# The Assignment operator (`=`) stores a value in a variable.
#
# It does **not** compare two values. It simply assigns the value on the right side to the variable on the left side.
#
# **Example**
#
# ```python
# age = 25
#
# print(age)
# ```
#
# ##### Output
#
# ```text
# 25
# ```
#
# ---
#
# ##### 2. Syntax
#
# ##### Syntax
#
# ```python
# variable = value
# ```
#
# ##### Explanation
#
# - `variable` → Name used to store data.
# - `=` → Assignment operator.
# - `value` → Data to be assigned.
#
# Python first evaluates the value and then stores it in the variable.
#
# ---
#
# ##### 3. Assigning Integer Values
#
# You can assign integer values to variables.
#
# **Example**
#
# ```python
# count = 100
#
# print(count)
# ```
#
# ##### Output
#
# ```text
# 100
# ```
#
# ---
#
# ##### 4. Assigning Floating-Point Values
#
# Floating-point numbers can also be assigned.
#
# **Example**
#
# ```python
# price = 99.99
#
# print(price)
# ```
#
# ##### Output
#
# ```text
# 99.99
# ```
#
# ---
#
# ##### 5. Assigning Strings
#
# Strings can be assigned to variables.
#
# **Example**
#
# ```python
# language = "Python"
#
# print(language)
# ```
#
# ##### Output
#
# ```text
# Python
# ```
#
# ---
#
# ##### 6. Assigning Boolean Values
#
# Boolean values are frequently assigned in programs.
#
# **Example**
#
# ```python
# is_logged_in = True
#
# print(is_logged_in)
# ```
#
# ##### Output
#
# ```text
# True
# ```
#
# ---
#
# ##### 7. Assigning Collections
#
# The Assignment operator works with collection data types.
#
# ##### List
#
# ```python
# numbers = [10, 20, 30]
#
# print(numbers)
# ```
#
# ##### Output
#
# ```text
# [10, 20, 30]
# ```
#
# ---
#
# ##### Tuple
#
# ```python
# coordinates = (5, 8)
#
# print(coordinates)
# ```
#
# ##### Output
#
# ```text
# (5, 8)
# ```
#
# ---
#
# ##### Dictionary
#
# ```python
# student = {
#     "name": "John",
#     "age": 21
# }
#
# print(student)
# ```
#
# ##### Output
#
# ```text
# {'name': 'John', 'age': 21}
# ```
#
# ---
#
# ##### 8. Multiple Assignment
#
# Python allows multiple variables to be assigned in a single statement.
#
# **Example**
#
# ```python
# x, y, z = 10, 20, 30
#
# print(x)
# print(y)
# print(z)
# ```
#
# ##### Output
#
# ```text
# 10
# 20
# 30
# ```
#
# ---
#
# ##### 9. Assigning the Same Value to Multiple Variables
#
# The same value can be assigned to multiple variables.
#
# **Example**
#
# ```python
# a = b = c = 100
#
# print(a)
# print(b)
# print(c)
# ```
#
# ##### Output
#
# ```text
# 100
# 100
# 100
# ```
#
# ---
#
# ##### 10. Practical Examples
#
# Apply the Assignment operator through practical programming examples.
#
# ##### Example 1: Student Information
#
# ```python
# name = "Emma"
# age = 20
#
# print(name)
# print(age)
# ```
#
# ##### Output
#
# ```text
# Emma
# 20
# ```
#
# ---
#
# ##### Example 2: Product Details
#
# ```python
# product = "Laptop"
# price = 75000
#
# print(product)
# print(price)
# ```
#
# ##### Output
#
# ```text
# Laptop
# 75000
# ```
#
# ---
#
# ##### Example 3: Bank Balance
#
# ```python
# balance = 25000
#
# print(balance)
# ```
#
# ##### Output
#
# ```text
# 25000
# ```
#
# ---
#
# ##### 11. Common Use Cases
#
# The Assignment operator is commonly used in:
#
# - Storing user input
# - Saving calculation results
# - Creating variables
# - Initializing counters
# - Configuration settings
# - Database records
# - Data processing
# - Object creation
#
# ---
#
# ##### 12. Common Mistakes
#
# Avoid these common mistakes while using the Assignment operator.
#
# ##### Using `==` Instead of `=`
#
# **Incorrect**
#
# ```python
# name == "John"
# ```
#
# ##### Output
#
# ```text
# NameError
# ```
#
# > **Why?** The `==` operator compares values, while `=` assigns a value to a variable.
#
# ---
#
# ##### Using Invalid Variable Names
#
# **Incorrect**
#
# ```python
# 1name = "Alice"
# ```
#
# ##### Output
#
# ```text
# SyntaxError
# ```
#
# ---
#
# ##### Using Undefined Variables
#
# ```python
# print(age)
# ```
#
# ##### Output
#
# ```text
# NameError
# ```
#
# > **Why?** A variable must be assigned a value before it can be used.
#
# ---
#
# ##### 13. Best Practices
#
# Follow these recommended practices when using the Assignment operator.
#
# - Use meaningful variable names.
# - Initialize variables before using them.
# - Keep assignment statements simple.
# - Follow Python naming conventions.
# - Assign values close to where they are used.
# - Use multiple assignment only when it improves readability.
#
# ---
#
# #### 📊 Summary
#
# | Feature | Description |
# |---------|-------------|
# | Operator | `=` |
# | Category | Assignment Operator |
# | Purpose | Assigns a value to a variable |
# | Returns | No return value (stores data in a variable) |
# | Works With | All Python data types |
# | Supports Multiple Assignment | ✅ Yes |
#
# ---
#
# > **Note:** The Assignment (`=`) operator is one of the most important operators in Python. Every Python program relies on it to create variables and store data. A clear understanding of assignment is essential before learning more advanced programming concepts such as functions, loops, classes, and data structures.

# %%
# Assignment
number = 10

print(number)
# Out:
# 10

# %%
# String Assignment
name = "Jensilin"

print(name)
# Out:
# Jensilin

# %%
# Float Assignment
price = 99.99

print(price)
# Out:
# 99.99

# %%
# Boolean Assignment
is_active = True

print(is_active)
# Out:
# True

# %%
# None Assignment
value = None

print(value)
# Out:
# None

# %%
# List Assignment
numbers = [10, 20, 30]

print(numbers)
# Out:
# [10, 20, 30]

# %%
# Tuple Assignment
numbers = (10, 20, 30)

print(numbers)
# Out:
# (10, 20, 30)

# %%
# Set Assignment
numbers = {10, 20, 30}

print(numbers)
# Out:
# {10, 20, 30}

# %%
# Dictionary Assignment
student = {
    "name": "Jensilin",
    "age": 23
}

print(student)
# Out:
# {'name': 'Jensilin', 'age': 23}

# %%
# Expression Assignment
result = 10 + 5

print(result)
# Out:
# 15

# %%
# Expression Assignment
total = 100 * 5

print(total)
# Out:
# 500

# %%
# Comparison Result
result = 10 > 5

print(result)
# Out:
# True

# %%
# Multiple Assignment
a = 10
b = 20
c = 30

print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %%
# Multiple Assignment
a, b, c = 10, 20, 30

print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %%
# Same Value
a = b = c = 100

print(a)
print(b)
print(c)
# Out:
# 100
# 100
# 100

# %%
# Reassignment
number = 10
print(number)

number = 20
print(number)
# Out:
# 10
# 20

# %%
# Changing Data Type

value = 10
print(value)
print(type(value))

value = "Python"
print(value)
print(type(value))
# Out:
# 10
# <class 'int'>
# Python
# <class 'str'>

# %%
# Assigning Another Variable
a = 10
b = a

print(a)
print(b)
# Out:
# 10
# 10

# %%
# Expression
a = 10
b = 20

result = a + b
print(result)
# Out:
# 30

# %%
# User Input

name = input("Enter your name: ")
print(name)
# Out:
# Jensilin

# %%
# Assignment in Loop
total = 0

for number in range(1, 6):
    total = total + number

print(total)
# Out:
# 15

# %%
# Assignment with if
number = 10

if number > 5:
    result = "Greater"
    
print(result)
# Out:
# Greater

# %%
# Function Result
def get_number():
    return 100

result = get_number()
print(result)
# Out:
# 100

# %%
# Swapping Variables
a = 10
b = 20

a, b = b, a
print(a)
print(b)
# Out:
# 20
# 10

# %%
# Assignment

number = 10
print(number)
# Out:
# 10

# %%
# Equality

number = 10
print(number == 10)
# Out:
# True

# %%
# Assignment
a = 10
b = 20

print(a)
print(b)
# Out:
# 10
# 20

# %%
# Comparison
print(a == b)
# Out:
# False

# %%
# Empty String

name = ""
print(name)

# %%
# Empty List

numbers = []
print(numbers)
# Out:
# []

# %%
# Empty Dictionary

student = {}
print(student)
# Out:
# {}

# %%
# Different Data Types

integer_value = 10
float_value = 10.5
string_value = "Python"
boolean_value = True
none_value = None

print(integer_value)
print(float_value)
print(string_value)
print(boolean_value)
print(none_value)
# Out:
# 10
# 10.5
# Python
# True
# None

# %% [markdown]
# | Example         | Meaning                         |
# | --------------- | ------------------------------- |
# | `x = 10`        | Assign `10` to `x`              |
# | `x = "Python"`  | Assign a string                 |
# | `x = 10 + 5`    | Assign expression result        |
# | `x = y`         | Assign value/reference from `y` |
# | `a = b = 10`    | Assign `10` to both             |
# | `a, b = 10, 20` | Multiple assignment             |
# | `x = None`      | Assign `None`                   |
# | `x = input()`   | Assign user input               |

# %% [markdown]
# | Operator | Purpose             | Example   |
# | -------- | ------------------- | --------- |
# | `=`      | Assignment          | `x = 10`  |
# | `==`     | Equality comparison | `x == 10` |
