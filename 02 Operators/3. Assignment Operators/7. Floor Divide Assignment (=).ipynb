# %% [markdown]
# #### ⌊⌋ Floor Divide Assignment Operator (`//=`)
#
# The **Floor Divide Assignment (`//=`) operator** is a compound assignment operator in Python used to **perform floor division on a variable and assign the updated result back to the same variable**.
#
# Instead of writing `x = x // value`, you can write `x //= value`, making your code shorter, cleaner, and easier to read.
#
# The Floor Divide Assignment operator works with **integers (`int`)** and **floating-point numbers (`float`)**. It returns the **floor value** (largest whole number less than or equal to the quotient).
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Floor Divide Assignment operator is.
# - Syntax of the Floor Divide Assignment operator.
# - How it works.
# - Using `//=` with integers and floating-point numbers.
# - Practical programming examples.
# - Common real-world applications.
# - Common mistakes.
# - Best practices.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# number = 25
#
# number //= 4
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 6
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Floor Divide Assignment Operator
#
# The Floor Divide Assignment operator (`//=`) divides the current value of a variable by another value using **floor division** and stores the result back in the same variable.
#
# Instead of writing:
#
# ```python
# number = number // 4
# ```
#
# you can simply write:
#
# ```python
# number //= 4
# ```
#
# Both statements produce the same result.
#
# ---
#
# ##### 2. Syntax
#
# ##### Syntax
#
# ```python
# variable //= value
# ```
#
# ##### Equivalent To
#
# ```python
# variable = variable // value
# ```
#
# ##### Explanation
#
# - `variable` → Variable whose value will be updated.
# - `//=` → Floor Divide Assignment operator.
# - `value` → Value used for floor division.
#
# ---
#
# ##### 3. Floor Divide Assignment with Integers
#
# The operator works with integer values.
#
# **Example**
#
# ```python
# count = 22
#
# count //= 5
#
# print(count)
# ```
#
# ##### Output
#
# ```text
# 4
# ```
#
# ---
#
# ##### 4. Floor Divide Assignment with Floating-Point Numbers
#
# The operator also works with floating-point numbers.
#
# **Example**
#
# ```python
# price = 18.5
#
# price //= 3
#
# print(price)
# ```
#
# ##### Output
#
# ```text
# 6.0
# ```
#
# > **Note:** If either operand is a `float`, the result is also returned as a `float`.
#
# ---
#
# ##### 5. Floor Divide Assignment with Negative Numbers
#
# The operator rounds the result **down toward negative infinity**.
#
# **Example**
#
# ```python
# value = -17
#
# value //= 5
#
# print(value)
# ```
#
# ##### Output
#
# ```text
# -4
# ```
#
# ---
#
# ##### 6. Practical Examples
#
# Apply the Floor Divide Assignment operator through practical programming examples.
#
# ##### Example 1: Number of Complete Boxes
#
# ```python
# items = 57
#
# items //= 10
#
# print(items)
# ```
#
# ##### Output
#
# ```text
# 5
# ```
#
# ---
#
# ##### Example 2: Completed Hours
#
# ```python
# minutes = 250
#
# minutes //= 60
#
# print(minutes)
# ```
#
# ##### Output
#
# ```text
# 4
# ```
#
# ---
#
# ##### Example 3: Student Groups
#
# ```python
# students = 48
#
# students //= 6
#
# print(students)
# ```
#
# ##### Output
#
# ```text
# 8
# ```
#
# ---
#
# ##### 7. Common Use Cases
#
# The Floor Divide Assignment operator is commonly used in:
#
# - Inventory management
# - Pagination
# - Time calculations
# - Batch processing
# - Resource allocation
# - Manufacturing systems
# - Seating arrangements
# - Data processing
#
# ---
#
# ##### 8. Common Mistakes
#
# Avoid these common mistakes while using the Floor Divide Assignment operator.
#
# ##### Using an Uninitialized Variable
#
# **Incorrect**
#
# ```python
# count //= 2
# ```
#
# ##### Output
#
# ```text
# NameError
# ```
#
# **Correct**
#
# ```python
# count = 10
#
# count //= 2
# ```
#
# ---
#
# ##### Dividing by Zero
#
# ```python
# number = 20
#
# number //= 0
# ```
#
# ##### Output
#
# ```text
# ZeroDivisionError
# ```
#
# ---
#
# ##### Confusing `//=` with `/=`
#
# ```python
# number = 15
#
# number /= 4
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 3.75
# ```
#
# Using floor division:
#
# ```python
# number = 15
#
# number //= 4
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 3
# ```
#
# ---
#
# ##### Ignoring Negative Numbers
#
# ```python
# value = -15
#
# value //= 4
#
# print(value)
# ```
#
# ##### Output
#
# ```text
# -4
# ```
#
# > **Why?** Floor division always rounds **down**, not toward zero.
#
# ---
#
# ##### 9. Best Practices
#
# Follow these recommended practices when using the Floor Divide Assignment operator.
#
# - Initialize variables before using `//=`.
# - Use `//=` only when the whole-number quotient is required.
# - Check that the divisor is not zero.
# - Be careful when working with negative numbers.
# - Use meaningful variable names.
# - Follow Python style guidelines by adding spaces around operators.
#
# ---
#
# #### 📊 Summary
#
# | Feature | Description |
# |---------|-------------|
# | Operator | `//=` |
# | Category | Assignment Operator |
# | Purpose | Performs floor division and assigns the result back to the variable |
# | Equivalent To | `variable = variable // value` |
# | Works With | `int`, `float` |
# | Returns | Floor value of the quotient |
# | Division by Zero | Raises `ZeroDivisionError` |
#
# ---
#
# > **Note:** The Floor Divide Assignment (`//=`) operator combines floor division and assignment into a single statement. It is especially useful when working with complete groups, resource allocation, pagination, and other situations where only the whole-number quotient is required.

# %%
# Floor Divide Assignment

number = 10
number //= 3

print(number)
# Out:
# 3

# %%
# Exact Division

number = 20
number //= 5

print(number)
# Out:
# 4

# %%
# Division with Remainder

number = 17
number //= 5

print(number)
# Out:
# 3

# %%
# Result Type

number = 17
number //= 5

print(number)
print(type(number))
# Out:
# 3
# <class 'int'>

# %%
# Float

number = 10.0
number //= 3

print(number)
# Out:
# 3.0

# %%
# Integer and Float

number = 10
number //= 2.5

print(number)
# Out:
# 4.0

# %%
# Multiple Floor Divide Assignments
number = 100

number //= 2
number //= 5

print(number)
# Out:
# 10

# %%
# Variables
number = 100
divisor = 4

number //= divisor
print(number)
# Out:
# 25

# %%
# User Input
number = int(input("Enter a number: "))
divisor = int(input("Enter divisor: "))

number //= divisor
print(number)
# Out:
# 6

# %%
# Loop
number = 100

for i in range(3):
    number //= 2

print(number)
# Out:
# 12

# %%
# Repeated Floor Division
number = 80

number //= 2
number //= 2
number //= 2

print(number)
# Out:
# 10

# %%
# Expression
number = 100

number //= 2 + 3
print(number)
# Out:
# 20

# %%
# Expression
number = 100

number //= 2 * 5
print(number)
# Out:
# 10

# %%
# Exponentiation
number = 100

number //= 2 ** 2
print(number)
# Out:
# 25

# %%
# Positive Numbers
number = 25

number //= 4
print(number)
# Out:
# 6

# %%
# Negative Number
number = -10

number //= 3
print(number)
# Out:
# -4

# %%
# Negative Divisor
number = 10

number //= -3
print(number)
# Out:
# -4

# %%
# Both Negative
number = -10

number //= -3
print(number)
# Out:
# 3

# %%
# Floor Division
number = 17
result = number // 5

print(number)
print(result)
# Out:
# 17
# 3

# %%
# Floor Divide Assignment
number = 17
number //= 5

print(number)
# Out:
# 3

# %%
# Complete Boxes
items = 27
items_per_box = 5

items //= items_per_box
print(items)
# Out:
# 5

# %%
# Complete Groups
students = 23
students_per_group = 4

students //= students_per_group
print(students)
# Out:
# 5

# %%
# Convert Minutes to Hours
minutes = 135
minutes //= 60

print(minutes)
# Out:
# 2

# %%
# Complete Pages
items = 53
items_per_page = 10

items //= items_per_page
print(items)
# Out:
# 5

# %%
# Complete Notes
money = 2750
note_value = 500

money //= note_value
print(money)
# Out:
# 5

# %%
# Conditional
number = 100

if number >= 50:
    number //= 2

print(number)
# Out:
# 50

# %%
# Quotient and Remainder
number = 17
divisor = 5

quotient = number
quotient //= divisor
remainder = number % divisor

print(quotient)
print(remainder)
# Out:
# 3
# 2

# %%
# Division by Zero

number = 10
# number //= 0

# %%
# Safe Floor Division
number = 100
divisor = 0

if divisor != 0:
    number //= divisor
    print(number)
else:
    print("Cannot divide by zero")
# Out:
# Cannot divide by zero

# %% [markdown]
# | Expression | Equivalent    | Meaning              |
# | ---------- | ------------- | -------------------- |
# | `x //= 5`  | `x = x // 5`  | Floor divide by `5`  |
# | `x //= 2`  | `x = x // 2`  | Floor divide by `2`  |
# | `x //= 1`  | `x = x // 1`  | No numeric change    |
# | `x //= -2` | `x = x // -2` | Floor divide by `-2` |
