# %% [markdown]
# #### ➕ Add Assignment Operator (`+=`)
#
# The **Add Assignment (`+=`) operator** is a compound assignment operator in Python used to **add a value to a variable and assign the updated result back to the same variable**.
#
# Instead of writing `x = x + value`, you can write `x += value`, making your code shorter, cleaner, and easier to read.
#
# The Add Assignment operator works with various data types, including **integers (`int`)**, **floating-point numbers (`float`)**, **strings (`str`)**, **lists (`list`)**, and other objects that support addition.
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Add Assignment operator is.
# - Syntax of the Add Assignment operator.
# - How it works.
# - Using `+=` with different data types.
# - Practical programming examples.
# - Common real-world applications.
# - Common mistakes.
# - Best practices.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# count = 10
#
# count += 5
#
# print(count)
# ```
#
# ##### Output
#
# ```text
# 15
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Add Assignment Operator
#
# The Add Assignment operator (`+=`) adds the right-hand operand to the current value of the variable and stores the result back in the same variable.
#
# Instead of writing:
#
# ```python
# count = count + 5
# ```
#
# you can simply write:
#
# ```python
# count += 5
# ```
#
# Both statements produce the same result.
#
# ---
#
# ##### 2. Syntax
#
# ##### Syntax
#
# ```python
# variable += value
# ```
#
# ##### Equivalent To
#
# ```python
# variable = variable + value
# ```
#
# ##### Explanation
#
# - `variable` → Variable whose value will be updated.
# - `+=` → Add Assignment operator.
# - `value` → Value to be added.
#
# ---
#
# ##### 3. Adding Integers
#
# The Add Assignment operator works with integers.
#
# **Example**
#
# ```python
# score = 50
#
# score += 10
#
# print(score)
# ```
#
# ##### Output
#
# ```text
# 60
# ```
#
# ---
#
# ##### 4. Adding Floating-Point Numbers
#
# The operator also works with floating-point numbers.
#
# **Example**
#
# ```python
# price = 99.5
#
# price += 20.5
#
# print(price)
# ```
#
# ##### Output
#
# ```text
# 120.0
# ```
#
# ---
#
# ##### 5. Adding Strings
#
# For strings, `+=` performs **string concatenation**.
#
# **Example**
#
# ```python
# message = "Hello"
#
# message += " World"
#
# print(message)
# ```
#
# ##### Output
#
# ```text
# Hello World
# ```
#
# ---
#
# ##### 6. Adding Lists
#
# For lists, `+=` appends the elements of another iterable to the existing list.
#
# **Example**
#
# ```python
# numbers = [1, 2, 3]
#
# numbers += [4, 5]
#
# print(numbers)
# ```
#
# ##### Output
#
# ```text
# [1, 2, 3, 4, 5]
# ```
#
# ---
#
# ##### 7. Practical Examples
#
# Apply the Add Assignment operator through practical programming examples.
#
# ##### Example 1: Bank Account Balance
#
# ```python
# balance = 5000
#
# balance += 1500
#
# print(balance)
# ```
#
# ##### Output
#
# ```text
# 6500
# ```
#
# ---
#
# ##### Example 2: Student Total Marks
#
# ```python
# marks = 75
#
# marks += 20
#
# print(marks)
# ```
#
# ##### Output
#
# ```text
# 95
# ```
#
# ---
#
# ##### Example 3: Shopping Cart Total
#
# ```python
# total = 250
#
# total += 120
# total += 80
#
# print(total)
# ```
#
# ##### Output
#
# ```text
# 450
# ```
#
# ---
#
# ##### 8. Common Use Cases
#
# The Add Assignment operator is commonly used in:
#
# - Counters
# - Running totals
# - Banking applications
# - Shopping cart calculations
# - Scoreboards
# - Data processing
# - Loop accumulators
# - String building
#
# ---
#
# ##### 9. Common Mistakes
#
# Avoid these common mistakes while using the Add Assignment operator.
#
# ##### Using an Uninitialized Variable
#
# **Incorrect**
#
# ```python
# count += 1
# ```
#
# ##### Output
#
# ```text
# NameError
# ```
#
# **Correct**
#
# ```python
# count = 0
#
# count += 1
# ```
#
# ---
#
# ##### Adding Incompatible Data Types
#
# ```python
# number = 100
#
# number += "50"
# ```
#
# ##### Output
#
# ```text
# TypeError
# ```
#
# ---
#
# ##### Forgetting Spaces Around Operators
#
# Although valid,
#
# ```python
# total+=10
# ```
#
# is less readable than
#
# ```python
# total += 10
# ```
#
# ---
#
# ##### 10. Best Practices
#
# Follow these recommended practices when using the Add Assignment operator.
#
# - Initialize variables before using `+=`.
# - Use `+=` instead of `variable = variable + value` for readability.
# - Ensure operands are compatible.
# - Use meaningful variable names.
# - Follow Python style guidelines by adding spaces around operators.
#
# ---
#
# #### 📊 Summary
#
# | Feature | Description |
# |---------|-------------|
# | Operator | `+=` |
# | Category | Assignment Operator |
# | Purpose | Adds a value and assigns the result back to the variable |
# | Equivalent To | `variable = variable + value` |
# | Works With | `int`, `float`, `str`, `list`, and other compatible data types |
# | Common Uses | Counters, totals, accumulators, string concatenation, list extension |
#
# ---
#
# > **Note:** The Add Assignment (`+=`) operator is one of the most frequently used compound assignment operators in Python. It simplifies code by combining addition and assignment into a single statement, making programs more concise, readable, and easier to maintain.

# %%
# Add Assignment
number = 10
number += 5

print(number)
# Out:
# 15

# %%
# Integer
number = 100
number += 20

print(number)
# Out:
# 120

# %%
# Float
number = 10.5
number += 2.5

print(number)
# Out:
# 13.0

# %%
# Integer and Float
number = 10
number += 2.5

print(number)
# Out:
# 12.5

# %%
# Negative Number
number = 10
number += -5

print(number)
# Out:
# 5

# %%
# Adding Zero
number = 10
number += 0

print(number)
# Out:
# 10

# %%
# Multiple Add Assignments
number = 10

number += 5
number += 10
number += 15

print(number)
# Out:
# 40

# %%
# Variables
number = 10
value = 5

number += value
print(number)
# Out:
# 15

# %%
# User Input

number = int(input("Enter a number: "))
value = int(input("Enter value to add: "))

number += value
print(number)
# Out:
# 908

# %%
# Counter
count = 0

count += 1
count += 1
count += 1

print(count)
# Out:
# 3

# %%
# Loop Counter
count = 0

for number in range(1, 6):
    count += 1
print(count)
# Out:
# 5

# %%
# Total
total = 0

total += 100
total += 200
total += 300

print(total)
# Out:
# 600

# %%
# List Total
numbers = [10, 20, 30, 40]
total = 0

for number in numbers:
    total += number
print(total)
# Out:
# 100

# %%
# String Concatenation
text = "Hello"
text += " Python"

print(text)
# Out:
# Hello Python

# %%
# Multiple String Additions
text = "Python"

text += " is"
text += " easy"

print(text)
# Out:
# Python is easy

# %%
# List Addition

numbers = [1, 2, 3]
numbers += [4, 5]

print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
# Tuple Addition

numbers = (1, 2, 3)
numbers += (4, 5)

print(numbers)
# Out:
# (1, 2, 3, 4, 5)

# %%
# Boolean

number = 10
number += True

print(number)
# Out:
# 11

# %%
number = 10
number += False

print(number)
# Out:
# 10

# %%
# Conditional
total = 0

if True:
    total += 10

print(total)
# Out:
# 10

# %%
# Function Result
def get_value():
    return 50

total = 100
total += get_value()

print(total)
# Out:
# 150

# %%
# Building a String

result = ""
for number in range(1, 4):
    result += str(number)

print(result)
# Out:
# 123

# %%
# Building a List

numbers = []
for number in range(1, 6):
    numbers += [number]

print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
# Addition

number = 10
result = number + 5

print(number)
print(result)
# Out:
# 10
# 15

# %%
# Add Assignment

number = 10
number += 5

print(number)
# Out:
# 15

# %%
number = 10
number += 5
number += 10
number
# Out:
# 25

# %%
# Running Total

total = 0
for number in range(1, 6):
    total += number

print(total)
# Out:
# 15

# %%
# Shopping Cart
total = 0

total += 500
total += 250
total += 150

print(total)
# Out:
# 900

# %%
# Score
score = 0

score += 10
score += 20
score += 15

print(score)
# Out:
# 45

# %%
# Age
age = 20
age += 3

print(age)
# Out:
# 23

# %%
# Result Type
number = 10
number += 5

print(number)
print(type(number))
# Out:
# 15
# <class 'int'>

# %%
number = 10
value = "5"

number += int(value)
print(number)
# Out:
# 15

# %% [markdown]
# | Expression     | Equivalent           |        Result |
# | -------------- | -------------------- | ------------: |
# | `x += 5`       | `x = x + 5`          |      Adds `5` |
# | `x += 10`      | `x = x + 10`         |     Adds `10` |
# | `x += -5`      | `x = x + (-5)`       | Subtracts `5` |
# | `x += 0`       | `x = x + 0`          |     No change |
# | `text += "Hi"` | `text = text + "Hi"` |  Concatenates |
# | `list += [4]`  | Adds element(s)      |  Extends list |
