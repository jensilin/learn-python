# %% [markdown]
# #### ➗ Divide Assignment Operator (`/=`)
#
# The **Divide Assignment (`/=`) operator** is a compound assignment operator in Python used to **divide a variable by a value and assign the updated result back to the same variable**.
#
# Instead of writing `x = x / value`, you can write `x /= value`, making your code shorter, cleaner, and easier to read.
#
# The Divide Assignment operator works with **integers (`int`)**, **floating-point numbers (`float`)**, and **complex numbers (`complex`)**. Regardless of the operand types, **true division (`/`) always returns a floating-point value** (except when working with complex numbers).
#
# ---
#
# #### 📚 What You Will Learn
#
# In this notebook, you will learn:
#
# - What the Divide Assignment operator is.
# - Syntax of the Divide Assignment operator.
# - How it works.
# - Using `/=` with different numeric data types.
# - Practical programming examples.
# - Common real-world applications.
# - Common mistakes.
# - Best practices.
#
# ---
#
# #### 💻 Quick Example
#
# ```python
# salary = 60000
#
# salary /= 2
#
# print(salary)
# ```
#
# ##### Output
#
# ```text
# 30000.0
# ```
#
# ---
#
# #### 📖 Topics Covered
#
# ##### 1. Introduction to the Divide Assignment Operator
#
# The Divide Assignment operator (`/=`) divides the current value of a variable by another value and stores the result back in the same variable.
#
# Instead of writing:
#
# ```python
# salary = salary / 2
# ```
#
# you can simply write:
#
# ```python
# salary /= 2
# ```
#
# Both statements produce the same result.
#
# ---
#
# ##### 2. Syntax
#
# ##### Syntax
#
# ```python
# variable /= value
# ```
#
# ##### Equivalent To
#
# ```python
# variable = variable / value
# ```
#
# ##### Explanation
#
# - `variable` → Variable whose value will be updated.
# - `/=` → Divide Assignment operator.
# - `value` → Value used for division.
#
# ---
#
# ##### 3. Dividing Integers
#
# The Divide Assignment operator works with integers.
#
# **Example**
#
# ```python
# number = 20
#
# number /= 4
#
# print(number)
# ```
#
# ##### Output
#
# ```text
# 5.0
# ```
#
# > **Note:** Even though both operands are integers, the result is a `float`.
#
# ---
#
# ##### 4. Dividing Floating-Point Numbers
#
# The operator also works with floating-point numbers.
#
# **Example**
#
# ```python
# price = 99.9
#
# price /= 3
#
# print(price)
# ```
#
# ##### Output
#
# ```text
# 33.300000000000004
# ```
#
# > **Note:** Floating-point arithmetic may produce small precision differences.
#
# ---
#
# ##### 5. Dividing Complex Numbers
#
# The operator supports complex numbers.
#
# **Example**
#
# ```python
# num = 8 + 4j
#
# num /= 2
#
# print(num)
# ```
#
# ##### Output
#
# ```text
# (4+2j)
# ```
#
# ---
#
# ##### 6. Practical Examples
#
# Apply the Divide Assignment operator through practical programming examples.
#
# ##### Example 1: Average Score
#
# ```python
# total_marks = 450
#
# total_marks /= 5
#
# print(total_marks)
# ```
#
# ##### Output
#
# ```text
# 90.0
# ```
#
# ---
#
# ##### Example 2: Remaining Battery Percentage
#
# ```python
# battery = 80
#
# battery /= 2
#
# print(battery)
# ```
#
# ##### Output
#
# ```text
# 40.0
# ```
#
# ---
#
# ##### Example 3: Equal Expense Sharing
#
# ```python
# bill = 1500
#
# bill /= 3
#
# print(bill)
# ```
#
# ##### Output
#
# ```text
# 500.0
# ```
#
# ---
#
# ##### 7. Common Use Cases
#
# The Divide Assignment operator is commonly used in:
#
# - Average calculations
# - Financial applications
# - Scientific computations
# - Percentage calculations
# - Unit conversions
# - Data normalization
# - Physics formulas
# - Statistical analysis
#
# ---
#
# ##### 8. Common Mistakes
#
# Avoid these common mistakes while using the Divide Assignment operator.
#
# ##### Using an Uninitialized Variable
#
# **Incorrect**
#
# ```python
# count /= 2
# ```
#
# ##### Output
#
# ```text
# NameError
# ```
#
# **Correct**
#
# ```python
# count = 10
#
# count /= 2
# ```
#
# ---
#
# ##### Dividing by Zero
#
# ```python
# number = 10
#
# number /= 0
# ```
#
# ##### Output
#
# ```text
# ZeroDivisionError
# ```
#
# ---
#
# ##### Expecting an Integer Result
#
# ```python
# number = 10
#
# number /= 2
#
# print(type(number))
# ```
#
# ##### Output
#
# ```text
# <class 'float'>
# ```
#
# > **Why?** The `/` operator always performs true division and returns a floating-point result.
#
# ---
#
# ##### Forgetting Spaces Around Operators
#
# Although valid,
#
# ```python
# value/=5
# ```
#
# is less readable than
#
# ```python
# value /= 5
# ```
#
# ---
#
# ##### 9. Best Practices
#
# Follow these recommended practices when using the Divide Assignment operator.
#
# - Initialize variables before using `/=`.
# - Check that the divisor is not zero.
# - Remember that `/=` returns a floating-point result.
# - Use meaningful variable names.
# - Follow Python style guidelines by adding spaces around operators.
#
# ---
#
# #### 📊 Summary
#
# | Feature | Description |
# |---------|-------------|
# | Operator | `/=` |
# | Category | Assignment Operator |
# | Purpose | Divides a value and assigns the result back to the variable |
# | Equivalent To | `variable = variable / value` |
# | Works With | `int`, `float`, `complex` |
# | Returns | `float` (or `complex` for complex numbers) |
# | Division by Zero | Raises `ZeroDivisionError` |
#
# ---
#
# > **Note:** The Divide Assignment (`/=`) operator combines division and assignment into a single statement, making code more concise and readable. It is widely used in calculations involving averages, percentages, financial computations, and scientific applications where values need to be updated after division.

# %%
# Divide Assignment
number = 20
number /= 5

print(number)
# Out:
# 4.0

# %%
# Integer Division
number = 100
number /= 10

print(number)
# Out:
# 10.0

# %%
# Result Type
number = 100
number /= 10

print(number)
print(type(number))
# Out:
# 10.0
# <class 'float'>

# %%
# Float Division
number = 10.5
number /= 2

print(number)
# Out:
# 5.25

# %%
# Integer and Float
number = 10
number /= 2.5

print(number)
# Out:
# 4.0

# %%
# Division by One
number = 100
number /= 1

print(number)
# Out:
# 100.0

# %%
# Negative Divisor
number = 20
number /= -4

print(number)
# Out:
# -5.0

# %%
# Negative Number
number = -20
number /= 4

print(number)
# Out:
# -5.0

# %%
# Both Negative
number = -20
number /= -4

print(number)
# Out:
# 5.0

# %%
# Multiple Divide Assignments
number = 100

number /= 2
number /= 5
print(number)
# Out:
# 10.0

# %%
# Variables
number = 100
divisor = 4

number /= divisor
print(number)
# Out:
# 25.0

# %%
# User Input
number = float(input("Enter a number: "))
divisor = float(input("Enter divisor: "))

number /= divisor
print(number)
# Out:
# 28.0

# %%
# Loop
number = 100

for i in range(2):
    number /= 2
print(number)
# Out:
# 25.0

# %%
# Repeated Division
number = 80

number /= 2
number /= 2
number /= 2

print(number)
# Out:
# 10.0

# %%
# Expression

number = 100
number /= 2 + 3

print(number)
# Out:
# 20.0

# %%
# Expression

number = 100
number /= 2 * 5

print(number)
# Out:
# 10.0

# %%
# Exponentiation

number = 100
number /= 2 ** 2

print(number)
# Out:
# 25.0

# %%
# Conditional

number = 100
if number > 50:
    number /= 2
    
print(number)
# Out:
# 50.0

# %%
# Function Result

def get_divisor():
    return 5

number = 100
number /= get_divisor()

print(number)
# Out:
# 20.0

# %%
# Splitting Money

amount = 1000
people = 4

amount /= people
print(amount)
# Out:
# 250.0

# %%
# Average

total = 300
count = 3

total /= count
print(total)
# Out:
# 100.0

# %%
# Half Price

price = 1000
price /= 2

print(price)
# Out:
# 500.0

# %%
# Scaling Down

value = 500
value /= 10

print(value)
# Out:
# 50.0

# %%
# Division

number = 20
result = number / 5

print(number)
print(result)
# Out:
# 20
# 4.0

# %%
# Divide Assignment

number = 20
number /= 5

print(number)
# Out:
# 4.0

# %%
number = 10
number /= 3

print(number)
# Out:
# 3.3333333333333335

# %%
number = 10
number //= 3

print(number)
# Out:
# 3

# %%
# Decimal Result

number = 7
number /= 2

print(number)
# Out:
# 3.5

# %%
# Division by Zero
number = 100

# number /= 0

# %%
# Safe Division
number = 100
divisor = 0

if divisor != 0:
    number /= divisor
    print(number)
else:
    print("Cannot divide by zero")
# Out:
# Cannot divide by zero

# %%
number = 100
# number /= "5"

# %%
number = 100
divisor = "5"

number /= int(divisor)
print(number)
# Out:
# 20.0

# %% [markdown]
# | Expression | Equivalent    |             Result |
# | ---------- | ------------- | -----------------: |
# | `x /= 5`   | `x = x / 5`   |      Divide by `5` |
# | `x /= 2`   | `x = x / 2`   |      Divide by `2` |
# | `x /= 1`   | `x = x / 1`   | Same numeric value |
# | `x /= -2`  | `x = x / -2`  |     Divide by `-2` |
# | `x /= 0.5` | `x = x / 0.5` |    Divide by `0.5` |
