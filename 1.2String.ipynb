# %% [markdown]
# Primitive Data Types
#
# 1. Strings
# 2. Integers
# 4. Floats
# 5. Booleans

# %%
#Indexing

a="hello"
#In python indexing starts with 0

#hello
#01234

print(a[1])
# Out:
# e

# %%
#indexing types we have 
#positive and negative

b="Jensilin"

print(b[-1])
# Out:
# n

# %%
#Concatenation of string in numbers
print("123" + "456")

#its in the form of string so it does not do tradional addition
# Out:
# 123456

# %%
#String metods

print(len("Jensilin"))
